# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # Missing data GDSC

# %%
gdsc_dr = pd.read_csv('data/GDSC/metrics.csv').rename(columns={'Cell_line':'CCL'})
gdsc_ge = pd.read_csv('data/GDSC/ge.csv', sep='\t').rename(columns={'Unnamed: 0':'CCL'}).transpose()
new = pd.read_csv('data/GDSC/new.csv').rename(columns={'CELL_LINE_NAME':'CCL'})
new['CCL'] = new['CCL'].str.replace('-', '').str.replace(' ','').str.upper()

# %%
print(str(len(gdsc_dr['CCL'].unique())) + ' different CCLs in Pozdeyev\'s data')
# Out:
# 707 different CCLs in Pozdeyev's data

# %%
print(str(len(gdsc_dr['Drug_name'].unique())) + ' different Drugs in Pozdeyev\'s data')
# Out:
# 139 different Drugs in Pozdeyev's data

# %%
print(str(len(new['CCL'].unique())) + ' different CCLs in new data')
# Out:
# 808 different CCLs in new data

# %%
print(str(len(new['DRUG_ID'].unique())) + ' different Drugs in new data')
# Out:
# 200 different Drugs in new data

# %% [markdown]
# ### Deletes the symbols from CCL ID to normalize format

# %%
def clean(s):
    new = []
    for i in s:
        new.append(re.sub("[^A-Za-z0-9]", '', i).upper())
    return new

# %%
poz_r = list(gdsc_dr['CCL'].unique())
cell_r = list(gdsc_ge.index.to_series().reset_index()[0])
gdsc_r = list(pd.Series(new['CCL'].unique()))

cell = clean(cell_r)
poz = clean(poz_r)
gdsc = clean(gdsc_r)

# %% [markdown]
# Pozdeyev's CCLs missing from CellMinerCDB

# %%
miss1 = []
for ccl in poz:
    if ccl not in cell:
        miss1.append(ccl)
len(miss1)
# Out:
# 8

# %% [markdown]
# New data CCLs missing from CellMinerCDB

# %%
miss2 = []
for ccl in gdsc:
    if ccl not in cell:
        miss2.append(ccl)
len(miss2)
# Out:
# 19

# %%
gdsc2 = {k:re.sub("[^A-Za-z0-9]", '', k).upper() for k in gdsc_r if re.sub("[^A-Za-z0-9]", '', k).upper() not in miss2}

# %% [markdown]
# These rules are made by looking at the 'missing' CCLs that turned out to simply have different names

# %%
for i in miss2:
    if i[0:3]=='NCI':
        gdsc2[i] = i.lstrip('NCI')
    elif i[0:3]=='SNU':
        gdsc2[i] = 'NCI' + i

# %%
gdsc2['NTERA2CLD1'] = ('NTERASCLD1')

# %%
new['CCL'] = new['CCL'].replace(gdsc2)

# %% [markdown]
# Same is done now for Pozdayev's data.
#
# ## One question, I turn TTTHYROID into TT because of [this](https://web.expasy.org/cellosaurus/CVCL_1774). Not quite sure, let's maybe discuss it.

# %%
poz2 = {k:re.sub("[^A-Za-z0-9]", '', k) for k in poz_r if re.sub("[^A-Za-z0-9]", '', k).upper() not in miss1}

# %%
missv = ['7860', 'COLO320HSR','KNS81FD', 'EOL1CELL', 'NCIH510A','TT' , 'U266', 'U031']
for i, ele in enumerate(miss1):
    poz2[ele] = missv[i]

# %%
gdsc_dr['CCL'] = gdsc_dr['CCL'].replace(poz2)

# %%
gdsc_dr.to_csv('data/Processed/gdsc_poz_dr.csv', index =False)

# %%
gdsc_ge = gdsc_ge.reset_index()
gdsc_ge.columns = gdsc_ge.iloc[0]
gdsc_ge = gdsc_ge[1:]
cellrep = {k:v for k in cell v in }

# %%
gdsc_ge
# Out:
# 0          CCL     A1BG     A1CF      A2M    A2ML1  A3GALT2 A3GALT2P   A4GALT  \
# 1         201T  3.17242  2.93284  3.39045  2.71703  2.67498  2.67498  3.48303
# 2        22RV1  3.53794  6.36465  5.33244  2.92303  2.81538  2.81538  3.24112
# 3     23132-87  3.37095  6.28488  3.48568  2.83156  2.91337  2.91337  3.31303
# 4     42-MG-BA  6.01674  3.19189  3.24948  2.80896   2.6262   2.6262  3.06339
# 5        451Lu  5.72524  2.97195  10.7685  2.92855  2.75028  2.75028  3.36712
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 1076     YH-13  5.16786  3.07284  3.04907  3.09807  3.02972  3.02972  2.99009
# 1077     YKG-1  4.71162  3.06794  3.30693  3.03796  2.71344  2.71344   3.1544
# 1078   YMB-1-E      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1079        YT  3.14359  3.77979  5.09516  2.87933  2.74909  2.74909  3.18623
# 1080  ZR-75-30  5.59418  3.03213   3.5622  3.10855  2.76767  2.76767  3.61138
#
# 0       A4GNT     AAAS  ...     ZW10   ZWILCH    ZWINT     ZXDB     ZXDC  \
# 1      3.1235  4.75917  ...  7.26434  6.20224  6.28252  4.04948  4.93531
# 2     3.26263  4.72216  ...  8.37838  7.52632  9.27417  3.78576  5.20193
# 3     3.09653  4.87362  ...  8.58629  6.52671  8.02195  3.52058  4.95737
# 4     3.35685  4.91996  ...  8.57463  7.27485  7.68393  3.47306  5.23711
# 5     3.16265  5.14418  ...  7.80586  7.94224  9.38534  3.29279  5.53094
# ...       ...      ...  ...      ...      ...      ...      ...      ...
# 1076  3.31857  4.56187  ...  8.47652  8.04813   8.2353   3.3059  4.74561
# 1077  2.98892  4.58681  ...  6.98386  7.97826  9.15039  3.97241  5.16608
# 1078      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 1079  3.35959  4.51172  ...  8.46731  8.19677  9.20568  3.51532  5.15234
# 1080  3.24774  4.54791  ...  7.72574  7.39858  8.78124  3.57496  5.30155
#
# 0      ZYG11A   ZYG11B      ZYX    ZZEF1     ZZZ3
# 1     2.74394  4.77964  4.70476   4.6623  8.80625
# 2     2.74257  4.63502  3.94019  4.65866  8.08867
# 3     2.63693  4.35012  4.39581  4.59858  7.95115
# 4     2.75974  5.51799  4.39196  4.15771  8.94488
# 5     2.58216  5.08715  5.19761  4.92217   7.4706
# ...       ...      ...      ...      ...      ...
# 1076  2.57763  5.21584  7.00354  4.20382  7.91928
# 1077  2.81345  5.11719  5.08564  4.91817  8.20834
# 1078      NaN      NaN      NaN      NaN      NaN
# 1079  2.47275  5.04678  6.01671  5.16818  7.06395
# 1080  3.04522  4.95208  4.60416    4.473   7.6756
#
# [1080 rows x 19563 columns]

# %%
gdsc_ge.to_csv('data/Processed/gdsc_cell_ge.csv', index=False)

# %%
# Out:
# 707

# %% [markdown]
# # Missing CCLE data

# %%
ccle_ge = pd.read_csv('data/CCLE/ge.csv', sep='\t').rename(columns={'Unnamed: 0':'CCL'}).set_index('CCL').transpose()
ccle_dr = pd.read_csv('data/CCLE/metrics.csv').rename(columns={'Cell_line':'CCL'})

# %%
poz = list(ccle_dr['CCL'].unique())
cell = list(ccle_ge.index.to_series().str.upper().reset_index()[0])

ncell = []
for i in cell:
    ncell.append(re.sub("[^A-Za-z0-9]", '', i))
cell = ncell

# %%
len(poz)
# Out:
# 504

# %%
miss = []
for ccl in poz:
    if ccl not in cell2:
        miss.append(ccl)
miss
# Out:
# ['BGC823',
#  'GLC82',
#  'KP1N',
#  'KP1NL',
#  'M059J',
#  'MB157',
#  'OVCAR3',
#  'SF8657',
#  'SNUC2B']

# %% [markdown]
# ### Now I substitute by the correct names

# %% [markdown]
# ### I look for the following 9 cell lines [here](https://www.expasy.org/) and find what the problem with them is.

# %% [markdown]
# BGC823, GLC82, KP1N and KP1NL are problematic (shown to be derivatives of HeLa and PANC-1) cell lines so I will drop them.
#
# MB157 and OVCAR3 are under different names, namely MDAMB157, NIH:OVCAR3
#
# _M059J_ wasn't found on cellminercdb, there is a M059K but idk if it's the same, maybe download M059J from [here](https://web.expasy.org/cellosaurus/CVCL_0400). It is on GDSC's cellminercdb dataset.
#
# _SF8657_ wasn't found,  can be downloaded from [here] (https://web.expasy.org/cellosaurus/CVCL_K085)
#
# _SNUC2B_ can't be found on this cellminercdb dataset but it is on GDSC's, here you find it under the alias SNUC2A according [to] (https://web.expasy.org/cellosaurus/CVCL_1710)

# %%
d = ccle_dr[~ccle_dr['CCL'].isin(['BGC823', 'GLC82', 'KP1N', 'KP1NL', 'M059J', 'SF8657', 'SNUC2B'])]

# %%
# Out:
# MB157
# OVCAR3

# %% [markdown]
# # Missing CTRP data

# %%
ctrp_ge = pd.read_csv('data/CTRP/cell_ge.csv', sep='\t').rename(columns={'Unnamed: 0':'CCL'}).set_index('CCL').transpose()
ctrp_dr = pd.read_csv('data/CTRP/metrics.csv').rename(columns={'Cell_line':'CCL'})

# %%
import re
poz = list(ctrp_dr['CCL'].unique())
cell3 = list(ctrp_ge.index.to_series().str.upper().reset_index()[0])

ncell = []
for i in cell3:
    ncell.append(re.sub("[^A-Za-z0-9]", '', i))
cell3 = ncell

# %%
miss = []
for ccl in poz:
    if ccl not in cell3:
        miss.append(ccl)
len(miss)
# Out:
# 66

# %%
miss
# Out:
# ['2004',
#  'ASKA',
#  'BT112',
#  'BT131',
#  'BT139',
#  'BT145',
#  'BT147',
#  'BT159',
#  'BT16',
#  'BT164',
#  'BT172',
#  'BT179',
#  'BT216',
#  'BT224',
#  'BT228',
#  'BT231',
#  'BT232',
#  'BT239',
#  'BT245',
#  'BT248',
#  'BT271',
#  'BT286',
#  'BT320',
#  'BT328',
#  'BT330',
#  'BT333',
#  'BT340',
#  'BT359',
#  'BT416',
#  'BT422',
#  'BT428',
#  'BT440',
#  'BT444',
#  'BT482',
#  'BT498',
#  'BT504',
#  'H292',
#  'HS578BST',
#  'HS888LU',
#  'HSTS',
#  'KRIJ',
#  'PSTS',
#  'SW982',
#  'SYO1',
#  'TM8716',
#  'TTTHYROID',
#  'UCH1',
#  'YAMATO',
#  'BT187']

# %%
cell3
# Out:
# ['CHP126',
#  'CHP212',
#  'IMR32',
#  'KELLY',
#  'KPNSI9S',
#  'KPNYN',
#  'MHHNB11',
#  'NB1',
#  'NH6',
#  'SIMA',
#  'SKNAS',
#  'SKNBE2',
#  'SKNDZ',
#  'SKNFI',
#  'SKNSH',
#  'HUCCT1',
#  'HUH28',
#  'SNU1079',
#  'SNU1196',
#  'SNU245',
#  'SNU308',
#  'SNU478',
#  'SNU869',
#  'A673',
#  'CADOES1',
#  'CAL78',
#  'G292CLONEA141B1',
#  'HOS',
#  'HS822T',
#  'HS888T',
#  'MG63',
#  'MHHES1',
#  'RDES',
#  'SAOS2',
#  'SJSA1',
#  'SKES1',
#  'SKNMC',
#  'SW1353',
#  'TC71',
#  'U2OS',
#  'AU565',
#  'BT20',
#  'BT474',
#  'BT549',
#  'CAL120',
#  'CAL148',
#  'CAL51',
#  'CAL851',
#  'CAMA1',
#  'DU4475',
#  'EFM192A',
#  'HCC1143',
#  'HCC1395',
#  'HCC1419',
#  'HCC1428',
#  'HCC1500',
#  'HCC1569',
#  'HCC1806',
#  'HCC1937',
#  'HCC1954',
#  'HCC202',
#  'HCC2218',
#  'HCC38',
#  'HDQP1',
#  'HMC18',
#  'HS578T',
#  'JIMT1',
#  'KPL1',
#  'MCF7',
#  'MDAMB157',
#  'MDAMB231',
#  'MDAMB361',
#  'MDAMB415',
#  'MDAMB453',
#  'MDAMB468',
#  'SKBR3',
#  'T47D',
#  'UACC812',
#  'ZR751',
#  'ZR7530',
#  '42MGBA',
#  '8MGBA',
#  'A172',
#  'AM38',
#  'BECKER',
#  'CAS1',
#  'CCFSTTG1',
#  'D283MED',
#  'DAOY',
#  'DBTRG05MG',
#  'DKMG',
#  'GAMG',
#  'GB1',
#  'GI1',
#  'GMS10',
#  'GOS3',
#  'HS683',
#  'KALS1',
#  'KG1C',
#  'KNS42',
#  'KNS60',
#  'KNS81',
#  'LN18',
#  'LN229',
#  'M059K',
#  'NMCG1',
#  'ONS76',
#  'SF126',
#  'SF295',
#  'SNU1105',
#  'SNU201',
#  'SNU466',
#  'SNU489',
#  'SNU626',
#  'SNU738',
#  'SW1088',
#  'SW1783',
#  'T98G',
#  'TM31',
#  'U118MG',
#  'U251MG',
#  'U87MG',
#  'YH13',
#  'YKG1',
#  'AN3CA',
#  'COLO684',
#  'EFE184',
#  'EN',
#  'ESS1',
#  'HEC108',
#  'HEC151',
#  'HEC1A',
#  'HEC1B',
#  'HEC251',
#  'HEC265',
#  'HEC50B',
#  'HEC59',
#  'HEC6',
#  'ISHIKAWAHERAKLIO02ER',
#  'JHUEM1',
#  'JHUEM2',
#  'JHUEM3',
#  'KLE',
#  'MFE296',
#  'MFE319',
#  'RL952',
#  'SNGM',
#  'SNU1077',
#  'SNU685',
#  '697',
#  'A3KAW',
#  'A4FUK',
#  'ALLSIL',
#  'AML193',
#  'AMO1',
#  'BCP1',
#  'BDCM',
#  'BL41',
#  'BL70',
#  'BV173',
#  'CA46',
#  'CI1',
#  'CMK',
#  'CMLT1',
#  'DAUDI',
#  'DB',
#  'DEL',
#  'DND41',
#  'DOHH2',
#  'EB1',
#  'EHEB',
#  'EJM',
#  'EM2',
#  'EOL1',
#  'F36P',
#  'GA10',
#  'GDM1',
#  'GRANTA519',
#  'HDLM2',
#  'HDMYZ',
#  'HEL',
#  'HEL9217',
#  'HH',
#  'HL60',
#  'HPBALL',
#  'HS611T',
#  'HT',
#  'HUNS1',
#  'HUT78',
#  'JEKO1',
#  'JJN3',
#  'JK1',
#  'JM1',
#  'JURKAT',
#  'JURLMK1',
#  'JVM2',
#  'JVM3',
#  'K562',
#  'KARPAS299',
#  'KARPAS422',
#  'KARPAS620',
#  'KASUMI1',
#  'KASUMI2',
#  'KCL22',
#  'KE37',
#  'KE97',
#  'KHM1B',
#  'KIJK',
#  'KMH2',
#  'KMM1',
#  'KMS11',
#  'KMS12BM',
#  'KMS18',
#  'KMS20',
#  'KMS21BM',
#  'KMS26',
#  'KMS27',
#  'KMS28BM',
#  'KMS34',
#  'KO52',
#  'KU812',
#  'KYO1',
#  'L1236',
#  'L363',
#  'L428',
#  'L540',
#  'LAMA84',
#  'LP1',
#  'M07E',
#  'MC116',
#  'ME1',
#  'MEC1',
#  'MHHCALL3',
#  'MHHCALL4',
#  'MINO',
#  'MJ',
#  'MM1S',
#  'MOLM13',
#  'MOLM16',
#  'MOLM6',
#  'MOLP2',
#  'MOLP8',
#  'MOLT13',
#  'MOLT16',
#  'MONOMAC1',
#  'MONOMAC6',
#  'MOTN1',
#  'MV411',
#  'NALM6',
#  'NAMALWA',
#  'NB4',
#  'NCIH929',
#  'NCO2',
#  'NOMO1',
#  'NUDHL1',
#  'NUDUL1',
#  'OCIAML2',
#  'OCIAML3',
#  'OCIAML5',
#  'OCILY10',
#  'OCILY19',
#  'OCILY3',
#  'OCIM1',
#  'OPM2',
#  'P12ICHIKAWA',
#  'P31FUJ',
#  'P3HR1',
#  'PEER',
#  'PF382',
#  'PFEIFFER',
#  'PL21',
#  'RAJI',
#  'RCHACV',
#  'REC1',
#  'REH',
#  'RI1',
#  'RL',
#  'RPMI8226',
#  'RPMI8402',
#  'RS411',
#  'SEM',
#  'SET2',
#  'SIGM5',
#  'SKM1',
#  'SKMM2',
#  'SR786',
#  'ST486',
#  'SUDHL1',
#  'SUDHL10',
#  'SUDHL4',
#  'SUDHL6',
#  'SUDHL8',
#  'SUPB15',
#  'SUPHD1',
#  'SUPM2',
#  'SUPT1',
#  'SUPT11',
#  'TALL1',
#  'TF1',
#  'THP1',
#  'TOLEDO',
#  'U266B1',
#  'U937',
#  'WSUDLCL2',
#  '769P',
#  '786O',
#  'A498',
#  'ACHN',
#  'BFTC909',
#  'CAKI1',
#  'CAKI2',
#  'CAL54',
#  'KMRC1',
#  'KMRC2',
#  'KMRC20',
#  'KMRC3',
#  'OSRC2',
#  'RCC10RGB',
#  'SNU1272',
#  'TUHR10TKB',
#  'TUHR14TKB',
#  'TUHR4TKB',
#  'VMRCRCW',
#  'VMRCRCZ',
#  'C2BBE1',
#  'CCK81',
#  'CL11',
#  'CL34',
#  'COLO201',
#  'COLO205',
#  'COLO320',
#  'COLO678',
#  'CW2',
#  'DLD1',
#  'GP2D',
#  'HCC56',
#  'HCT116',
#  'HCT15',
#  'HCT8',
#  'HT115',
#  'HT29',
#  'HT55',
#  'KM12',
#  'LOVO',
#  'LS1034',
#  'LS123',
#  'LS180',
#  'LS411N',
#  'LS513',
#  'MDST8',
#  'NCIH508',
#  'NCIH716',
#  'NCIH747',
#  'OUMS23',
#  'RCM1',
#  'RKO',
#  'SKCO1',
#  'SNU1033',
#  'SNU175',
#  'SNU407',
#  'SNU503',
#  'SNU61',
#  'SNU81',
#  'SNUC1',
#  'SNUC2A',
#  'SNUC4',
#  'SNUC5',
#  'SW1116',
#  'SW1417',
#  'SW1463',
#  'SW48',
#  'SW620',
#  'SW948',
#  'T84',
#  'HEP3B217',
#  'HEPG2',
#  'HLF',
#  'HUH1',
#  'HUH6',
#  'JHH1',
#  'JHH2',
#  'JHH4',
#  'JHH5',
#  'JHH6',
#  'LI7',
#  'PLCPRF5',
#  'SKHEP1',
#  'SNU182',
#  'SNU387',
#  'SNU398',
#  'SNU423',
#  'SNU449',
#  'SNU475',
#  'SNU761',
#  'SNU878',
#  'SNU886',
#  'A549',
#  'BEN',
#  'CAL12T',
#  'CALU1',
#  'CALU3',
#  'CALU6',
#  'CHAGOK1',
#  'COLO668',
#  'CORL105',
#  'CORL279',
#  'CORL47',
#  'CORL51',
#  'CORL88',
#  'CORL95',
#  'DMS114',
#  'DMS273',
#  'DMS454',
#  'DMS53',
#  'DMS79',
#  'DV90',
#  'EBC1',
#  'EPLC272H',
#  'HARA',
#  'HCC1171',
#  'HCC1195',
#  'HCC1438',
#  'HCC15',
#  'HCC1588',
#  'HCC1833',
#  'HCC2108',
#  'HCC2279',
#  'HCC2935',
#  'HCC33',
#  'HCC366',
#  'HCC4006',
#  'HCC44',
#  'HCC78',
#  'HCC827',
#  'HCC95',
#  'IALM',
#  'KNS62',
#  'LC1F',
#  'LC1SQSF',
#  'LCLC103H',
#  'LCLC97TM1',
#  'LK2',
#  'LOUNH91',
#  'LU65',
#  'LU99',
#  'LUDLU1',
#  'LXF289',
#  'MORCPR',
#  'NCIH1092',
#  'NCIH1105',
#  'NCIH1155',
#  'NCIH1184',
#  'NCIH1299',
#  'NCIH1339',
#  'NCIH1341',
#  'NCIH1355',
#  'NCIH1373',
#  'NCIH1385',
#  'NCIH1395',
#  'NCIH1435',
#  'NCIH146',
#  'NCIH1563',
#  'NCIH1568',
#  'NCIH1573',
#  'NCIH1581',
#  'NCIH1623',
#  'NCIH1650',
#  'NCIH1651',
#  'NCIH1666',
#  'NCIH1693',
#  'NCIH1694',
#  'NCIH1703',
#  'NCIH1734',
#  'NCIH1755',
#  'NCIH1792',
#  'NCIH1793',
#  'NCIH1838',
#  'NCIH1869',
#  'NCIH1915',
#  'NCIH1944',
#  'NCIH196',
#  'NCIH1975',
#  'NCIH2009',
#  'NCIH2023',
#  'NCIH2029',
#  'NCIH2030',
#  'NCIH2081',
#  'NCIH2085',
#  'NCIH2087',
#  'NCIH209',
#  'NCIH2106',
#  'NCIH211',
#  'NCIH2110',
#  'NCIH2122',
#  'NCIH2126',
#  'NCIH2141',
#  'NCIH2170',
#  'NCIH2171',
#  'NCIH2172',
#  'NCIH2196',
#  'NCIH2228',
#  'NCIH226',
#  'NCIH2286',
#  'NCIH2291',
#  'NCIH23',
#  'NCIH2342',
#  'NCIH2405',
#  'NCIH2444',
#  'NCIH292',
#  'NCIH322',
#  'NCIH358',
#  'NCIH441',
#  'NCIH446',
#  'NCIH460',
#  'NCIH510',
#  'NCIH520',
#  'NCIH522',
#  'NCIH524',
#  'NCIH526',
#  'NCIH647',
#  'NCIH650',
#  'NCIH661',
#  'NCIH69',
#  'NCIH727',
#  'NCIH810',
#  'NCIH838',
#  'NCIH841',
#  'NCIH889',
#  'PC14',
#  'RERFLCAD1',
#  'RERFLCAD2',
#  'RERFLCAI',
#  'RERFLCMS',
#  'SBC5',
#  'SCLC21H',
#  'SHP77',
#  'SKLU1',
#  'SKMES1',
#  'SQ1',
#  'SW1271',
#  'SW1573',
#  'T3M10',
#  'VMRCLCD',
#  'COLO680N',
#  'ECGI10',
#  'KYSE140',
#  'KYSE150',
#  'KYSE180',
#  'KYSE30',
#  'KYSE410',
#  'KYSE450',
#  'KYSE510',
#  'KYSE520',
#  'KYSE70',
#  'OE19',
#  'OE33',
#  'TE1',
#  'TE10',
#  'TE11',
#  'TE14',
#  'TE15',
#  'TE4',
#  'TE5',
#  'TE6',
#  'TE8',
#  'TE9',
#  'A2780',
#  'CAOV3',
#  'COV362',
#  'COV434',
#  'COV644',
#  'EFO21',
#  'EFO27',
#  'ES2',
#  'FUOV1',
#  'HEYA8',
#  'IGROV1',
#  'JHOC5',
#  'JHOM1',
#  'JHOS2',
#  'KURAMOCHI',
#  'MCAS',
#  'OAW28',
#  'OAW42',
#  'OC314',
#  'ONCODG1',
#  'OV56',
#  'OV7',
#  'OV90',
#  'OVCAR4',
#  'OVCAR8',
#  'OVISE',
#  'OVK18',
#  'OVSAHO',
#  'OVTOKO',
#  'RMGI',
#  'SKOV3',
#  'SNU119',
#  'SNU8',
#  'SNU840',
#  'TOV112D',
#  'TOV21G',
#  'TYKNU',
#  'ASPC1',
#  'BXPC3',
#  'CAPAN1',
#  'CAPAN2',
#  'CFPAC1',
#  'DANG',
#  'HPAC',
#  'HPAFII',
#  'HS766T',
#  'HUPT3',
#  'HUPT4',
#  'KP2',
#  'KP3',
#  'KP4',
#  'L33',
#  'MIAPACA2',
#  'PANC0203',
#  'PANC0327',
#  'PANC0403',
#  'PANC0504',
#  'PANC0813',
#  'PANC1',
#  'PANC1005',
#  'PATU8902',
#  'PATU8988S',
#  'PATU8988T',
#  'PK1',
#  'PK45H',
#  'PK59',
#  'PSN1',
#  'QGP1',
#  'SNU213',
#  'SNU410',
#  'SU8686',
#  'SUIT2',
#  'SW1990',
#  'TCCPAN2',
#  'YAPC',
#  'ACCMESO1',
#  'ISTMES1',
#  'JL1',
#  'MPP89',
#  'MSTO211H',
#  'NCIH2052',
#  'NCIH2452',
#  'NCIH28',
#  '22RV1',
#  'DU145',
#  'LNCAPCLONEFGC',
#  'NCIH660',
#  'PC3',
#  'VCAP',
#  'A253',
#  'YD15',
#  'A101D',
#  'A2058',
#  'A375',
#  'C32',
#  'CJM',
#  'COLO741',
#  'COLO792',
#  'COLO800',
#  'COLO829',
#  'G361',
#  'HMCB',
#  'HS294T',
#  'HS688AT',
#  'HS839T',
#  'HS852T',
#  'HS895T',
#  'HS934T',
#  'HS936T',
#  'HS940T',
#  'HS944T',
#  'HT144',
#  'IGR1',
#  'IGR37',
#  'IGR39',
#  'IPC298',
#  'K029AX',
#  'LOXIMVI',
#  'MALME3M',
#  'MDAMB435S',
#  'MELHO',
#  'MELJUSO',
#  'MEWO',
#  'RPMI7951',
#  'RVH421',
#  'SH4',
#  'SKMEL1',
#  'SKMEL2',
#  'SKMEL24',
#  'SKMEL28',
#  'SKMEL3',
#  'SKMEL30',
#  'SKMEL31',
#  'SKMEL5',
#  'UACC257',
#  'UACC62',
#  'WM115',
#  'WM1799',
#  'WM2664',
#  'WM793',
#  'WM88',
#  'WM983B',
#  'A204',
#  'G401',
#  'G402',
#  'GCT',
#  'HS729',
#  'HT1080',
#  'KYM1',
#  'MESSA',
#  'RD',
#  'RH18',
#  'RH30',
#  'RH41',
#  'RKN',
#  'SKLMS1',
#  'SKUT1',
#  'TE441T',
#  'TE617T',
#  '2313287',
#  'AGS',
#  'ECC10',
#  'ECC12',
#  'FU97',
#  'GSS',
#  'GSU',
#  'HGC27',
#  'HS746T',
#  'HUG1N',
#  'IM95',
#  'KATOIII',
#  'KE39',
#  'LMSU',
#  'MKN1',
#  'MKN45',
#  'MKN7',
#  'MKN74',
#  'NCCSTCK140',
#  'NCIN87',
#  'NUGC3',
#  'NUGC4',
#  'OCUM1',
#  'SH10TC',
#  'SNU1',
#  'SNU16',
#  'SNU216',
#  'SNU5',
#  'SNU601',
#  'SNU620',
#  'SNU668',
#  'SNU719',
#  '8305C',
#  '8505C',
#  'BCPAP',
#  'BHT101',
#  'CAL62',
#  'CGTHW1',
#  'FTC133',
#  'FTC238',
#  'ML1',
#  'SW579',
#  'TT',
#  'TT2609C02',
#  'BHY',
#  'BICR16',
#  'BICR18',
#  'BICR22',
#  'BICR31',
#  'BICR56',
#  'BICR6',
#  'CAL27',
#  'CAL33',
#  'DETROIT562',
#  'FADU',
#  'HSC2',
#  'HSC3',
#  'HSC4',
#  'PECAPJ15',
#  'PECAPJ34CLONEC12',
#  'PECAPJ41CLONED2',
#  'PECAPJ49',
#  'SCC25',
#  'SCC4',
#  'SCC9',
#  'SNU1041',
#  'SNU1066',
#  'SNU1076',
#  'SNU1214',
#  'SNU46',
#  'SNU899',
#  'YD10B',
#  'YD38',
#  'YD8',
#  '253J',
#  '253JBV',
#  '5637',
#  '639V',
#  '647V',
#  'BC3C',
#  'BFTC905',
#  'CAL29',
#  'HT1197',
#  'HT1376',
#  'J82',
#  'JMSU1',
#  'KMBC2',
#  'KU1919',
#  'RT112',
#  'RT4',
#  'SCABER',
#  'SW1710',
#  'T24',
#  'TCCSUP',
#  'UBLC1',
#  'UMUC1',
#  'UMUC3',
#  'VMCUB1']

# %% [markdown]
# ## It seems like the Pozdeyev data isn't too good regarding gene expression data, therefore I try to download the ctrp data directly

# %%
lo2 = pd.read_csv('data/ctrp2.csv', sep=';')

# %%
lo = lo2['ccl_name']

# %%
miss = []
for ccl in lo:
    if ccl not in cell2:
        miss.append(ccl)
len(miss)
# Out:
# 8

# %%
set(miss)
# Out:
# {'1\xa0MKN',
#  '45\xa0MKN',
#  '74\xa0MKN',
#  '7\xa0MCF',
#  '7\xa0MKN',
#  'H292',
#  'TTTHYROID'}

# %%
dif = ['MCF7', 'NCIH292', 'MKN74', 'MKN1', 'MKN45', 'MKN7', 'TT']
for i in set(miss):

# %%
g = pd.read_csv('data/CTRP/ctrp_g.csv', sep='\t')
g
# Out:
#      master_ccl_id  ccl_name                   ccle_primary_site  \
# 0                1       697  haematopoietic_and_lymphoid_tissue
# 1                3      5637                       urinary_tract
# 2                4   2313287                             stomach
# 3                7     22RV1                            prostate
# 4                8      253J                       urinary_tract
# ..             ...       ...                                 ...
# 830         155511  NCIH2291                                lung
# 831         155513  NCIH2342                                lung
# 832         155518  NCIH2405                                lung
# 833         155519  NCIH2444                                lung
# 834         155520  NCIH2452                              pleura
#
#      ccle_primary_hist                   ccle_hist_subtype_1
# 0    lymphoid_neoplasm  acute_lymphoblastic_B_cell_leukaemia
# 1            carcinoma                                   NaN
# 2            carcinoma                        adenocarcinoma
# 3            carcinoma                                   NaN
# 4            carcinoma           transitional_cell_carcinoma
# ..                 ...                                   ...
# 830          carcinoma                        adenocarcinoma
# 831          carcinoma                        adenocarcinoma
# 832          carcinoma                        adenocarcinoma
# 833          carcinoma              non_small_cell_carcinoma
# 834       mesothelioma                                   NaN
#
# [835 rows x 5 columns]

# %%
ge = pd.read_csv('data/CTRP/ctrp_ge.csv', sep='\t')

# %%
miss = []
for i in g['ccl_name'].unique():
    if i not in poz:
        miss.append(i)

print(len(miss))
# Out:
# 0

# %%
len(poz)
# Out:
# 887

# %%
len(g['ccl_name'].unique())
# Out:
# 835
