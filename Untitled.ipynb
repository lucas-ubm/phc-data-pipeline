# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
full = pd.read_csv('data/runs/full.csv').drop('Unnamed: 0', axis=1)
clean = full[full['Quality']>-0.95]
clean['started'] = pd.to_datetime(clean['started'])
clean = clean[clean['started'] > pd.to_datetime('2020-04-15 18:00:00')]
full['started'] = pd.to_datetime(full['started'])
full = full[full['started'] > pd.to_datetime('2020-04-15 18:00:00')]
# Out:
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
clean[['Drug', 'r2_score']].groupby('Drug').describe().sort_values(('r2_score', 'count'), ascending=False).head()
# Out:
#             r2_score                                                    \
#                count      mean       std       min       25%       50%
# Drug
# Selumetinib   3899.0  0.184667  0.179786 -0.586784 -0.000544  0.212642
# Nutlin-3      3898.0  0.042215  0.219847 -1.956753 -0.028994  0.009788
# Paclitaxel    3881.0  0.110028  0.158878 -0.866935 -0.005530  0.116330
# TAE684        3876.0  0.052642  0.164565 -0.742592 -0.023843  0.013251
# Saracatinib   3868.0  0.085891  0.154987 -1.412134 -0.009189  0.077140
#
#
#                   75%       max
# Drug
# Selumetinib  0.336339  0.598656
# Nutlin-3     0.128333  0.738862
# Paclitaxel   0.223688  0.479926
# TAE684       0.123273  0.693535
# Saracatinib  0.177243  0.586263

# %% [markdown]
# ## Model testing statsmodel

# %%
clean.columns
# Out:
# Index(['C', 'Drug', 'algorithm', 'alpha', 'bootstrap', 'cache_size', 'coef0',
#        'copy_X', 'criterion', 'degree', 'epsilon', 'fit_intercept', 'gamma',
#        'kernel', 'l1_ratio', 'leaf_size', 'max_depth', 'max_features',
#        'max_iter', 'max_leaf_nodes', 'mean_absolute_error',
#        'mean_squared_error', 'median_absolute_error', 'metric',
#        'metric_params', 'min_impurity_decrease', 'min_impurity_split',
#        'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf',
#        'n_estimators', 'n_jobs', 'n_neighbors', 'normalize', 'oob_score', 'p',
#        'positive', 'precompute', 'presort', 'r2_score', 'random_state', 'run',
#        'selection', 'shrinking', 'splitter', 'tol', 'verbose', 'warm_start',
#        'weights', 'operation', 'started', 'time', 'status', 'label', 'ajive',
#        'ccle', 'ctrp', 'cutoff', 'drugs', 'feda', 'fs', 'gdsc', 'metric_drug',
#        'model', 'n', 'norm', 'test', 'threshold', 'step', 'r_2_mean',
#        'r_2_std', 'seconds', 'datasets', 'Quality'],
#       dtype='object')

# %%
full_short = full[['Drug', 'r2_score', 'mean_squared_error', 'ajive', 'ccle', 'ctrp','gdsc', 'feda', 'fs', 'metric_drug', 'model', 'n', 'norm', 'datasets', 'Quality']]
short = clean[['Drug', 'r2_score', 'mean_squared_error', 'ajive', 'ccle', 'ctrp','gdsc', 'feda', 'fs', 'metric_drug', 'model', 'n', 'norm', 'datasets', 'Quality']]

# %%
d1 = short[short['Drug']=='Selumetinib'].drop('Drug', axis=1)

# %%
d1['ajive'] = d1['ajive'].fillna(0)
d1['norm'] = d1['norm'].fillna('None')

# %%
d1 = pd.get_dummies(d1, columns=['ajive', 'metric_drug', 'fs', 'model', 'norm', 'datasets'], drop_first=True)

# %%
d1 = d1.replace({True:1, False:0})

# %%
d1.head()
# Out:
#      r2_score  mean_squared_error  ccle  ctrp  gdsc  feda         n   Quality  \
# 15   0.304388            0.043233     0     1     1     0  0.100451 -0.538826
# 69   0.283115            0.050470     1     1     1     0  0.007475 -0.538826
# 108  0.098804            0.061326     1     0     0     1  0.089648 -0.303030
# 141  0.285679            0.049029     1     1     1     0  0.091667 -0.303030
# 156  0.313713            0.049590     1     1     0     0  0.075733 -0.538826
#
#      ajive_1.0  ajive_2.0  ...  model_ElasticNet  model_KNeighborsRegressor  \
# 15           0          0  ...                 1                          0
# 69           0          0  ...                 0                          0
# 108          0          0  ...                 0                          0
# 141          0          0  ...                 1                          0
# 156          0          0  ...                 0                          0
#
#      model_RandomForestRegressor  model_SVR  norm_MinMaxScaler  norm_None  \
# 15                             0          0                  0          0
# 69                             0          0                  1          0
# 108                            0          0                  0          0
# 141                            0          0                  1          0
# 156                            0          1                  1          0
#
#      norm_QuantileTransformer  norm_StandardScaler  datasets_2  datasets_3
# 15                          0                    1           1           0
# 69                          0                    0           0           1
# 108                         0                    1           0           0
# 141                         0                    0           0           1
# 156                         0                    0           1           0
#
# [5 rows x 27 columns]

# %%
X = d1.drop(['r2_score', 'mean_squared_error', 'ccle'], axis=1)
y = d1['r2_score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=X['Quality'])

# %% [markdown]
# # Statsmodel

# %%
import statsmodels.api as sm
mod = sm.OLS(y_train, X_train)
results = mod.fit()

# %%
results.summary2(alpha=0.01)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ============================================================================
# Model:                 OLS                 Adj. R-squared:        0.563
# Dependent Variable:    r2_score            AIC:                   -4107.1911
# Date:                  2020-05-18 11:01    BIC:                   -3963.6541
# No. Observations:      2924                Log-Likelihood:        2077.6
# Df Model:              23                  F-statistic:           164.9
# Df Residuals:          2900                Prob (F-statistic):    0.00
# R-squared:             0.567               Scale:                 0.014254
# ----------------------------------------------------------------------------
#                              Coef.  Std.Err.    t     P>|t|   [0.005  0.995]
# ----------------------------------------------------------------------------
# ctrp                         0.0353   0.0078   4.5262 0.0000  0.0152  0.0554
# gdsc                         0.0099   0.0072   1.3655 0.1722 -0.0088  0.0285
# feda                        -0.2425   0.0056 -43.3336 0.0000 -0.2569 -0.2281
# n                            0.1835   0.0397   4.6279 0.0000  0.0813  0.2857
# Quality                     -0.4912   0.0415 -11.8293 0.0000 -0.5982 -0.3841
# ajive_1.0                   -0.0186   0.0076  -2.4344 0.0150 -0.0382  0.0011
# ajive_2.0                   -0.0206   0.0073  -2.8171 0.0049 -0.0395 -0.0018
# ajive_3.0                   -0.0161   0.0075  -2.1516 0.0315 -0.0353  0.0032
# metric_drug_AUC_IC50        -0.1145   0.0118  -9.7340 0.0000 -0.1448 -0.0842
# fs_ElasticNet               -0.0267   0.0090  -2.9700 0.0030 -0.0499 -0.0035
# fs_Lasso                    -0.0215   0.0079  -2.7245 0.0065 -0.0418 -0.0012
# fs_RandomForestRegressor     0.0128   0.0084   1.5322 0.1256 -0.0088  0.0344
# fs_f_regression              0.0172   0.0079   2.1944 0.0283 -0.0030  0.0375
# fs_mutual_info_regression    0.0154   0.0081   1.9099 0.0562 -0.0054  0.0362
# model_ElasticNet             0.1665   0.0072  23.2303 0.0000  0.1481  0.1850
# model_KNeighborsRegressor    0.1972   0.0079  25.0045 0.0000  0.1768  0.2175
# model_RandomForestRegressor  0.1928   0.0074  25.9096 0.0000  0.1736  0.2120
# model_SVR                    0.2030   0.0076  26.8017 0.0000  0.1835  0.2226
# norm_MinMaxScaler            0.0131   0.0084   1.5583 0.1193 -0.0086  0.0348
# norm_None                    0.0193   0.0073   2.6287 0.0086  0.0004  0.0382
# norm_QuantileTransformer     0.0335   0.0086   3.9178 0.0001  0.0115  0.0556
# norm_StandardScaler         -0.0194   0.0085  -2.2685 0.0234 -0.0414  0.0026
# datasets_2                  -0.1023   0.0087 -11.7113 0.0000 -0.1249 -0.0798
# datasets_3                  -0.0888   0.0142  -6.2696 0.0000 -0.1253 -0.0523
# ----------------------------------------------------------------------------
# Omnibus:                 219.722          Durbin-Watson:             1.940
# Prob(Omnibus):           0.000            Jarque-Bera (JB):          971.841
# Skew:                    -0.220           Prob(JB):                  0.000
# Kurtosis:                5.790            Condition No.:             33
# ============================================================================
#
# """

# %%
coef = results.summary2(alpha=0.01).tables[1]

# %%
coef[coef['[0.005']*coef['0.995]'] > 0]
# Out:
#                                 Coef.  Std.Err.          t          P>|t|  \
# ctrp                         0.035298  0.007799   4.526211   6.246821e-06
# feda                        -0.242477  0.005596 -43.333578  9.331424e-317
# n                            0.183519  0.039655   4.627944   3.855281e-06
# Quality                     -0.491162  0.041521 -11.829347   1.446489e-31
# ajive_2.0                   -0.020621  0.007320  -2.817129   4.878296e-03
# metric_drug_AUC_IC50        -0.114507  0.011764  -9.733990   4.680323e-22
# fs_ElasticNet               -0.026732  0.009001  -2.969961   3.002809e-03
# fs_Lasso                    -0.021494  0.007889  -2.724459   6.479328e-03
# model_ElasticNet             0.166545  0.007169  23.230313  1.270584e-109
# model_KNeighborsRegressor    0.197165  0.007885  25.004515  3.995978e-125
# model_RandomForestRegressor  0.192801  0.007441  25.909614  2.573337e-133
# model_SVR                    0.203042  0.007576  26.801734  1.448521e-141
# norm_None                    0.019283  0.007335   2.628724   8.615806e-03
# norm_QuantileTransformer     0.033541  0.008561   3.917751   9.144226e-05
# datasets_2                  -0.102331  0.008738 -11.711255   5.502334e-31
# datasets_3                  -0.088763  0.014158  -6.269567   4.159058e-10
#
#                                [0.005    0.995]
# ctrp                         0.015197  0.055399
# feda                        -0.256900 -0.228054
# n                            0.081309  0.285730
# Quality                     -0.598182 -0.384141
# ajive_2.0                   -0.039487 -0.001754
# metric_drug_AUC_IC50        -0.144829 -0.084186
# fs_ElasticNet               -0.049931 -0.003532
# fs_Lasso                    -0.041830 -0.001159
# model_ElasticNet             0.148066  0.185024
# model_KNeighborsRegressor    0.176841  0.217489
# model_RandomForestRegressor  0.173621  0.211981
# model_SVR                    0.183515  0.222569
# norm_None                    0.000376  0.038190
# norm_QuantileTransformer     0.011474  0.055608
# datasets_2                  -0.124853 -0.079809
# datasets_3                  -0.125256 -0.052271

# %% [markdown]
# # Drug agnostic linear regression

# %%
d_r = clean[['Drug', 'r2_score']].groupby('Drug').mean()

# %%
clean['r2'] = [clean.loc[i]['r2_score']-d_r.loc[clean.loc[i]['Drug']]['r2_score'] for i in clean.index]

# %%
short2 = clean[['r2', 'mean_squared_error', 'ajive', 'ccle', 'ctrp','gdsc', 'feda', 'fs', 'metric_drug', 'model', 'n', 'norm', 'datasets', 'Quality']]

# %%
short2['ajive'] = short2['ajive'].fillna(0)
short2['norm'] = short2['norm'].fillna('None')
# Out:
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
short2 = pd.get_dummies(short2, columns=['ajive', 'metric_drug', 'fs', 'model', 'norm', 'datasets'], drop_first=True)

# %%
short2 = short2.replace({True:1, False:0})

# %%
from sklearn.model_selection import train_test_split
X = short2.drop(['r2', 'mean_squared_error', 'ccle'], axis=1)
y = short2['r2']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
import statsmodels.api as sm

mod = sm.OLS(y_train, X_train)
results = mod.fit()
results.summary2(alpha=0.01)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.089
# Dependent Variable:     r2               AIC:                         28410.5918
# Date:                   2020-05-18 13:15 BIC:                         28632.9275
# No. Observations:       77963            Log-Likelihood:              -14181.
# Df Model:               24               F-statistic:                 317.0
# Df Residuals:           77939            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.089            Scale:                       0.084266
# --------------------------------------------------------------------------------
#                                  Coef.  Std.Err.    t     P>|t|   [0.005  0.995]
# --------------------------------------------------------------------------------
# ctrp                             0.0104   0.0027   3.8740 0.0001  0.0035  0.0173
# gdsc                             0.0318   0.0025  12.5052 0.0000  0.0252  0.0383
# feda                            -0.1386   0.0026 -53.9748 0.0000 -0.1452 -0.1320
# n                               -0.0479   0.0175  -2.7353 0.0062 -0.0930 -0.0028
# Quality                          0.0008   0.0022   0.3785 0.7051 -0.0048  0.0065
# ajive_1.0                       -0.0235   0.0034  -6.8314 0.0000 -0.0324 -0.0147
# ajive_2.0                       -0.0345   0.0034 -10.2005 0.0000 -0.0433 -0.0258
# ajive_3.0                       -0.0250   0.0034  -7.4109 0.0000 -0.0337 -0.0163
# metric_drug_AUC_IC50            -0.0101   0.0021  -4.8764 0.0000 -0.0155 -0.0048
# fs_ElasticNet                   -0.0411   0.0038 -10.9427 0.0000 -0.0508 -0.0314
# fs_Lasso                        -0.0407   0.0033 -12.3026 0.0000 -0.0492 -0.0322
# fs_RandomForestRegressor        -0.0311   0.0037  -8.4942 0.0000 -0.0405 -0.0217
# fs_f_regression                 -0.0330   0.0034  -9.8533 0.0000 -0.0417 -0.0244
# fs_mutual_info_regression       -0.0230   0.0034  -6.6543 0.0000 -0.0318 -0.0141
# model_ElasticNet                 0.1366   0.0029  46.3408 0.0000  0.1290  0.1442
# model_KNeighborsRegressor        0.1436   0.0036  40.3697 0.0000  0.1344  0.1527
# model_RandomForestRegressor      0.1530   0.0032  48.0040 0.0000  0.1448  0.1612
# model_SVR                        0.0668   0.0033  20.5065 0.0000  0.0584  0.0751
# norm_MinMaxScaler               -0.0228   0.0037  -6.1377 0.0000 -0.0323 -0.0132
# norm_None                       -0.0303   0.0029 -10.3120 0.0000 -0.0378 -0.0227
# norm_QuantileTransformer        -0.0162   0.0038  -4.2210 0.0000 -0.0262 -0.0063
# norm_StandardScaler             -0.0650   0.0038 -17.0732 0.0000 -0.0748 -0.0552
# datasets_2                       0.0133   0.0028   4.8353 0.0000  0.0062  0.0204
# datasets_3                      -0.0005   0.0048  -0.0977 0.9222 -0.0128  0.0119
# --------------------------------------------------------------------------------
# Omnibus:               164934.748        Durbin-Watson:           1.993
# Prob(Omnibus):         0.000             Jarque-Bera (JB):        1902544416.743
# Skew:                  -18.111           Prob(JB):                0.000
# Kurtosis:              767.437           Condition No.:           24
# ================================================================================
#
# """

# %%
coef = results.summary2(alpha=0.01).tables[1]

# %%
coef[coef['[0.005']*coef['0.995]'] > 0]
# Out:
#                                 Coef.  Std.Err.          t         P>|t|  \
# ctrp                         0.010420  0.002690   3.874021  1.071417e-04
# gdsc                         0.031776  0.002541  12.505186  7.571022e-36
# feda                        -0.138610  0.002568 -53.974766  0.000000e+00
# n                           -0.047918  0.017519  -2.735268  6.234362e-03
# ajive_1.0                   -0.023523  0.003443  -6.831378  8.471731e-12
# ajive_2.0                   -0.034538  0.003386 -10.200467  2.044229e-24
# ajive_3.0                   -0.025032  0.003378  -7.410939  1.266709e-13
# metric_drug_AUC_IC50        -0.010124  0.002076  -4.876423  1.082389e-06
# fs_ElasticNet               -0.041124  0.003758 -10.942706  7.546173e-28
# fs_Lasso                    -0.040715  0.003309 -12.302584  9.449291e-35
# fs_RandomForestRegressor    -0.031095  0.003661  -8.494248  2.026644e-17
# fs_f_regression             -0.033033  0.003352  -9.853345  6.837593e-23
# fs_mutual_info_regression   -0.022954  0.003450  -6.654253  2.866197e-11
# model_ElasticNet             0.136599  0.002948  46.340768  0.000000e+00
# model_KNeighborsRegressor    0.143553  0.003556  40.369714  0.000000e+00
# model_RandomForestRegressor  0.153001  0.003187  48.004018  0.000000e+00
# model_SVR                    0.066752  0.003255  20.506533  3.321610e-93
# norm_MinMaxScaler           -0.022759  0.003708  -6.137750  8.410044e-10
# norm_None                   -0.030250  0.002933 -10.311992  6.453760e-25
# norm_QuantileTransformer    -0.016246  0.003849  -4.221038  2.434544e-05
# norm_StandardScaler         -0.065020  0.003808 -17.073243  3.087156e-65
# datasets_2                   0.013320  0.002755   4.835308  1.331927e-06
#
#                                [0.005    0.995]
# ctrp                         0.003491  0.017348
# gdsc                         0.025231  0.038321
# feda                        -0.145225 -0.131995
# n                           -0.093045 -0.002792
# ajive_1.0                   -0.032392 -0.014653
# ajive_2.0                   -0.043259 -0.025816
# ajive_3.0                   -0.033733 -0.016332
# metric_drug_AUC_IC50        -0.015472 -0.004776
# fs_ElasticNet               -0.050805 -0.031443
# fs_Lasso                    -0.049239 -0.032190
# fs_RandomForestRegressor    -0.040524 -0.021665
# fs_f_regression             -0.041669 -0.024398
# fs_mutual_info_regression   -0.031840 -0.014069
# model_ElasticNet             0.129006  0.144192
# model_KNeighborsRegressor    0.134393  0.152712
# model_RandomForestRegressor  0.144791  0.161211
# model_SVR                    0.058367  0.075137
# norm_MinMaxScaler           -0.032310 -0.013207
# norm_None                   -0.037806 -0.022694
# norm_QuantileTransformer    -0.026160 -0.006332
# norm_StandardScaler         -0.074830 -0.055210
# datasets_2                   0.006224  0.020416

# %%
drug = clean[['Drug', 'r2_score']].groupby('Drug').describe()

# %%
drug[drug['r2_score']['count']>500]
# Out:
#              r2_score                                                     \
#                 count      mean       std        min       25%       50%
# Drug
# 17-AAG         3820.0  0.149062  0.204046  -1.233983 -0.005183  0.121713
# AZD6482         525.0  0.172120  0.181320  -0.394806  0.002931  0.148892
# Crizotinib     3818.0  0.092328  0.254007  -1.981364 -0.021931  0.029392
# Erlotinib      3828.0  0.109429  0.155873  -2.658171 -0.001731  0.129111
# L-685458       1767.0  0.019427  0.198321  -1.526681 -0.034600  0.054149
# Lapatinib      3860.0  0.129062  0.170416  -1.513676 -0.001295  0.143291
# Nilotinib      3840.0  0.035936  0.205081  -2.772547 -0.020709  0.040809
# Nutlin-3       3898.0  0.042215  0.219847  -1.956753 -0.028994  0.009788
# PD-0325901     1787.0  0.236564  0.186792  -0.556175  0.061156  0.272517
# PD-0332991     1808.0  0.098914  0.129332  -0.834617 -0.000865  0.115319
# PHA-665752      824.0 -0.010676  0.241737  -5.091912 -0.042943  0.019949
# PLX-4720       3851.0  0.145333  0.183962  -2.233266 -0.001769  0.183089
# Paclitaxel     3881.0  0.110028  0.158878  -0.866935 -0.005530  0.116330
# Panobinostat   1728.0 -0.522939  1.591837 -21.885501 -0.226227 -0.025829
# RAF265         1770.0  0.021966  0.108032  -0.705000 -0.032225  0.029227
# Saracatinib    3868.0  0.085891  0.154987  -1.412134 -0.009189  0.077140
# Selumetinib    3899.0  0.184667  0.179786  -0.586784 -0.000544  0.212642
# Sorafenib      3852.0  0.011322  0.175856  -1.252390 -0.037522 -0.000087
# TAE684         3876.0  0.052642  0.164565  -0.742592 -0.023843  0.013251
# TGX-221         518.0  0.171164  0.177139  -0.466879  0.015467  0.206224
# Topotecan      1734.0  0.121338  0.148140  -0.608673 -0.000216  0.138359
# Vandetanib     1717.0  0.019512  0.107865  -0.947217 -0.026943  0.028828
#
#
#                    75%       max
# Drug
# 17-AAG        0.316266  0.638431
# AZD6482       0.342191  0.528133
# Crizotinib    0.211760  0.930501
# Erlotinib     0.215468  0.496865
# L-685458      0.147266  0.405178
# Lapatinib     0.255716  0.533728
# Nilotinib     0.143889  0.455090
# Nutlin-3      0.128333  0.738862
# PD-0325901    0.389743  0.606141
# PD-0332991    0.199632  0.412602
# PHA-665752    0.089457  0.244161
# PLX-4720      0.285883  0.536622
# Paclitaxel    0.223688  0.479926
# Panobinostat  0.017534  0.301424
# RAF265        0.093184  0.292388
# Saracatinib   0.177243  0.586263
# Selumetinib   0.336339  0.598656
# Sorafenib     0.114616  0.438296
# TAE684        0.123273  0.693535
# TGX-221       0.315866  0.456370
# Topotecan     0.231109  0.431786
# Vandetanib    0.091257  0.262556
