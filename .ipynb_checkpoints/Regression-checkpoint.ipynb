# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
full = pd.read_csv('data/runs/full.csv').drop('Unnamed: 0', axis=1)
clean = full[full['Quality']>-0.95]
clean['started'] = pd.to_datetime(clean['started'])
clean = clean[clean['started'] > pd.to_datetime('2020-04-15 18:00:00')]
full['started'] = pd.to_datetime(full['started'])
full = full[full['started'] > pd.to_datetime('2020-04-15 18:00:00')]
# Out:
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
clean = pd.read_csv('data/runs/clean.csv')

# %%
clean[['Drug', 'r2_score']].groupby('Drug').describe().sort_values(('r2_score', 'count'), ascending=False).head()
# Out:
#             r2_score                                                    \
#                count      mean       std       min       25%       50%
# Drug
# Selumetinib   4512.0  0.189548  0.177463 -0.586784  0.003512  0.215650
# Nutlin-3      4480.0  0.042574  0.222276 -1.956753 -0.029524  0.013063
# Paclitaxel    4479.0  0.114114  0.157428 -0.866935 -0.003286  0.121838
# Saracatinib   4452.0  0.089953  0.155960 -1.412134 -0.006891  0.083961
# TAE684        4451.0  0.054032  0.166655 -0.774732 -0.022764  0.016381
#
#
#                   75%       max
# Drug
# Selumetinib  0.337072  0.598656
# Nutlin-3     0.129311  0.738862
# Paclitaxel   0.223766  0.479926
# Saracatinib  0.181256  0.586263
# TAE684       0.126441  0.693535

# %% [markdown]
# ## Model testing statsmodel

# %%
clean.columns
# Out:
# Index(['C', 'Drug', 'algorithm', 'alpha', 'bootstrap', 'cache_size', 'coef0',
#        'copy_X', 'criterion', 'degree', 'epsilon', 'fit_intercept', 'gamma',
#        'kernel', 'l1_ratio', 'leaf_size', 'max_depth', 'max_features',
#        'max_iter', 'max_leaf_nodes', 'mean_absolute_error',
#        'mean_squared_error', 'median_absolute_error', 'metric',
#        'metric_params', 'min_impurity_decrease', 'min_impurity_split',
#        'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf',
#        'n_estimators', 'n_jobs', 'n_neighbors', 'normalize', 'oob_score', 'p',
#        'positive', 'precompute', 'presort', 'r2_score', 'random_state', 'run',
#        'selection', 'shrinking', 'splitter', 'tol', 'verbose', 'warm_start',
#        'weights', 'operation', 'started', 'time', 'status', 'label', 'ajive',
#        'ccle', 'ctrp', 'cutoff', 'drugs', 'feda', 'fs', 'gdsc', 'metric_drug',
#        'model', 'n', 'norm', 'test', 'threshold', 'step', 'r_2_mean',
#        'r_2_std', 'seconds', 'datasets', 'Quality'],
#       dtype='object')

# %%
full_short = full[['Drug', 'r2_score', 'mean_squared_error', 'ajive', 'ccle', 'ctrp','gdsc', 'feda', 'fs', 'metric_drug', 'model', 'n', 'norm', 'datasets', 'Quality']]
short = clean[['Drug', 'r2_score', 'mean_squared_error', 'ajive', 'ccle', 'ctrp','gdsc', 'feda', 'fs', 'metric_drug', 'model', 'n', 'norm', 'datasets', 'Quality']]

# %%
d1 = short[short['Drug']=='Selumetinib'].drop('Drug', axis=1)

# %%
d1['ajive'] = d1['ajive'].fillna(0)
d1['norm'] = d1['norm'].fillna('None')

# %%
d1 = pd.get_dummies(d1, columns=['ajive', 'metric_drug', 'fs', 'model', 'norm', 'datasets'], drop_first=True)

# %%
d1 = d1.replace({True:1, False:0})

# %%
d1.head()
# Out:
#      r2_score  mean_squared_error  ccle  ctrp  gdsc  feda         n   Quality  \
# 15   0.304388            0.043233     0     1     1     0  0.100451 -0.538826
# 69   0.283115            0.050470     1     1     1     0  0.007475 -0.538826
# 108  0.098804            0.061326     1     0     0     1  0.089648 -0.303030
# 141  0.285679            0.049029     1     1     1     0  0.091667 -0.303030
# 156  0.313713            0.049590     1     1     0     0  0.075733 -0.538826
#
#      ajive_1.0  ajive_2.0  ...  model_ElasticNet  model_KNeighborsRegressor  \
# 15           0          0  ...                 1                          0
# 69           0          0  ...                 0                          0
# 108          0          0  ...                 0                          0
# 141          0          0  ...                 1                          0
# 156          0          0  ...                 0                          0
#
#      model_RandomForestRegressor  model_SVR  norm_MinMaxScaler  norm_None  \
# 15                             0          0                  0          0
# 69                             0          0                  1          0
# 108                            0          0                  0          0
# 141                            0          0                  1          0
# 156                            0          1                  1          0
#
#      norm_QuantileTransformer  norm_StandardScaler  datasets_2  datasets_3
# 15                          0                    1           1           0
# 69                          0                    0           0           1
# 108                         0                    1           0           0
# 141                         0                    0           0           1
# 156                         0                    0           1           0
#
# [5 rows x 27 columns]

# %%
X = d1.drop(['r2_score', 'mean_squared_error', 'ccle'], axis=1)
y = d1['r2_score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=X['Quality'])

# %% [markdown]
# # Statsmodel

# %%
import statsmodels.api as sm
mod = sm.OLS(y_train, X_train)
results = mod.fit()

# %%
results.summary2(alpha=0.01)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ============================================================================
# Model:                 OLS                 Adj. R-squared:        0.550
# Dependent Variable:    r2_score            AIC:                   -4745.7849
# Date:                  2020-05-19 13:32    BIC:                   -4598.7414
# No. Observations:      3384                Log-Likelihood:        2396.9
# Df Model:              23                  F-statistic:           181.0
# Df Residuals:          3360                Prob (F-statistic):    0.00
# R-squared:             0.553               Scale:                 0.014302
# ----------------------------------------------------------------------------
#                              Coef.  Std.Err.    t     P>|t|   [0.005  0.995]
# ----------------------------------------------------------------------------
# ctrp                         0.0370   0.0074   5.0101 0.0000  0.0180  0.0560
# gdsc                         0.0066   0.0068   0.9661 0.3341 -0.0109  0.0241
# feda                        -0.2434   0.0055 -44.0291 0.0000 -0.2576 -0.2291
# n                            0.1779   0.0371   4.8000 0.0000  0.0824  0.2735
# Quality                     -0.4325   0.0388 -11.1384 0.0000 -0.5326 -0.3324
# ajive_1.0                   -0.0224   0.0068  -3.3189 0.0009 -0.0399 -0.0050
# ajive_2.0                   -0.0285   0.0065  -4.4065 0.0000 -0.0452 -0.0118
# ajive_3.0                   -0.0227   0.0067  -3.3615 0.0008 -0.0401 -0.0053
# metric_drug_AUC_IC50        -0.0974   0.0109  -8.9346 0.0000 -0.1255 -0.0693
# fs_ElasticNet               -0.0180   0.0084  -2.1385 0.0325 -0.0396  0.0037
# fs_Lasso                    -0.0192   0.0073  -2.6261 0.0087 -0.0380 -0.0004
# fs_RandomForestRegressor     0.0120   0.0079   1.5242 0.1275 -0.0083  0.0322
# fs_f_regression              0.0288   0.0073   3.9341 0.0001  0.0099  0.0476
# fs_mutual_info_regression    0.0239   0.0074   3.2113 0.0013  0.0047  0.0430
# model_ElasticNet             0.1750   0.0068  25.6769 0.0000  0.1574  0.1925
# model_KNeighborsRegressor    0.2037   0.0075  27.2484 0.0000  0.1844  0.2230
# model_RandomForestRegressor  0.1999   0.0070  28.7366 0.0000  0.1820  0.2178
# model_SVR                    0.2136   0.0072  29.6117 0.0000  0.1950  0.2322
# norm_MinMaxScaler            0.0052   0.0078   0.6661 0.5054 -0.0149  0.0253
# norm_None                    0.0069   0.0069   0.9917 0.3214 -0.0110  0.0247
# norm_QuantileTransformer     0.0325   0.0080   4.0847 0.0000  0.0120  0.0530
# norm_StandardScaler         -0.0310   0.0078  -3.9578 0.0001 -0.0512 -0.0108
# datasets_2                  -0.0821   0.0081 -10.1675 0.0000 -0.1030 -0.0613
# datasets_3                  -0.0673   0.0133  -5.0678 0.0000 -0.1016 -0.0331
# ----------------------------------------------------------------------------
# Omnibus:                264.082          Durbin-Watson:             2.012
# Prob(Omnibus):          0.000            Jarque-Bera (JB):          1284.967
# Skew:                   -0.195           Prob(JB):                  0.000
# Kurtosis:               5.993            Condition No.:             33
# ============================================================================
#
# """

# %%
coef = results.summary2(alpha=0.01).tables[1]

# %%
coef[coef['[0.005']*coef['0.995]'] > 0]
# Out:
#                                 Coef.  Std.Err.          t          P>|t|  \
# ctrp                         0.036978  0.007381   5.010119   5.720316e-07
# feda                        -0.243352  0.005527 -44.029060   0.000000e+00
# n                            0.177926  0.037068   4.799953   1.656224e-06
# Quality                     -0.432489  0.038828 -11.138439   2.538932e-28
# ajive_1.0                   -0.022443  0.006762  -3.318919   9.132977e-04
# ajive_2.0                   -0.028542  0.006477  -4.406500   1.083377e-05
# ajive_3.0                   -0.022670  0.006744  -3.361536   7.837670e-04
# metric_drug_AUC_IC50        -0.097381  0.010899  -8.934630   6.592040e-19
# fs_Lasso                    -0.019167  0.007298  -2.626133   8.675282e-03
# fs_f_regression              0.028760  0.007310   3.934062   8.521097e-05
# fs_mutual_info_regression    0.023877  0.007435   3.211284   1.333897e-03
# model_ElasticNet             0.174955  0.006814  25.676867  6.421186e-133
# model_KNeighborsRegressor    0.203687  0.007475  27.248410  6.950035e-148
# model_RandomForestRegressor  0.199915  0.006957  28.736608  1.425941e-162
# model_SVR                    0.213581  0.007213  29.611669  1.984897e-171
# norm_QuantileTransformer     0.032483  0.007952   4.084691   4.516564e-05
# norm_StandardScaler         -0.031007  0.007834  -3.957837   7.719619e-05
# datasets_2                  -0.082131  0.008078 -10.167537   6.125800e-24
# datasets_3                  -0.067337  0.013287  -5.067832   4.240952e-07
#
#                                [0.005    0.995]
# ctrp                         0.017956  0.056000
# feda                        -0.257596 -0.229107
# n                            0.082390  0.273461
# Quality                     -0.532561 -0.332416
# ajive_1.0                   -0.039871 -0.005015
# ajive_2.0                   -0.045237 -0.011848
# ajive_3.0                   -0.040051 -0.005289
# metric_drug_AUC_IC50        -0.125472 -0.069291
# fs_Lasso                    -0.037977 -0.000356
# fs_f_regression              0.009919  0.047601
# fs_mutual_info_regression    0.004714  0.043041
# model_ElasticNet             0.157394  0.192516
# model_KNeighborsRegressor    0.184422  0.222953
# model_RandomForestRegressor  0.181985  0.217845
# model_SVR                    0.194992  0.232171
# norm_QuantileTransformer     0.011987  0.052978
# norm_StandardScaler         -0.051198 -0.010816
# datasets_2                  -0.102950 -0.061313
# datasets_3                  -0.101581 -0.033092

# %% [markdown]
# # Drug agnostic linear regression

# %%
d_r = clean[['Drug', 'r2_score']].groupby('Drug').mean()

# %%
clean = pd.read_csv('data/runs/clean.csv')

# %%
short2 = clean[['r2', 'mean_squared_error', 'ajive', 'ccle', 'ctrp','gdsc', 'feda', 'fs', 'metric_drug', 'model', 'n', 'norm', 'datasets', 'Quality']]

# %%
short2['ajive'] = short2['ajive'].fillna(0)
short2['norm'] = short2['norm'].fillna('None')
# Out:
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
short2 = pd.get_dummies(short2, columns=['ajive', 'metric_drug', 'fs', 'model', 'norm', 'datasets'], drop_first=True)

# %%
short2 = short2.replace({True:1, False:0})

# %%
from sklearn.model_selection import train_test_split
X = short2.drop(['r2', 'mean_squared_error', 'ccle'], axis=1)
y = short2['r2']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
import statsmodels.api as sm

mod = sm.OLS(y_train, X_train)
results = mod.fit()
results.summary2(alpha=0.01)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.090
# Dependent Variable:     r2               AIC:                         34798.9592
# Date:                   2020-05-19 13:33 BIC:                         35024.7015
# No. Observations:       89853            Log-Likelihood:              -17375.
# Df Model:               24               F-statistic:                 373.1
# Df Residuals:           89829            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.091            Scale:                       0.086220
# --------------------------------------------------------------------------------
#                                  Coef.  Std.Err.    t     P>|t|   [0.005  0.995]
# --------------------------------------------------------------------------------
# ctrp                             0.0094   0.0025   3.6867 0.0002  0.0028  0.0159
# gdsc                             0.0350   0.0024  14.5832 0.0000  0.0288  0.0412
# feda                            -0.1434   0.0026 -55.9328 0.0000 -0.1500 -0.1368
# n                               -0.0429   0.0165  -2.5944 0.0095 -0.0854 -0.0003
# Quality                          0.0038   0.0021   1.8447 0.0651 -0.0015  0.0091
# ajive_1.0                       -0.0256   0.0031  -8.3248 0.0000 -0.0335 -0.0177
# ajive_2.0                       -0.0351   0.0030 -11.5331 0.0000 -0.0430 -0.0273
# ajive_3.0                       -0.0275   0.0031  -8.9597 0.0000 -0.0354 -0.0196
# metric_drug_AUC_IC50            -0.0103   0.0020  -5.2717 0.0000 -0.0154 -0.0053
# fs_ElasticNet                   -0.0420   0.0035 -11.8243 0.0000 -0.0511 -0.0328
# fs_Lasso                        -0.0398   0.0032 -12.6291 0.0000 -0.0479 -0.0317
# fs_RandomForestRegressor        -0.0327   0.0034  -9.4769 0.0000 -0.0415 -0.0238
# fs_f_regression                 -0.0348   0.0032 -10.9236 0.0000 -0.0430 -0.0266
# fs_mutual_info_regression       -0.0255   0.0033  -7.7902 0.0000 -0.0339 -0.0170
# model_ElasticNet                 0.1363   0.0028  48.2829 0.0000  0.1291  0.1436
# model_KNeighborsRegressor        0.1493   0.0034  44.4904 0.0000  0.1407  0.1580
# model_RandomForestRegressor      0.1554   0.0030  51.0958 0.0000  0.1476  0.1633
# model_SVR                        0.0681   0.0031  21.7584 0.0000  0.0600  0.0761
# norm_MinMaxScaler               -0.0223   0.0035  -6.3434 0.0000 -0.0313 -0.0132
# norm_None                       -0.0359   0.0028 -12.8307 0.0000 -0.0432 -0.0287
# norm_QuantileTransformer        -0.0169   0.0036  -4.6610 0.0000 -0.0262 -0.0076
# norm_StandardScaler             -0.0656   0.0036 -18.2727 0.0000 -0.0748 -0.0563
# datasets_2                       0.0178   0.0026   6.8778 0.0000  0.0112  0.0245
# datasets_3                       0.0044   0.0045   0.9759 0.3291 -0.0072  0.0160
# --------------------------------------------------------------------------------
# Omnibus:               200888.931        Durbin-Watson:           1.989
# Prob(Omnibus):         0.000             Jarque-Bera (JB):        3450814729.869
# Skew:                  -20.593           Prob(JB):                0.000
# Kurtosis:              962.180           Condition No.:           24
# ================================================================================
#
# """

# %%
coef = results.summary2(alpha=0.01).tables[1]

# %%
coef[coef['[0.005']*coef['0.995]'] > 0]
# Out:
#                                 Coef.  Std.Err.          t          P>|t|  \
# ctrp                         0.009356  0.002538   3.686730   2.272874e-04
# gdsc                         0.035022  0.002402  14.583186   4.079504e-48
# feda                        -0.143384  0.002563 -55.932831   0.000000e+00
# n                           -0.042861  0.016521  -2.594352   9.478481e-03
# ajive_1.0                   -0.025581  0.003073  -8.324775   8.565813e-17
# ajive_2.0                   -0.035137  0.003047 -11.533106   9.444174e-31
# ajive_3.0                   -0.027457  0.003064  -8.959699   3.316017e-19
# metric_drug_AUC_IC50        -0.010341  0.001962  -5.271708   1.354714e-07
# fs_ElasticNet               -0.041950  0.003548 -11.824267   3.090158e-32
# fs_Lasso                    -0.039797  0.003151 -12.629075   1.568192e-36
# fs_RandomForestRegressor    -0.032667  0.003447  -9.476933   2.679406e-21
# fs_f_regression             -0.034774  0.003183 -10.923631   9.252110e-28
# fs_mutual_info_regression   -0.025471  0.003270  -7.790177   6.762690e-15
# model_ElasticNet             0.136327  0.002824  48.282879   0.000000e+00
# model_KNeighborsRegressor    0.149334  0.003357  44.490445   0.000000e+00
# model_RandomForestRegressor  0.155433  0.003042  51.095778   0.000000e+00
# model_SVR                    0.068063  0.003128  21.758413  1.073498e-104
# norm_MinMaxScaler           -0.022264  0.003510  -6.343358   2.258749e-10
# norm_None                   -0.035938  0.002801 -12.830736   1.190516e-37
# norm_QuantileTransformer    -0.016906  0.003627  -4.660963   3.151845e-06
# norm_StandardScaler         -0.065554  0.003588 -18.272733   1.862803e-74
# datasets_2                   0.017838  0.002594   6.877764   6.119474e-12
#
#                                [0.005    0.995]
# ctrp                         0.002819  0.015892
# gdsc                         0.028836  0.041208
# feda                        -0.149987 -0.136780
# n                           -0.085416 -0.000305
# ajive_1.0                   -0.033497 -0.017666
# ajive_2.0                   -0.042985 -0.027289
# ajive_3.0                   -0.035350 -0.019563
# metric_drug_AUC_IC50        -0.015394 -0.005288
# fs_ElasticNet               -0.051089 -0.032812
# fs_Lasso                    -0.047915 -0.031680
# fs_RandomForestRegressor    -0.041546 -0.023788
# fs_f_regression             -0.042974 -0.026574
# fs_mutual_info_regression   -0.033893 -0.017048
# model_ElasticNet             0.129054  0.143600
# model_KNeighborsRegressor    0.140688  0.157980
# model_RandomForestRegressor  0.147597  0.163269
# model_SVR                    0.060005  0.076120
# norm_MinMaxScaler           -0.031305 -0.013223
# norm_None                   -0.043152 -0.028723
# norm_QuantileTransformer    -0.026248 -0.007563
# norm_StandardScaler         -0.074795 -0.056313
# datasets_2                   0.011157  0.024518

# %%
a = clean[['model', 'fs', 'r2']].groupby(['model', 'fs']).describe()
a.index.to_flat_index()
clean['fsmodel'] = clean['fs']+clean['model']

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
m_comp = pairwise_tukeyhsd(endog=clean['r2'], groups=clean['fsmodel'], alpha=0.05)
# Out:
#                                      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================================================================================
#                    group1                                      group2                   meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------------------------------------------
#             DecisionTreeRegressorElasticNet    DecisionTreeRegressorKNeighborsRegressor   0.0052    0.9 -0.0201  0.0305  False
#             DecisionTreeRegressorElasticNet  DecisionTreeRegressorRandomForestRegressor  -0.0069    0.9 -0.0281  0.0144  False
#             DecisionTreeRegressorElasticNet                    DecisionTreeRegressorSVR  -0.1024  0.001  -0.127 -0.0778   True
#             DecisionTreeRegressorElasticNet             ElasticNetDecisionTreeRegressor  -0.1662  0.001 -0.1839 -0.1486   True
#             DecisionTreeRegressorElasticNet               ElasticNetKNeighborsRegressor  -0.0006    0.9 -0.0265  0.0252  False
#             DecisionTreeRegressorElasticNet             ElasticNetRandomForestRegressor    0.002    0.9 -0.0203  0.0243  False
#             DecisionTreeRegressorElasticNet                               ElasticNetSVR  -0.0796  0.001 -0.1012  -0.058   True
#             DecisionTreeRegressorElasticNet                  LassoDecisionTreeRegressor  -0.1656  0.001 -0.1836 -0.1476   True
#             DecisionTreeRegressorElasticNet                             LassoElasticNet  -0.0103    0.9 -0.0279  0.0074  False
#             DecisionTreeRegressorElasticNet                    LassoKNeighborsRegressor  -0.0119    0.9  -0.037  0.0132  False
#             DecisionTreeRegressorElasticNet                  LassoRandomForestRegressor   0.0065    0.9 -0.0142  0.0271  False
#             DecisionTreeRegressorElasticNet                                    LassoSVR  -0.0856  0.001 -0.1086 -0.0627   True
#             DecisionTreeRegressorElasticNet  RandomForestRegressorDecisionTreeRegressor  -0.1673  0.001 -0.1857 -0.1488   True
#             DecisionTreeRegressorElasticNet             RandomForestRegressorElasticNet   0.0001    0.9 -0.0175  0.0177  False
#             DecisionTreeRegressorElasticNet    RandomForestRegressorKNeighborsRegressor   0.0036    0.9  -0.025  0.0322  False
#             DecisionTreeRegressorElasticNet                    RandomForestRegressorSVR  -0.0743  0.001  -0.098 -0.0506   True
#             DecisionTreeRegressorElasticNet           f_regressionDecisionTreeRegressor  -0.1652  0.001 -0.1835 -0.1469   True
#             DecisionTreeRegressorElasticNet                      f_regressionElasticNet  -0.0086    0.9 -0.0263   0.009  False
#             DecisionTreeRegressorElasticNet             f_regressionKNeighborsRegressor  -0.0006    0.9 -0.0252  0.0241  False
#             DecisionTreeRegressorElasticNet           f_regressionRandomForestRegressor   0.0255 0.0021  0.0045  0.0465   True
#             DecisionTreeRegressorElasticNet                             f_regressionSVR  -0.0967  0.001 -0.1207 -0.0727   True
#             DecisionTreeRegressorElasticNet mutual_info_regressionDecisionTreeRegressor  -0.1514  0.001   -0.17 -0.1328   True
#             DecisionTreeRegressorElasticNet            mutual_info_regressionElasticNet   0.0021    0.9 -0.0159    0.02  False
#             DecisionTreeRegressorElasticNet   mutual_info_regressionKNeighborsRegressor   0.0186 0.6629 -0.0083  0.0455  False
#             DecisionTreeRegressorElasticNet mutual_info_regressionRandomForestRegressor   0.0322  0.001  0.0104  0.0541   True
#             DecisionTreeRegressorElasticNet                   mutual_info_regressionSVR  -0.0524  0.001 -0.0762 -0.0286   True
#    DecisionTreeRegressorKNeighborsRegressor  DecisionTreeRegressorRandomForestRegressor  -0.0121    0.9 -0.0401  0.0159  False
#    DecisionTreeRegressorKNeighborsRegressor                    DecisionTreeRegressorSVR  -0.1076  0.001 -0.1382  -0.077   True
#    DecisionTreeRegressorKNeighborsRegressor             ElasticNetDecisionTreeRegressor  -0.1714  0.001 -0.1968  -0.146   True
#    DecisionTreeRegressorKNeighborsRegressor               ElasticNetKNeighborsRegressor  -0.0058    0.9 -0.0374  0.0259  False
#    DecisionTreeRegressorKNeighborsRegressor             ElasticNetRandomForestRegressor  -0.0032    0.9  -0.032  0.0256  False
#    DecisionTreeRegressorKNeighborsRegressor                               ElasticNetSVR  -0.0848  0.001 -0.1131 -0.0565   True
#    DecisionTreeRegressorKNeighborsRegressor                  LassoDecisionTreeRegressor  -0.1708  0.001 -0.1965 -0.1452   True
#    DecisionTreeRegressorKNeighborsRegressor                             LassoElasticNet  -0.0155 0.8634 -0.0408  0.0099  False
#    DecisionTreeRegressorKNeighborsRegressor                    LassoKNeighborsRegressor  -0.0171    0.9 -0.0481  0.0139  False
#    DecisionTreeRegressorKNeighborsRegressor                  LassoRandomForestRegressor   0.0013    0.9 -0.0263  0.0288  False
#    DecisionTreeRegressorKNeighborsRegressor                                    LassoSVR  -0.0908  0.001 -0.1201 -0.0615   True
#    DecisionTreeRegressorKNeighborsRegressor  RandomForestRegressorDecisionTreeRegressor  -0.1725  0.001 -0.1984 -0.1465   True
#    DecisionTreeRegressorKNeighborsRegressor             RandomForestRegressorElasticNet  -0.0051    0.9 -0.0304  0.0203  False
#    DecisionTreeRegressorKNeighborsRegressor    RandomForestRegressorKNeighborsRegressor  -0.0016    0.9 -0.0355  0.0324  False
#    DecisionTreeRegressorKNeighborsRegressor                    RandomForestRegressorSVR  -0.0795  0.001 -0.1094 -0.0496   True
#    DecisionTreeRegressorKNeighborsRegressor           f_regressionDecisionTreeRegressor  -0.1704  0.001 -0.1963 -0.1446   True
#    DecisionTreeRegressorKNeighborsRegressor                      f_regressionElasticNet  -0.0138    0.9 -0.0392  0.0116  False
#    DecisionTreeRegressorKNeighborsRegressor             f_regressionKNeighborsRegressor  -0.0057    0.9 -0.0364  0.0249  False
#    DecisionTreeRegressorKNeighborsRegressor           f_regressionRandomForestRegressor   0.0204 0.5593 -0.0075  0.0482  False
#    DecisionTreeRegressorKNeighborsRegressor                             f_regressionSVR  -0.1019  0.001 -0.1321 -0.0717   True
#    DecisionTreeRegressorKNeighborsRegressor mutual_info_regressionDecisionTreeRegressor  -0.1566  0.001 -0.1827 -0.1305   True
#    DecisionTreeRegressorKNeighborsRegressor            mutual_info_regressionElasticNet  -0.0031    0.9 -0.0287  0.0225  False
#    DecisionTreeRegressorKNeighborsRegressor   mutual_info_regressionKNeighborsRegressor   0.0134    0.9 -0.0191  0.0459  False
#    DecisionTreeRegressorKNeighborsRegressor mutual_info_regressionRandomForestRegressor    0.027 0.0903 -0.0014  0.0555  False
#    DecisionTreeRegressorKNeighborsRegressor                   mutual_info_regressionSVR  -0.0576  0.001 -0.0875 -0.0276   True
#  DecisionTreeRegressorRandomForestRegressor                    DecisionTreeRegressorSVR  -0.0955  0.001 -0.1229 -0.0682   True
#  DecisionTreeRegressorRandomForestRegressor             ElasticNetDecisionTreeRegressor  -0.1593  0.001 -0.1807  -0.138   True
#  DecisionTreeRegressorRandomForestRegressor               ElasticNetKNeighborsRegressor   0.0063    0.9 -0.0222  0.0348  False
#  DecisionTreeRegressorRandomForestRegressor             ElasticNetRandomForestRegressor   0.0089    0.9 -0.0165  0.0342  False
#  DecisionTreeRegressorRandomForestRegressor                               ElasticNetSVR  -0.0727  0.001 -0.0974  -0.048   True
#  DecisionTreeRegressorRandomForestRegressor                  LassoDecisionTreeRegressor  -0.1588  0.001 -0.1804 -0.1371   True
#  DecisionTreeRegressorRandomForestRegressor                             LassoElasticNet  -0.0034    0.9 -0.0248   0.018  False
#  DecisionTreeRegressorRandomForestRegressor                    LassoKNeighborsRegressor   -0.005    0.9 -0.0328  0.0228  False
#  DecisionTreeRegressorRandomForestRegressor                  LassoRandomForestRegressor   0.0134    0.9 -0.0105  0.0373  False
#  DecisionTreeRegressorRandomForestRegressor                                    LassoSVR  -0.0787  0.001 -0.1046 -0.0528   True
#  DecisionTreeRegressorRandomForestRegressor  RandomForestRegressorDecisionTreeRegressor  -0.1604  0.001 -0.1824 -0.1384   True
#  DecisionTreeRegressorRandomForestRegressor             RandomForestRegressorElasticNet    0.007    0.9 -0.0143  0.0283  False
#  DecisionTreeRegressorRandomForestRegressor    RandomForestRegressorKNeighborsRegressor   0.0105    0.9 -0.0206  0.0415  False
#  DecisionTreeRegressorRandomForestRegressor                    RandomForestRegressorSVR  -0.0674  0.001  -0.094 -0.0408   True
#  DecisionTreeRegressorRandomForestRegressor           f_regressionDecisionTreeRegressor  -0.1583  0.001 -0.1802 -0.1364   True
#  DecisionTreeRegressorRandomForestRegressor                      f_regressionElasticNet  -0.0017    0.9 -0.0231  0.0196  False
#  DecisionTreeRegressorRandomForestRegressor             f_regressionKNeighborsRegressor   0.0063    0.9 -0.0211  0.0337  False
#  DecisionTreeRegressorRandomForestRegressor           f_regressionRandomForestRegressor   0.0324  0.001  0.0082  0.0566   True
#  DecisionTreeRegressorRandomForestRegressor                             f_regressionSVR  -0.0898  0.001 -0.1167  -0.063   True
#  DecisionTreeRegressorRandomForestRegressor mutual_info_regressionDecisionTreeRegressor  -0.1445  0.001 -0.1667 -0.1223   True
#  DecisionTreeRegressorRandomForestRegressor            mutual_info_regressionElasticNet   0.0089    0.9 -0.0127  0.0306  False
#  DecisionTreeRegressorRandomForestRegressor   mutual_info_regressionKNeighborsRegressor   0.0254 0.2206  -0.004  0.0549  False
#  DecisionTreeRegressorRandomForestRegressor mutual_info_regressionRandomForestRegressor   0.0391  0.001  0.0142   0.064   True
#  DecisionTreeRegressorRandomForestRegressor                   mutual_info_regressionSVR  -0.0455  0.001 -0.0721 -0.0189   True
#                    DecisionTreeRegressorSVR             ElasticNetDecisionTreeRegressor  -0.0638  0.001 -0.0885 -0.0392   True
#                    DecisionTreeRegressorSVR               ElasticNetKNeighborsRegressor   0.1018  0.001  0.0707  0.1329   True
#                    DecisionTreeRegressorSVR             ElasticNetRandomForestRegressor   0.1044  0.001  0.0762  0.1326   True
#                    DecisionTreeRegressorSVR                               ElasticNetSVR   0.0228 0.3058 -0.0048  0.0504  False
#                    DecisionTreeRegressorSVR                  LassoDecisionTreeRegressor  -0.0632  0.001 -0.0882 -0.0383   True
#                    DecisionTreeRegressorSVR                             LassoElasticNet   0.0921  0.001  0.0675  0.1168   True
#                    DecisionTreeRegressorSVR                    LassoKNeighborsRegressor   0.0905  0.001  0.0601  0.1209   True
#                    DecisionTreeRegressorSVR                  LassoRandomForestRegressor   0.1089  0.001   0.082  0.1358   True
#                    DecisionTreeRegressorSVR                                    LassoSVR   0.0168    0.9 -0.0119  0.0455  False
#                    DecisionTreeRegressorSVR  RandomForestRegressorDecisionTreeRegressor  -0.0649  0.001 -0.0901 -0.0396   True
#                    DecisionTreeRegressorSVR             RandomForestRegressorElasticNet   0.1025  0.001  0.0779  0.1271   True
#                    DecisionTreeRegressorSVR    RandomForestRegressorKNeighborsRegressor    0.106  0.001  0.0726  0.1394   True
#                    DecisionTreeRegressorSVR                    RandomForestRegressorSVR   0.0281 0.0819 -0.0012  0.0574  False
#                    DecisionTreeRegressorSVR           f_regressionDecisionTreeRegressor  -0.0628  0.001  -0.088 -0.0377   True
#                    DecisionTreeRegressorSVR                      f_regressionElasticNet   0.0938  0.001  0.0691  0.1184   True
#                    DecisionTreeRegressorSVR             f_regressionKNeighborsRegressor   0.1018  0.001  0.0718  0.1319   True
#                    DecisionTreeRegressorSVR           f_regressionRandomForestRegressor   0.1279  0.001  0.1008  0.1551   True
#                    DecisionTreeRegressorSVR                             f_regressionSVR   0.0057    0.9 -0.0239  0.0352  False
#                    DecisionTreeRegressorSVR mutual_info_regressionDecisionTreeRegressor   -0.049  0.001 -0.0744 -0.0236   True
#                    DecisionTreeRegressorSVR            mutual_info_regressionElasticNet   0.1045  0.001  0.0796  0.1293   True
#                    DecisionTreeRegressorSVR   mutual_info_regressionKNeighborsRegressor    0.121  0.001   0.089  0.1529   True
#                    DecisionTreeRegressorSVR mutual_info_regressionRandomForestRegressor   0.1346  0.001  0.1068  0.1624   True
#                    DecisionTreeRegressorSVR                   mutual_info_regressionSVR     0.05  0.001  0.0207  0.0794   True
#             ElasticNetDecisionTreeRegressor               ElasticNetKNeighborsRegressor   0.1656  0.001  0.1397  0.1916   True
#             ElasticNetDecisionTreeRegressor             ElasticNetRandomForestRegressor   0.1682  0.001  0.1458  0.1906   True
#             ElasticNetDecisionTreeRegressor                               ElasticNetSVR   0.0866  0.001  0.0649  0.1083   True
#             ElasticNetDecisionTreeRegressor                  LassoDecisionTreeRegressor   0.0006    0.9 -0.0175  0.0187  False
#             ElasticNetDecisionTreeRegressor                             LassoElasticNet   0.1559  0.001  0.1382  0.1737   True
#             ElasticNetDecisionTreeRegressor                    LassoKNeighborsRegressor   0.1543  0.001  0.1292  0.1795   True
#             ElasticNetDecisionTreeRegressor                  LassoRandomForestRegressor   0.1727  0.001  0.1519  0.1935   True
#             ElasticNetDecisionTreeRegressor                                    LassoSVR   0.0806  0.001  0.0576  0.1036   True
#             ElasticNetDecisionTreeRegressor  RandomForestRegressorDecisionTreeRegressor  -0.0011    0.9 -0.0196  0.0175  False
#             ElasticNetDecisionTreeRegressor             RandomForestRegressorElasticNet   0.1663  0.001  0.1486   0.184   True
#             ElasticNetDecisionTreeRegressor    RandomForestRegressorKNeighborsRegressor   0.1698  0.001  0.1411  0.1985   True
#             ElasticNetDecisionTreeRegressor                    RandomForestRegressorSVR   0.0919  0.001  0.0682  0.1157   True
#             ElasticNetDecisionTreeRegressor           f_regressionDecisionTreeRegressor    0.001    0.9 -0.0174  0.0194  False
#             ElasticNetDecisionTreeRegressor                      f_regressionElasticNet   0.1576  0.001  0.1398  0.1753   True
#             ElasticNetDecisionTreeRegressor             f_regressionKNeighborsRegressor   0.1657  0.001   0.141  0.1904   True
#             ElasticNetDecisionTreeRegressor           f_regressionRandomForestRegressor   0.1918  0.001  0.1707  0.2129   True
#             ElasticNetDecisionTreeRegressor                             f_regressionSVR   0.0695  0.001  0.0454  0.0936   True
#             ElasticNetDecisionTreeRegressor mutual_info_regressionDecisionTreeRegressor   0.0148 0.4018 -0.0039  0.0336  False
#             ElasticNetDecisionTreeRegressor            mutual_info_regressionElasticNet   0.1683  0.001  0.1502  0.1864   True
#             ElasticNetDecisionTreeRegressor   mutual_info_regressionKNeighborsRegressor   0.1848  0.001  0.1578  0.2118   True
#             ElasticNetDecisionTreeRegressor mutual_info_regressionRandomForestRegressor   0.1984  0.001  0.1765  0.2204   True
#             ElasticNetDecisionTreeRegressor                   mutual_info_regressionSVR   0.1138  0.001    0.09  0.1377   True
#               ElasticNetKNeighborsRegressor             ElasticNetRandomForestRegressor   0.0026    0.9 -0.0267  0.0319  False
#               ElasticNetKNeighborsRegressor                               ElasticNetSVR   -0.079  0.001 -0.1078 -0.0502   True
#               ElasticNetKNeighborsRegressor                  LassoDecisionTreeRegressor   -0.165  0.001 -0.1912 -0.1388   True
#               ElasticNetKNeighborsRegressor                             LassoElasticNet  -0.0097    0.9 -0.0356  0.0163  False
#               ElasticNetKNeighborsRegressor                    LassoKNeighborsRegressor  -0.0113    0.9 -0.0427  0.0202  False
#               ElasticNetKNeighborsRegressor                  LassoRandomForestRegressor   0.0071    0.9  -0.021  0.0352  False
#               ElasticNetKNeighborsRegressor                                    LassoSVR   -0.085  0.001 -0.1148 -0.0552   True
#               ElasticNetKNeighborsRegressor  RandomForestRegressorDecisionTreeRegressor  -0.1667  0.001 -0.1932 -0.1402   True
#               ElasticNetKNeighborsRegressor             RandomForestRegressorElasticNet   0.0007    0.9 -0.0252  0.0266  False
#               ElasticNetKNeighborsRegressor    RandomForestRegressorKNeighborsRegressor   0.0042    0.9 -0.0302  0.0386  False
#               ElasticNetKNeighborsRegressor                    RandomForestRegressorSVR  -0.0737  0.001 -0.1041 -0.0433   True
#               ElasticNetKNeighborsRegressor           f_regressionDecisionTreeRegressor  -0.1646  0.001  -0.191 -0.1382   True
#               ElasticNetKNeighborsRegressor                      f_regressionElasticNet   -0.008    0.9  -0.034  0.0179  False
#               ElasticNetKNeighborsRegressor             f_regressionKNeighborsRegressor   0.0001    0.9  -0.031  0.0312  False
#               ElasticNetKNeighborsRegressor           f_regressionRandomForestRegressor   0.0262  0.123 -0.0022  0.0545  False
#               ElasticNetKNeighborsRegressor                             f_regressionSVR  -0.0961  0.001 -0.1267 -0.0655   True
#               ElasticNetKNeighborsRegressor mutual_info_regressionDecisionTreeRegressor  -0.1508  0.001 -0.1774 -0.1242   True
#               ElasticNetKNeighborsRegressor            mutual_info_regressionElasticNet   0.0027    0.9 -0.0235  0.0288  False
#               ElasticNetKNeighborsRegressor   mutual_info_regressionKNeighborsRegressor   0.0192    0.9 -0.0138  0.0521  False
#               ElasticNetKNeighborsRegressor mutual_info_regressionRandomForestRegressor   0.0328 0.0079  0.0039  0.0618   True
#               ElasticNetKNeighborsRegressor                   mutual_info_regressionSVR  -0.0518  0.001 -0.0822 -0.0213   True
#             ElasticNetRandomForestRegressor                               ElasticNetSVR  -0.0816  0.001 -0.1072  -0.056   True
#             ElasticNetRandomForestRegressor                  LassoDecisionTreeRegressor  -0.1676  0.001 -0.1903 -0.1449   True
#             ElasticNetRandomForestRegressor                             LassoElasticNet  -0.0123    0.9 -0.0347  0.0101  False
#             ElasticNetRandomForestRegressor                    LassoKNeighborsRegressor  -0.0139    0.9 -0.0425  0.0148  False
#             ElasticNetRandomForestRegressor                  LassoRandomForestRegressor   0.0045    0.9 -0.0203  0.0293  False
#             ElasticNetRandomForestRegressor                                    LassoSVR  -0.0876  0.001 -0.1144 -0.0608   True
#             ElasticNetRandomForestRegressor  RandomForestRegressorDecisionTreeRegressor  -0.1693  0.001 -0.1923 -0.1462   True
#             ElasticNetRandomForestRegressor             RandomForestRegressorElasticNet  -0.0019    0.9 -0.0242  0.0205  False
#             ElasticNetRandomForestRegressor    RandomForestRegressorKNeighborsRegressor   0.0016    0.9 -0.0302  0.0334  False
#             ElasticNetRandomForestRegressor                    RandomForestRegressorSVR  -0.0763  0.001 -0.1037 -0.0488   True
#             ElasticNetRandomForestRegressor           f_regressionDecisionTreeRegressor  -0.1672  0.001 -0.1901 -0.1443   True
#             ElasticNetRandomForestRegressor                      f_regressionElasticNet  -0.0106    0.9  -0.033  0.0118  False
#             ElasticNetRandomForestRegressor             f_regressionKNeighborsRegressor  -0.0025    0.9 -0.0307  0.0257  False
#             ElasticNetRandomForestRegressor           f_regressionRandomForestRegressor   0.0236 0.1043 -0.0016  0.0487  False
#             ElasticNetRandomForestRegressor                             f_regressionSVR  -0.0987  0.001 -0.1264  -0.071   True
#             ElasticNetRandomForestRegressor mutual_info_regressionDecisionTreeRegressor  -0.1534  0.001 -0.1766 -0.1302   True
#             ElasticNetRandomForestRegressor            mutual_info_regressionElasticNet   0.0001    0.9 -0.0226  0.0227  False
#             ElasticNetRandomForestRegressor   mutual_info_regressionKNeighborsRegressor   0.0166    0.9 -0.0137  0.0468  False
#             ElasticNetRandomForestRegressor mutual_info_regressionRandomForestRegressor   0.0302 0.0045  0.0044  0.0561   True
#             ElasticNetRandomForestRegressor                   mutual_info_regressionSVR  -0.0544  0.001 -0.0819 -0.0269   True
#                               ElasticNetSVR                  LassoDecisionTreeRegressor   -0.086  0.001  -0.108 -0.0641   True
#                               ElasticNetSVR                             LassoElasticNet   0.0693  0.001  0.0476   0.091   True
#                               ElasticNetSVR                    LassoKNeighborsRegressor   0.0677  0.001  0.0397  0.0958   True
#                               ElasticNetSVR                  LassoRandomForestRegressor   0.0861  0.001  0.0619  0.1103   True
#                               ElasticNetSVR                                    LassoSVR   -0.006    0.9 -0.0322  0.0202  False
#                               ElasticNetSVR  RandomForestRegressorDecisionTreeRegressor  -0.0877  0.001   -0.11 -0.0653   True
#                               ElasticNetSVR             RandomForestRegressorElasticNet   0.0797  0.001  0.0581  0.1014   True
#                               ElasticNetSVR    RandomForestRegressorKNeighborsRegressor   0.0832  0.001  0.0519  0.1145   True
#                               ElasticNetSVR                    RandomForestRegressorSVR   0.0053    0.9 -0.0215  0.0322  False
#                               ElasticNetSVR           f_regressionDecisionTreeRegressor  -0.0856  0.001 -0.1079 -0.0634   True
#                               ElasticNetSVR                      f_regressionElasticNet    0.071  0.001  0.0493  0.0926   True
#                               ElasticNetSVR             f_regressionKNeighborsRegressor   0.0791  0.001  0.0514  0.1067   True
#                               ElasticNetSVR           f_regressionRandomForestRegressor   0.1051  0.001  0.0806  0.1296   True
#                               ElasticNetSVR                             f_regressionSVR  -0.0171 0.8099 -0.0442    0.01  False
#                               ElasticNetSVR mutual_info_regressionDecisionTreeRegressor  -0.0718  0.001 -0.0943 -0.0493   True
#                               ElasticNetSVR            mutual_info_regressionElasticNet   0.0817  0.001  0.0597  0.1036   True
#                               ElasticNetSVR   mutual_info_regressionKNeighborsRegressor   0.0982  0.001  0.0684  0.1279   True
#                               ElasticNetSVR mutual_info_regressionRandomForestRegressor   0.1118  0.001  0.0866   0.137   True
#                               ElasticNetSVR                   mutual_info_regressionSVR   0.0272 0.0434  0.0003  0.0541   True
#                  LassoDecisionTreeRegressor                             LassoElasticNet   0.1554  0.001  0.1372  0.1735   True
#                  LassoDecisionTreeRegressor                    LassoKNeighborsRegressor   0.1538  0.001  0.1283  0.1792   True
#                  LassoDecisionTreeRegressor                  LassoRandomForestRegressor   0.1721  0.001   0.151  0.1932   True
#                  LassoDecisionTreeRegressor                                    LassoSVR     0.08  0.001  0.0567  0.1033   True
#                  LassoDecisionTreeRegressor  RandomForestRegressorDecisionTreeRegressor  -0.0016    0.9 -0.0205  0.0173  False
#                  LassoDecisionTreeRegressor             RandomForestRegressorElasticNet   0.1658  0.001  0.1477  0.1838   True
#                  LassoDecisionTreeRegressor    RandomForestRegressorKNeighborsRegressor   0.1692  0.001  0.1403  0.1982   True
#                  LassoDecisionTreeRegressor                    RandomForestRegressorSVR   0.0914  0.001  0.0673  0.1154   True
#                  LassoDecisionTreeRegressor           f_regressionDecisionTreeRegressor   0.0004    0.9 -0.0184  0.0192  False
#                  LassoDecisionTreeRegressor                      f_regressionElasticNet    0.157  0.001  0.1389  0.1751   True
#                  LassoDecisionTreeRegressor             f_regressionKNeighborsRegressor   0.1651  0.001  0.1401    0.19   True
#                  LassoDecisionTreeRegressor           f_regressionRandomForestRegressor   0.1912  0.001  0.1698  0.2126   True
#                  LassoDecisionTreeRegressor                             f_regressionSVR   0.0689  0.001  0.0445  0.0933   True
#                  LassoDecisionTreeRegressor mutual_info_regressionDecisionTreeRegressor   0.0142  0.523 -0.0048  0.0333  False
#                  LassoDecisionTreeRegressor            mutual_info_regressionElasticNet   0.1677  0.001  0.1493  0.1861   True
#                  LassoDecisionTreeRegressor   mutual_info_regressionKNeighborsRegressor   0.1842  0.001   0.157  0.2114   True
#                  LassoDecisionTreeRegressor mutual_info_regressionRandomForestRegressor   0.1979  0.001  0.1756  0.2201   True
#                  LassoDecisionTreeRegressor                   mutual_info_regressionSVR   0.1133  0.001  0.0891  0.1374   True
#                             LassoElasticNet                    LassoKNeighborsRegressor  -0.0016    0.9 -0.0268  0.0236  False
#                             LassoElasticNet                  LassoRandomForestRegressor   0.0168 0.3535  -0.004  0.0375  False
#                             LassoElasticNet                                    LassoSVR  -0.0753  0.001 -0.0984 -0.0523   True
#                             LassoElasticNet  RandomForestRegressorDecisionTreeRegressor   -0.157  0.001 -0.1755 -0.1384   True
#                             LassoElasticNet             RandomForestRegressorElasticNet   0.0104    0.9 -0.0073  0.0281  False
#                             LassoElasticNet    RandomForestRegressorKNeighborsRegressor   0.0139    0.9 -0.0148  0.0426  False
#                             LassoElasticNet                    RandomForestRegressorSVR   -0.064  0.001 -0.0878 -0.0402   True
#                             LassoElasticNet           f_regressionDecisionTreeRegressor  -0.1549  0.001 -0.1734 -0.1365   True
#                             LassoElasticNet                      f_regressionElasticNet   0.0016    0.9 -0.0161  0.0194  False
#                             LassoElasticNet             f_regressionKNeighborsRegressor   0.0097    0.9  -0.015  0.0344  False
#                             LassoElasticNet           f_regressionRandomForestRegressor   0.0358  0.001  0.0147  0.0569   True
#                             LassoElasticNet                             f_regressionSVR  -0.0864  0.001 -0.1105 -0.0623   True
#                             LassoElasticNet mutual_info_regressionDecisionTreeRegressor  -0.1411  0.001 -0.1599 -0.1224   True
#                             LassoElasticNet            mutual_info_regressionElasticNet   0.0123 0.6818 -0.0057  0.0304  False
#                             LassoElasticNet   mutual_info_regressionKNeighborsRegressor   0.0288 0.0203  0.0019  0.0558   True
#                             LassoElasticNet mutual_info_regressionRandomForestRegressor   0.0425  0.001  0.0206  0.0644   True
#                             LassoElasticNet                   mutual_info_regressionSVR  -0.0421  0.001  -0.066 -0.0182   True
#                    LassoKNeighborsRegressor                  LassoRandomForestRegressor   0.0184 0.7105  -0.009  0.0457  False
#                    LassoKNeighborsRegressor                                    LassoSVR  -0.0737  0.001 -0.1029 -0.0446   True
#                    LassoKNeighborsRegressor  RandomForestRegressorDecisionTreeRegressor  -0.1554  0.001 -0.1811 -0.1297   True
#                    LassoKNeighborsRegressor             RandomForestRegressorElasticNet    0.012    0.9 -0.0131  0.0371  False
#                    LassoKNeighborsRegressor    RandomForestRegressorKNeighborsRegressor   0.0155    0.9 -0.0183  0.0493  False
#                    LassoKNeighborsRegressor                    RandomForestRegressorSVR  -0.0624  0.001 -0.0921 -0.0327   True
#                    LassoKNeighborsRegressor           f_regressionDecisionTreeRegressor  -0.1533  0.001  -0.179 -0.1277   True
#                    LassoKNeighborsRegressor                      f_regressionElasticNet   0.0032    0.9 -0.0219  0.0284  False
#                    LassoKNeighborsRegressor             f_regressionKNeighborsRegressor   0.0113    0.9 -0.0191  0.0418  False
#                    LassoKNeighborsRegressor           f_regressionRandomForestRegressor   0.0374  0.001  0.0098   0.065   True
#                    LassoKNeighborsRegressor                             f_regressionSVR  -0.0848  0.001 -0.1148 -0.0549   True
#                    LassoKNeighborsRegressor mutual_info_regressionDecisionTreeRegressor  -0.1395  0.001 -0.1654 -0.1136   True
#                    LassoKNeighborsRegressor            mutual_info_regressionElasticNet   0.0139    0.9 -0.0115  0.0393  False
#                    LassoKNeighborsRegressor   mutual_info_regressionKNeighborsRegressor   0.0304 0.0999 -0.0019  0.0628  False
#                    LassoKNeighborsRegressor mutual_info_regressionRandomForestRegressor   0.0441  0.001  0.0158  0.0724   True
#                    LassoKNeighborsRegressor                   mutual_info_regressionSVR  -0.0405  0.001 -0.0703 -0.0107   True
#                  LassoRandomForestRegressor                                    LassoSVR  -0.0921  0.001 -0.1175 -0.0667   True
#                  LassoRandomForestRegressor  RandomForestRegressorDecisionTreeRegressor  -0.1737  0.001 -0.1952 -0.1523   True
#                  LassoRandomForestRegressor             RandomForestRegressorElasticNet  -0.0064    0.9 -0.0271  0.0143  False
#                  LassoRandomForestRegressor    RandomForestRegressorKNeighborsRegressor  -0.0029    0.9 -0.0335  0.0278  False
#                  LassoRandomForestRegressor                    RandomForestRegressorSVR  -0.0808  0.001 -0.1069 -0.0547   True
#                  LassoRandomForestRegressor           f_regressionDecisionTreeRegressor  -0.1717  0.001  -0.193 -0.1504   True
#                  LassoRandomForestRegressor                      f_regressionElasticNet  -0.0151  0.568 -0.0359  0.0056  False
#                  LassoRandomForestRegressor             f_regressionKNeighborsRegressor   -0.007    0.9  -0.034  0.0199  False
#                  LassoRandomForestRegressor           f_regressionRandomForestRegressor   0.0191 0.3593 -0.0046  0.0428  False
#                  LassoRandomForestRegressor                             f_regressionSVR  -0.1032  0.001 -0.1296 -0.0768   True
#                  LassoRandomForestRegressor mutual_info_regressionDecisionTreeRegressor  -0.1579  0.001 -0.1795 -0.1363   True
#                  LassoRandomForestRegressor            mutual_info_regressionElasticNet  -0.0044    0.9 -0.0254  0.0166  False
#                  LassoRandomForestRegressor   mutual_info_regressionKNeighborsRegressor   0.0121    0.9  -0.017  0.0411  False
#                  LassoRandomForestRegressor mutual_info_regressionRandomForestRegressor   0.0257 0.0248  0.0013  0.0502   True
#                  LassoRandomForestRegressor                   mutual_info_regressionSVR  -0.0589  0.001  -0.085 -0.0327   True
#                                    LassoSVR  RandomForestRegressorDecisionTreeRegressor  -0.0817  0.001 -0.1053  -0.058   True
#                                    LassoSVR             RandomForestRegressorElasticNet   0.0857  0.001  0.0628  0.1087   True
#                                    LassoSVR    RandomForestRegressorKNeighborsRegressor   0.0892  0.001   0.057  0.1215   True
#                                    LassoSVR                    RandomForestRegressorSVR   0.0113    0.9 -0.0166  0.0393  False
#                                    LassoSVR           f_regressionDecisionTreeRegressor  -0.0796  0.001 -0.1031 -0.0561   True
#                                    LassoSVR                      f_regressionElasticNet    0.077  0.001   0.054     0.1   True
#                                    LassoSVR             f_regressionKNeighborsRegressor   0.0851  0.001  0.0564  0.1138   True
#                                    LassoSVR           f_regressionRandomForestRegressor   0.1112  0.001  0.0855  0.1369   True
#                                    LassoSVR                             f_regressionSVR  -0.0111    0.9 -0.0393  0.0171  False
#                                    LassoSVR mutual_info_regressionDecisionTreeRegressor  -0.0658  0.001 -0.0896  -0.042   True
#                                    LassoSVR            mutual_info_regressionElasticNet   0.0877  0.001  0.0644   0.111   True
#                                    LassoSVR   mutual_info_regressionKNeighborsRegressor   0.1042  0.001  0.0735  0.1349   True
#                                    LassoSVR mutual_info_regressionRandomForestRegressor   0.1178  0.001  0.0915  0.1442   True
#                                    LassoSVR                   mutual_info_regressionSVR   0.0332 0.0034  0.0052  0.0613   True
#  RandomForestRegressorDecisionTreeRegressor             RandomForestRegressorElasticNet   0.1674  0.001  0.1489  0.1859   True
#  RandomForestRegressorDecisionTreeRegressor    RandomForestRegressorKNeighborsRegressor   0.1709  0.001  0.1417  0.2001   True
#  RandomForestRegressorDecisionTreeRegressor                    RandomForestRegressorSVR    0.093  0.001  0.0686  0.1174   True
#  RandomForestRegressorDecisionTreeRegressor           f_regressionDecisionTreeRegressor   0.0021    0.9 -0.0171  0.0212  False
#  RandomForestRegressorDecisionTreeRegressor                      f_regressionElasticNet   0.1586  0.001  0.1401  0.1772   True
#  RandomForestRegressorDecisionTreeRegressor             f_regressionKNeighborsRegressor   0.1667  0.001  0.1415   0.192   True
#  RandomForestRegressorDecisionTreeRegressor           f_regressionRandomForestRegressor   0.1928  0.001   0.171  0.2146   True
#  RandomForestRegressorDecisionTreeRegressor                             f_regressionSVR   0.0706  0.001  0.0459  0.0953   True
#  RandomForestRegressorDecisionTreeRegressor mutual_info_regressionDecisionTreeRegressor   0.0159 0.3328 -0.0036  0.0354  False
#  RandomForestRegressorDecisionTreeRegressor            mutual_info_regressionElasticNet   0.1693  0.001  0.1505  0.1882   True
#  RandomForestRegressorDecisionTreeRegressor   mutual_info_regressionKNeighborsRegressor   0.1858  0.001  0.1583  0.2134   True
#  RandomForestRegressorDecisionTreeRegressor mutual_info_regressionRandomForestRegressor   0.1995  0.001  0.1769  0.2221   True
#  RandomForestRegressorDecisionTreeRegressor                   mutual_info_regressionSVR   0.1149  0.001  0.0904  0.1394   True
#             RandomForestRegressorElasticNet    RandomForestRegressorKNeighborsRegressor   0.0035    0.9 -0.0252  0.0322  False
#             RandomForestRegressorElasticNet                    RandomForestRegressorSVR  -0.0744  0.001 -0.0981 -0.0507   True
#             RandomForestRegressorElasticNet           f_regressionDecisionTreeRegressor  -0.1653  0.001 -0.1837  -0.147   True
#             RandomForestRegressorElasticNet                      f_regressionElasticNet  -0.0087    0.9 -0.0264  0.0089  False
#             RandomForestRegressorElasticNet             f_regressionKNeighborsRegressor  -0.0007    0.9 -0.0253   0.024  False
#             RandomForestRegressorElasticNet           f_regressionRandomForestRegressor   0.0254 0.0024  0.0044  0.0465   True
#             RandomForestRegressorElasticNet                             f_regressionSVR  -0.0968  0.001 -0.1209 -0.0728   True
#             RandomForestRegressorElasticNet mutual_info_regressionDecisionTreeRegressor  -0.1515  0.001 -0.1702 -0.1328   True
#             RandomForestRegressorElasticNet            mutual_info_regressionElasticNet   0.0019    0.9 -0.0161    0.02  False
#             RandomForestRegressorElasticNet   mutual_info_regressionKNeighborsRegressor   0.0184 0.6764 -0.0085  0.0454  False
#             RandomForestRegressorElasticNet mutual_info_regressionRandomForestRegressor   0.0321  0.001  0.0102   0.054   True
#             RandomForestRegressorElasticNet                   mutual_info_regressionSVR  -0.0525  0.001 -0.0763 -0.0287   True
#    RandomForestRegressorKNeighborsRegressor                    RandomForestRegressorSVR  -0.0779  0.001 -0.1107 -0.0451   True
#    RandomForestRegressorKNeighborsRegressor           f_regressionDecisionTreeRegressor  -0.1688  0.001 -0.1979 -0.1397   True
#    RandomForestRegressorKNeighborsRegressor                      f_regressionElasticNet  -0.0122    0.9 -0.0409  0.0165  False
#    RandomForestRegressorKNeighborsRegressor             f_regressionKNeighborsRegressor  -0.0042    0.9 -0.0376  0.0293  False
#    RandomForestRegressorKNeighborsRegressor           f_regressionRandomForestRegressor   0.0219 0.6122 -0.0089  0.0528  False
#    RandomForestRegressorKNeighborsRegressor                             f_regressionSVR  -0.1003  0.001 -0.1333 -0.0673   True
#    RandomForestRegressorKNeighborsRegressor mutual_info_regressionDecisionTreeRegressor   -0.155  0.001 -0.1843 -0.1257   True
#    RandomForestRegressorKNeighborsRegressor            mutual_info_regressionElasticNet  -0.0015    0.9 -0.0305  0.0274  False
#    RandomForestRegressorKNeighborsRegressor   mutual_info_regressionKNeighborsRegressor    0.015    0.9 -0.0202  0.0501  False
#    RandomForestRegressorKNeighborsRegressor mutual_info_regressionRandomForestRegressor   0.0286 0.1398 -0.0028  0.0601  False
#    RandomForestRegressorKNeighborsRegressor                   mutual_info_regressionSVR   -0.056  0.001 -0.0888 -0.0231   True
#                    RandomForestRegressorSVR           f_regressionDecisionTreeRegressor  -0.0909  0.001 -0.1152 -0.0667   True
#                    RandomForestRegressorSVR                      f_regressionElasticNet   0.0657  0.001  0.0419  0.0894   True
#                    RandomForestRegressorSVR             f_regressionKNeighborsRegressor   0.0737  0.001  0.0444  0.1031   True
#                    RandomForestRegressorSVR           f_regressionRandomForestRegressor   0.0998  0.001  0.0735  0.1262   True
#                    RandomForestRegressorSVR                             f_regressionSVR  -0.0224 0.4383 -0.0513  0.0064  False
#                    RandomForestRegressorSVR mutual_info_regressionDecisionTreeRegressor  -0.0771  0.001 -0.1016 -0.0526   True
#                    RandomForestRegressorSVR            mutual_info_regressionElasticNet   0.0763  0.001  0.0523  0.1004   True
#                    RandomForestRegressorSVR   mutual_info_regressionKNeighborsRegressor   0.0929  0.001  0.0616  0.1241   True
#                    RandomForestRegressorSVR mutual_info_regressionRandomForestRegressor   0.1065  0.001  0.0795  0.1335   True
#                    RandomForestRegressorSVR                   mutual_info_regressionSVR   0.0219 0.4747 -0.0067  0.0505  False
#           f_regressionDecisionTreeRegressor                      f_regressionElasticNet   0.1566  0.001  0.1382   0.175   True
#           f_regressionDecisionTreeRegressor             f_regressionKNeighborsRegressor   0.1647  0.001  0.1395  0.1898   True
#           f_regressionDecisionTreeRegressor           f_regressionRandomForestRegressor   0.1908  0.001  0.1691  0.2124   True
#           f_regressionDecisionTreeRegressor                             f_regressionSVR   0.0685  0.001  0.0439  0.0931   True
#           f_regressionDecisionTreeRegressor mutual_info_regressionDecisionTreeRegressor   0.0138 0.6037 -0.0055  0.0332  False
#           f_regressionDecisionTreeRegressor            mutual_info_regressionElasticNet   0.1673  0.001  0.1485   0.186   True
#           f_regressionDecisionTreeRegressor   mutual_info_regressionKNeighborsRegressor   0.1838  0.001  0.1564  0.2112   True
#           f_regressionDecisionTreeRegressor mutual_info_regressionRandomForestRegressor   0.1974  0.001   0.175  0.2199   True
#           f_regressionDecisionTreeRegressor                   mutual_info_regressionSVR   0.1128  0.001  0.0885  0.1372   True
#                      f_regressionElasticNet             f_regressionKNeighborsRegressor   0.0081    0.9 -0.0166  0.0328  False
#                      f_regressionElasticNet           f_regressionRandomForestRegressor   0.0342  0.001  0.0131  0.0553   True
#                      f_regressionElasticNet                             f_regressionSVR  -0.0881  0.001 -0.1122  -0.064   True
#                      f_regressionElasticNet mutual_info_regressionDecisionTreeRegressor  -0.1428  0.001 -0.1615  -0.124   True
#                      f_regressionElasticNet            mutual_info_regressionElasticNet   0.0107    0.9 -0.0074  0.0288  False
#                      f_regressionElasticNet   mutual_info_regressionKNeighborsRegressor   0.0272 0.0454  0.0002  0.0542   True
#                      f_regressionElasticNet mutual_info_regressionRandomForestRegressor   0.0408  0.001  0.0189  0.0628   True
#                      f_regressionElasticNet                   mutual_info_regressionSVR  -0.0438  0.001 -0.0676 -0.0199   True
#             f_regressionKNeighborsRegressor           f_regressionRandomForestRegressor   0.0261 0.0822 -0.0011  0.0533  False
#             f_regressionKNeighborsRegressor                             f_regressionSVR  -0.0962  0.001 -0.1258 -0.0666   True
#             f_regressionKNeighborsRegressor mutual_info_regressionDecisionTreeRegressor  -0.1508  0.001 -0.1763 -0.1254   True
#             f_regressionKNeighborsRegressor            mutual_info_regressionElasticNet   0.0026    0.9 -0.0223  0.0275  False
#             f_regressionKNeighborsRegressor   mutual_info_regressionKNeighborsRegressor   0.0191 0.8923 -0.0129  0.0511  False
#             f_regressionKNeighborsRegressor mutual_info_regressionRandomForestRegressor   0.0328  0.004  0.0049  0.0606   True
#             f_regressionKNeighborsRegressor                   mutual_info_regressionSVR  -0.0518  0.001 -0.0812 -0.0224   True
#           f_regressionRandomForestRegressor                             f_regressionSVR  -0.1223  0.001 -0.1489 -0.0956   True
#           f_regressionRandomForestRegressor mutual_info_regressionDecisionTreeRegressor  -0.1769  0.001 -0.1989  -0.155   True
#           f_regressionRandomForestRegressor            mutual_info_regressionElasticNet  -0.0235 0.0132 -0.0449 -0.0021   True
#           f_regressionRandomForestRegressor   mutual_info_regressionKNeighborsRegressor   -0.007    0.9 -0.0363  0.0223  False
#           f_regressionRandomForestRegressor mutual_info_regressionRandomForestRegressor   0.0067    0.9  -0.018  0.0314  False
#           f_regressionRandomForestRegressor                   mutual_info_regressionSVR  -0.0779  0.001 -0.1044 -0.0515   True
#                             f_regressionSVR mutual_info_regressionDecisionTreeRegressor  -0.0547  0.001 -0.0795 -0.0298   True
#                             f_regressionSVR            mutual_info_regressionElasticNet   0.0988  0.001  0.0744  0.1231   True
#                             f_regressionSVR   mutual_info_regressionKNeighborsRegressor   0.1153  0.001  0.0838  0.1468   True
#                             f_regressionSVR mutual_info_regressionRandomForestRegressor   0.1289  0.001  0.1016  0.1563   True
#                             f_regressionSVR                   mutual_info_regressionSVR   0.0443  0.001  0.0154  0.0732   True
# mutual_info_regressionDecisionTreeRegressor            mutual_info_regressionElasticNet   0.1534  0.001  0.1344  0.1725   True
# mutual_info_regressionDecisionTreeRegressor   mutual_info_regressionKNeighborsRegressor     0.17  0.001  0.1423  0.1976   True
# mutual_info_regressionDecisionTreeRegressor mutual_info_regressionRandomForestRegressor   0.1836  0.001  0.1609  0.2064   True
# mutual_info_regressionDecisionTreeRegressor                   mutual_info_regressionSVR    0.099  0.001  0.0744  0.1236   True
#            mutual_info_regressionElasticNet   mutual_info_regressionKNeighborsRegressor   0.0165 0.8695 -0.0107  0.0437  False
#            mutual_info_regressionElasticNet mutual_info_regressionRandomForestRegressor   0.0302  0.001   0.008  0.0524   True
#            mutual_info_regressionElasticNet                   mutual_info_regressionSVR  -0.0544  0.001 -0.0785 -0.0303   True
#   mutual_info_regressionKNeighborsRegressor mutual_info_regressionRandomForestRegressor   0.0137    0.9 -0.0163  0.0436  False
#   mutual_info_regressionKNeighborsRegressor                   mutual_info_regressionSVR  -0.0709  0.001 -0.1023 -0.0396   True
# mutual_info_regressionRandomForestRegressor                   mutual_info_regressionSVR  -0.0846  0.001 -0.1117 -0.0575   True
# ------------------------------------------------------------------------------------------------------------------------------

# %%
m_comp.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # ANOVA

# %%
import patsy
f = 'r2 ~ n + Quality + fs:model + C(da) + ctrp + gdsc + C(norm)+C(datasets)+metric_drug'
y, X = patsy.dmatrices(f,clean.drop('C', axis=1), return_type='dataframe')

# %%
#X.columns

# %%
X = X.drop(['fs[T.f_regression]:model[DecisionTreeRegressor]','C(da)[T.none]', 'fs[T.ElasticNet]:model[ElasticNet]', 'fs[T.RandomForestRegressor]:model[RandomForestRegressor]'], axis=1)

# %%
mod = sm.OLS(y, X).fit()
results = pd.DataFrame(mod.summary(alpha=0.01).tables[1].data).set_index(0)
results = results.rename(columns=results.iloc[0])[1:]

# %%
results['[0.005'] = pd.to_numeric(results['[0.005'])
results['0.995]'] = pd.to_numeric(results['0.995]'])

# %%
X = X.drop(list(results[results['[0.005']*results['0.995]'] < 0].index), axis=1)

# %%
mod = sm.OLS(y, X).fit()
results = pd.DataFrame(mod.summary(alpha=0.01).tables[1].data).set_index(0)
results = results.rename(columns=results.iloc[0])[1:]

# %%
results
# Out:
#                                                           coef    std err  \
# 0
# Intercept                                              -0.1494      0.004
# C(da)[T.feda]                                          -0.1184      0.002
# ctrp[T.True]                                            0.0239      0.002
# gdsc[T.True]                                            0.0475      0.002
# C(norm)[T.MinMaxScaler]                                 0.0089      0.003
# C(norm)[T.None]                                         0.0093      0.003
# C(norm)[T.QuantileTransformer]                          0.0102      0.003
# C(norm)[T.StandardScaler]                              -0.0387      0.003
# C(datasets)[T.2]                                        0.0190      0.002
# model[T.ElasticNet]                                     0.1788      0.003
# model[T.KNeighborsRegressor]                            0.1785      0.003
# model[T.RandomForestRegressor]                          0.1789      0.004
# model[T.SVR]                                            0.0935      0.003
# fs[T.Lasso]:model[RandomForestRegressor]                0.0141      0.006
# fs[T.f_regression]:model[RandomForestRegressor]         0.0254      0.006
# fs[T.mutual_info_regression]:model[RandomForest...      0.0256      0.006
# fs[T.RandomForestRegressor]:model[SVR]                  0.0174      0.006
# fs[T.mutual_info_regression]:model[SVR]                 0.0258      0.006
# n                                                       0.1116      0.015
#
#                                                             t   P>|t|  \
# 0
# Intercept                                             -41.681   0.000
# C(da)[T.feda]                                         -63.015   0.000
# ctrp[T.True]                                           13.230   0.000
# gdsc[T.True]                                           27.214   0.000
# C(norm)[T.MinMaxScaler]                                 2.840   0.005
# C(norm)[T.None]                                         3.379   0.001
# C(norm)[T.QuantileTransformer]                          3.183   0.001
# C(norm)[T.StandardScaler]                             -12.315   0.000
# C(datasets)[T.2]                                       10.580   0.000
# model[T.ElasticNet]                                    69.094   0.000
# model[T.KNeighborsRegressor]                           60.925   0.000
# model[T.RandomForestRegressor]                         47.230   0.000
# model[T.SVR]                                           29.890   0.000
# fs[T.Lasso]:model[RandomForestRegressor]                2.571   0.010
# fs[T.f_regression]:model[RandomForestRegressor]         4.539   0.000
# fs[T.mutual_info_regression]:model[RandomForest...      4.406   0.000
# fs[T.RandomForestRegressor]:model[SVR]                  2.929   0.003
# fs[T.mutual_info_regression]:model[SVR]                 4.329   0.000
# n                                                       7.657   0.000
#
#                                                        [0.005     0.995]
# 0
# Intercept                                              -0.159     -0.140
# C(da)[T.feda]                                          -0.123     -0.114
# ctrp[T.True]                                            0.019      0.029
# gdsc[T.True]                                            0.043      0.052
# C(norm)[T.MinMaxScaler]                                 0.001      0.017
# C(norm)[T.None]                                         0.002      0.016
# C(norm)[T.QuantileTransformer]                          0.002      0.018
# C(norm)[T.StandardScaler]                              -0.047     -0.031
# C(datasets)[T.2]                                        0.014      0.024
# model[T.ElasticNet]                                     0.172      0.185
# model[T.KNeighborsRegressor]                            0.171      0.186
# model[T.RandomForestRegressor]                          0.169      0.189
# model[T.SVR]                                            0.085      0.102
# fs[T.Lasso]:model[RandomForestRegressor]            -2.47e-05      0.028
# fs[T.f_regression]:model[RandomForestRegressor]         0.011      0.040
# fs[T.mutual_info_regression]:model[RandomForest...      0.011      0.041
# fs[T.RandomForestRegressor]:model[SVR]                  0.002      0.033
# fs[T.mutual_info_regression]:model[SVR]                 0.010      0.041
# n                                                       0.074      0.149
