# %%
import pandas as pd
import config as c
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import subprocess

# %%
data = pd.read_csv('data/runs/n_results.csv', index_col='run')
drug_data = pd.read_csv('data/runs/drug_data.csv')
new_drug_data = pd.read_csv('data/runs/new_drug.csv')
# Out:
# /usr/local_rwth/sw/python/3.7.3/x86_64/extra/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (3,24,39,44,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = data[data['status']=='completed']
data = data[data['r_2_mean'].notnull()]

# %%
data['time'] = pd.to_timedelta(data['time'])
data['started'] = pd.to_datetime(data['started'])

# %%
data['seconds'] = data['time'].apply(lambda x:x.seconds)

# %%
data['datasets'] = data['gdsc']+data['ctrp']+data['ccle']

# %%
data = data[data['datasets']>0]

# %%
ndata = data[data['started'] > pd.to_datetime('2020-04-15 18:00:00')]

# %%
drug_data_j = drug_data.join(ndata, rsuffix='_drug', on='run')
drug_data_j = drug_data_j[drug_data_j['started'].notnull()]

# %%
ndrug_data = drug_data_j[drug_data_j['started'] > pd.to_datetime('2020-04-15 18:00:00')]

# %%
ndata.shape
# Out:
# (1937, 23)

# %%
data[(data['datasets']>1)&(data['feda'] == True)].describe()
# Out:
#                          time  cutoff       drugs           n  test  \
# count                     695   695.0  695.000000  692.000000   0.0
# mean   0 days 01:30:35.712230     4.0   20.258993    0.095094   NaN
# std    0 days 02:12:35.054488     0.0    2.777374    0.059794   NaN
# min           0 days 00:01:02     4.0   20.000000    0.000000   NaN
# 25%    0 days 00:22:08.500000     4.0   20.000000    0.041896   NaN
# 50%           0 days 00:54:51     4.0   20.000000    0.092191   NaN
# 75%    0 days 01:50:36.500000     4.0   20.000000    0.144740   NaN
# max           1 days 04:49:17     4.0   50.000000    0.245415   NaN
#
#         threshold   step    r_2_mean     r_2_std       seconds
# count  695.000000  695.0  695.000000  695.000000    695.000000
# mean     0.010187    0.0   -0.036622    0.041326   5311.395683
# std      0.003734    0.0    0.044299    0.079631   7038.656899
# min      0.010000    0.0   -0.273618    0.000876     62.000000
# 25%      0.010000    0.0   -0.055968    0.008021   1328.500000
# 50%      0.010000    0.0   -0.012395    0.015552   3291.000000
# 75%      0.010000    0.0   -0.005483    0.044381   6636.500000
# max      0.100000    0.0    0.000176    0.842386  63575.000000

# %%
drug_data = pd.concat([drug_data, new_drug_data])
full_data = drug_data.join(data, on='run', rsuffix='_drug')

# %%
data.describe()
# Out:
#                          time  cutoff        drugs            n  test  \
# count                    2819  2820.0  2820.000000  2811.000000   0.0
# mean   0 days 00:56:40.401560     4.0    20.663475     0.099703   NaN
# std    0 days 01:31:10.591949     0.0     4.449856     0.058432   NaN
# min           0 days 00:00:35     4.0     1.000000     0.000000   NaN
# 25%           0 days 00:09:54     4.0    20.000000     0.049250   NaN
# 50%           0 days 00:30:00     4.0    20.000000     0.098271   NaN
# 75%    0 days 01:05:48.500000     4.0    20.000000     0.148706   NaN
# max           1 days 04:49:17     4.0    50.000000     0.248831   NaN
#
#          threshold    step     r_2_mean      r_2_std       seconds
# count  2820.000000  2820.0  2820.000000  2819.000000   2819.000000
# mean      0.010110     0.0     0.138684     0.263361   3369.752394
# std       0.003029     0.0     0.494276     1.672491   5140.193487
# min       0.010000     0.0   -12.995511     0.000012     35.000000
# 25%       0.010000     0.0    -0.013248     0.037092    594.000000
# 50%       0.010000     0.0     0.083728     0.118700   1800.000000
# 75%       0.010000     0.0     0.223126     0.185232   3948.500000
# max       0.100000     0.0     0.999979    58.519798  63575.000000

# %%
ndata[ndata['norm'].notnull()].sort_values('r_2_mean', ascending=False)
# Out:
#             operation             started     time     status  \
# run
# 678f9d02  train:train 2020-04-20 14:38:41 02:23:17  completed
# c817d1c1  train:train 2020-04-20 21:54:10 01:31:26  completed
# 399edb43  train:train 2020-04-22 03:37:12 01:32:16  completed
# b7b72d30  train:train 2020-04-22 23:20:03 01:42:36  completed
# 4b83ffb6  train:train 2020-04-21 18:15:44 00:50:20  completed
# 7cce85ba  train:train 2020-04-25 00:53:30 02:57:31  completed
# ccb9696c  train:train 2020-04-21 09:38:42 03:00:39  completed
# 83a3bd2b  train:train 2020-04-24 09:47:38 00:39:16  completed
# 950ee138  train:train 2020-04-21 20:32:27 00:34:14  completed
# 16bff4a8  train:train 2020-04-25 05:59:35 04:22:33  completed
# 0e5a43e8  train:train 2020-04-24 03:21:43 03:28:14  completed
# bce98971  train:train 2020-04-24 03:48:06 08:03:28  completed
# b7c728ee  train:train 2020-04-25 13:34:43 01:18:15  completed
# ec2a425e  train:train 2020-04-23 07:17:49 00:46:14  completed
# b3228e13  train:train 2020-04-23 03:49:07 00:05:10  completed
# 9396374d  train:train 2020-04-23 00:22:19 01:34:37  completed
# 26277a7c  train:train 2020-04-21 00:35:03 02:27:52  completed
# c74fbbe0  train:train 2020-04-22 04:18:12 01:34:23  completed
# e0df41ff  train:train 2020-04-20 19:01:29 00:07:39  completed
# 982d8b11  train:train 2020-04-29 10:43:23 00:10:08  completed
# df9f1d04  train:train 2020-04-20 12:48:24 00:02:40  completed
# 980c01d7  train:train 2020-04-25 19:58:43 01:12:04  completed
# 0bea2bdc  train:train 2020-04-23 01:57:07 00:04:04  completed
# 64620800  train:train 2020-04-20 18:00:33 00:23:46  completed
# c7c8ed42  train:train 2020-04-21 19:27:56 01:17:17  completed
# 67f81626  train:train 2020-04-23 10:21:17 01:16:10  completed
# 5af81bc5  train:train 2020-04-20 17:08:46 01:31:45  completed
# 22da1f44  train:train 2020-04-25 20:18:41 00:40:05  completed
# 4b3deb36  train:train 2020-04-20 12:04:18 01:23:23  completed
# 2e70e72f  train:train 2020-04-28 15:43:54 01:11:20  completed
# ...               ...                 ...      ...        ...
# 227996ce  train:train 2020-04-22 21:58:43 00:03:00  completed
# 21b6e3e8  train:train 2020-04-20 12:48:05 00:24:14  completed
# 20e001bc  train:train 2020-04-23 09:16:36 00:54:37  completed
# 98de0cfa  train:train 2020-04-20 13:45:50 00:08:13  completed
# 7f2d6e42  train:train 2020-04-23 05:59:50 00:13:48  completed
# 590568d3  train:train 2020-04-22 21:50:26 00:19:18  completed
# 520c0aec  train:train 2020-04-22 19:45:00 00:31:05  completed
# bea9a3a5  train:train 2020-04-20 17:53:10 00:13:46  completed
# b5953438  train:train 2020-04-21 19:19:12 00:17:05  completed
# 2217696f  train:train 2020-04-20 12:48:05 00:08:43  completed
# 81a86370  train:train 2020-04-20 17:08:58 00:04:02  completed
# 9b04d9cb  train:train 2020-04-22 21:50:53 00:51:37  completed
# f741bbf8  train:train 2020-04-21 19:29:19 00:03:57  completed
# 6e716254  train:train 2020-04-21 17:56:14 00:09:46  completed
# a14b5910  train:train 2020-04-23 04:39:08 00:02:09  completed
# 9943f16d  train:train 2020-04-21 19:26:26 00:02:44  completed
# f1d89b20  train:train 2020-04-20 13:57:43 00:07:25  completed
# 587d7ca5  train:train 2020-04-20 14:20:48 00:17:22  completed
# f1adf025  train:train 2020-04-20 19:41:27 00:02:07  completed
# d4df60a5  train:train 2020-04-20 21:45:27 00:12:26  completed
# 546b05f9  train:train 2020-04-20 14:10:43 00:07:29  completed
# 2cb9fab6  train:train 2020-04-23 02:52:24 00:06:18  completed
# 5e7b5693  train:train 2020-04-20 20:56:41 00:16:38  completed
# 36046953  train:train 2020-04-22 23:48:10 00:00:46  completed
# 076c3815  train:train 2020-04-20 19:41:27 00:32:06  completed
# e3c5e095  train:train 2020-04-20 13:44:10 00:32:42  completed
# aecf4a6a  train:train 2020-04-20 13:16:13 00:17:37  completed
# e980401e  train:train 2020-04-20 14:52:53 00:36:07  completed
# e161bae0  train:train 2020-04-28 16:07:51 00:01:40  completed
# 85aa66c0  train:train 2020-04-20 17:08:58 00:14:45  completed
#
#                                                       label   ccle   ctrp  \
# run
# 678f9d02  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# c817d1c1  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 399edb43  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# b7b72d30  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 4b83ffb6  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 7cce85ba  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# ccb9696c  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 83a3bd2b  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 950ee138  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 16bff4a8  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 0e5a43e8  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# bce98971  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# b7c728ee  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# ec2a425e  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# b3228e13  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 9396374d  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 26277a7c  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# c74fbbe0  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# e0df41ff  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 982d8b11  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# df9f1d04  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 980c01d7  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 0bea2bdc  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 64620800  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# c7c8ed42  ccle=yes ctrp=no cutoff=4 drugs=20 feda=no fs=...   True  False
# 67f81626  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 5af81bc5  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 22da1f44  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 4b3deb36  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 2e70e72f  ccle=yes ctrp=no cutoff=4 drugs=20 feda=no fs=...   True  False
# ...                                                     ...    ...    ...
# 227996ce  ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...   True  False
# 21b6e3e8  ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...   True  False
# 20e001bc  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# 98de0cfa  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# 7f2d6e42  ccle=no ctrp=no cutoff=4 drugs=20 feda=no fs=f...  False  False
# 590568d3  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# 520c0aec  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# bea9a3a5  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=no fs...   True   True
# b5953438  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# 2217696f  ccle=no ctrp=no cutoff=4 drugs=20 feda=yes fs=...  False  False
# 81a86370  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# 9b04d9cb  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=no fs...   True   True
# f741bbf8  ccle=no ctrp=no cutoff=4 drugs=20 feda=no fs=f...  False  False
# 6e716254  ccle=no ctrp=no cutoff=4 drugs=20 feda=no fs=L...  False  False
# a14b5910  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 9943f16d  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# f1d89b20  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 587d7ca5  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# f1adf025  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# d4df60a5  ccle=no ctrp=no cutoff=4 drugs=20 feda=yes fs=...  False  False
# 546b05f9  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=no fs...   True   True
# 2cb9fab6  ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...   True  False
# 5e7b5693  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# 36046953  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 076c3815  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# e3c5e095  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# aecf4a6a  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# e980401e  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# e161bae0  ccle=no ctrp=yes cutoff=4 drugs=20 feda=no fs=...  False   True
# 85aa66c0  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
#
#           cutoff  drugs   feda  ...                  model         n  \
# run                             ...
# 678f9d02     4.0   20.0  False  ...  RandomForestRegressor  0.141642
# c817d1c1     4.0   20.0  False  ...                    SVR  0.061395
# 399edb43     4.0   20.0  False  ...             ElasticNet  0.098535
# b7b72d30     4.0   20.0  False  ...    KNeighborsRegressor  0.066072
# 4b83ffb6     4.0   20.0  False  ...             ElasticNet  0.125826
# 7cce85ba     4.0   20.0  False  ...    KNeighborsRegressor  0.074267
# ccb9696c     4.0   20.0  False  ...  RandomForestRegressor  0.119352
# 83a3bd2b     4.0   20.0  False  ...    KNeighborsRegressor  0.011392
# 950ee138     4.0   20.0  False  ...             ElasticNet  0.032061
# 16bff4a8     4.0   20.0  False  ...    KNeighborsRegressor  0.110154
# 0e5a43e8     4.0   20.0  False  ...    KNeighborsRegressor  0.099212
# bce98971     4.0   20.0  False  ...    KNeighborsRegressor  0.162228
# b7c728ee     4.0   20.0  False  ...    KNeighborsRegressor  0.009046
# ec2a425e     4.0   20.0  False  ...             ElasticNet  0.076502
# b3228e13     4.0   20.0  False  ...                    SVR  0.070809
# 9396374d     4.0   20.0  False  ...  RandomForestRegressor  0.114966
# 26277a7c     4.0   20.0  False  ...                    SVR  0.010026
# c74fbbe0     4.0   20.0  False  ...             ElasticNet  0.106307
# e0df41ff     4.0   20.0  False  ...    KNeighborsRegressor  0.078955
# 982d8b11     4.0   20.0  False  ...                    SVR  0.179228
# df9f1d04     4.0   20.0  False  ...  RandomForestRegressor  0.039672
# 980c01d7     4.0   20.0  False  ...             ElasticNet  0.036885
# 0bea2bdc     4.0   20.0  False  ...  RandomForestRegressor  0.069676
# 64620800     4.0   20.0  False  ...             ElasticNet  0.047648
# c7c8ed42     4.0   20.0  False  ...             ElasticNet  0.092280
# 67f81626     4.0   20.0  False  ...             ElasticNet  0.043930
# 5af81bc5     4.0   20.0  False  ...  RandomForestRegressor  0.105178
# 22da1f44     4.0   20.0  False  ...             ElasticNet  0.078103
# 4b3deb36     4.0   20.0  False  ...             ElasticNet  0.022807
# 2e70e72f     4.0   20.0  False  ...             ElasticNet  0.080024
# ...          ...    ...    ...  ...                    ...       ...
# 227996ce     4.0   20.0   True  ...  DecisionTreeRegressor  0.026365
# 21b6e3e8     4.0   20.0   True  ...  DecisionTreeRegressor  0.112857
# 20e001bc     4.0   20.0   True  ...  DecisionTreeRegressor  0.116414
# 98de0cfa     4.0   20.0   True  ...  DecisionTreeRegressor  0.075507
# 7f2d6e42     4.0   20.0  False  ...  DecisionTreeRegressor  0.123347
# 590568d3     4.0   20.0   True  ...                    SVR  0.089946
# 520c0aec     4.0   20.0  False  ...  DecisionTreeRegressor  0.122894
# bea9a3a5     4.0   20.0  False  ...                    SVR  0.069203
# b5953438     4.0   20.0   True  ...  DecisionTreeRegressor  0.073721
# 2217696f     4.0   20.0   True  ...  DecisionTreeRegressor  0.035541
# 81a86370     4.0   20.0   True  ...                    SVR  0.022157
# 9b04d9cb     4.0   20.0  False  ...                    SVR  0.060983
# f741bbf8     4.0   20.0  False  ...  DecisionTreeRegressor  0.038958
# 6e716254     4.0   20.0  False  ...  DecisionTreeRegressor  0.149825
# a14b5910     4.0   20.0  False  ...  DecisionTreeRegressor  0.057591
# 9943f16d     4.0   20.0   True  ...  DecisionTreeRegressor  0.004648
# f1d89b20     4.0   20.0  False  ...  DecisionTreeRegressor  0.162670
# 587d7ca5     4.0   20.0   True  ...  DecisionTreeRegressor  0.177286
# f1adf025     4.0   20.0  False  ...  DecisionTreeRegressor  0.110765
# d4df60a5     4.0   20.0   True  ...                    SVR  0.045107
# 546b05f9     4.0   20.0  False  ...  DecisionTreeRegressor  0.045362
# 2cb9fab6     4.0   20.0   True  ...                    SVR  0.073480
# 5e7b5693     4.0   20.0   True  ...  DecisionTreeRegressor  0.143987
# 36046953     4.0   20.0  False  ...                    SVR  0.035029
# 076c3815     4.0   20.0  False  ...  DecisionTreeRegressor  0.190056
# e3c5e095     4.0   20.0  False  ...  DecisionTreeRegressor  0.070644
# aecf4a6a     4.0   20.0   True  ...  DecisionTreeRegressor  0.162714
# e980401e     4.0   20.0   True  ...  DecisionTreeRegressor  0.157931
# e161bae0     4.0   20.0  False  ...             ElasticNet  0.096593
# 85aa66c0     4.0   20.0   True  ...                    SVR  0.009067
#
#                          norm test  threshold step   r_2_mean    r_2_std  \
# run
# 678f9d02  QuantileTransformer  NaN       0.01  0.0   0.394109   0.218128
# c817d1c1  QuantileTransformer  NaN       0.01  0.0   0.391546   0.176993
# 399edb43  QuantileTransformer  NaN       0.01  0.0   0.386600   0.218185
# b7b72d30         MaxAbsScaler  NaN       0.01  0.0   0.380133   0.239234
# 4b83ffb6  QuantileTransformer  NaN       0.01  0.0   0.375033   0.200046
# 7cce85ba         MaxAbsScaler  NaN       0.01  0.0   0.373889   0.189286
# ccb9696c  QuantileTransformer  NaN       0.01  0.0   0.373249   0.136731
# 83a3bd2b         MinMaxScaler  NaN       0.01  0.0   0.363057   0.227744
# 950ee138  QuantileTransformer  NaN       0.01  0.0   0.360887   0.239003
# 16bff4a8         MaxAbsScaler  NaN       0.01  0.0   0.358903   0.219234
# 0e5a43e8         MaxAbsScaler  NaN       0.01  0.0   0.358217   0.211575
# bce98971  QuantileTransformer  NaN       0.01  0.0   0.345183   0.199722
# b7c728ee         MinMaxScaler  NaN       0.01  0.0   0.341874   0.258741
# ec2a425e  QuantileTransformer  NaN       0.01  0.0   0.336492   0.232892
# b3228e13         MaxAbsScaler  NaN       0.01  0.0   0.335894   0.165657
# 9396374d         MinMaxScaler  NaN       0.01  0.0   0.327136   0.228150
# 26277a7c         MinMaxScaler  NaN       0.01  0.0   0.323529   0.250833
# c74fbbe0         MinMaxScaler  NaN       0.01  0.0   0.317594   0.190351
# e0df41ff       StandardScaler  NaN       0.01  0.0   0.316827   0.163746
# 982d8b11         MinMaxScaler  NaN       0.01  0.0   0.315870   0.240013
# df9f1d04       StandardScaler  NaN       0.01  0.0   0.315154   0.251800
# 980c01d7         MaxAbsScaler  NaN       0.01  0.0   0.314991   0.239198
# 0bea2bdc       StandardScaler  NaN       0.01  0.0   0.311299   0.174748
# 64620800         MaxAbsScaler  NaN       0.01  0.0   0.310541   0.233453
# c7c8ed42  QuantileTransformer  NaN       0.01  0.0   0.305459   0.116538
# 67f81626         MinMaxScaler  NaN       0.01  0.0   0.304457   0.193752
# 5af81bc5         MinMaxScaler  NaN       0.01  0.0   0.303067   0.193708
# 22da1f44         MaxAbsScaler  NaN       0.01  0.0   0.302023   0.210399
# 4b3deb36         MaxAbsScaler  NaN       0.01  0.0   0.301998   0.259965
# 2e70e72f  QuantileTransformer  NaN       0.01  0.0   0.300366   0.125960
# ...                       ...  ...        ...  ...        ...        ...
# 227996ce       StandardScaler  NaN       0.01  0.0  -0.206756   0.452441
# 21b6e3e8  QuantileTransformer  NaN       0.01  0.0  -0.207493   0.253208
# 20e001bc         MaxAbsScaler  NaN       0.01  0.0  -0.209435   0.382557
# 98de0cfa         MinMaxScaler  NaN       0.01  0.0  -0.211710   0.497777
# 7f2d6e42         MaxAbsScaler  NaN       0.01  0.0  -0.213422   0.302445
# 590568d3         MinMaxScaler  NaN       0.01  0.0  -0.215952   0.898543
# 520c0aec  QuantileTransformer  NaN       0.01  0.0  -0.222217   0.702355
# bea9a3a5  QuantileTransformer  NaN       0.01  0.0  -0.228784   0.514250
# b5953438         MinMaxScaler  NaN       0.01  0.0  -0.240289   0.462672
# 2217696f         MinMaxScaler  NaN       0.01  0.0  -0.241573   0.524464
# 81a86370         MaxAbsScaler  NaN       0.01  0.0  -0.246424   0.792094
# 9b04d9cb  QuantileTransformer  NaN       0.01  0.0  -0.248810   0.628906
# f741bbf8         MaxAbsScaler  NaN       0.01  0.0  -0.254048   0.569399
# 6e716254         MinMaxScaler  NaN       0.01  0.0  -0.255236   0.564529
# a14b5910       StandardScaler  NaN       0.01  0.0  -0.262464   0.471556
# 9943f16d         MinMaxScaler  NaN       0.01  0.0  -0.273618   0.842386
# f1d89b20         MaxAbsScaler  NaN       0.01  0.0  -0.276587   0.444694
# 587d7ca5         MaxAbsScaler  NaN       0.01  0.0  -0.283986   0.653247
# f1adf025       StandardScaler  NaN       0.01  0.0  -0.289418   0.998260
# d4df60a5  QuantileTransformer  NaN       0.01  0.0  -0.291673   1.556217
# 546b05f9         MaxAbsScaler  NaN       0.01  0.0  -0.331440   1.295494
# 2cb9fab6         MaxAbsScaler  NaN       0.01  0.0  -0.337705   2.135088
# 5e7b5693  QuantileTransformer  NaN       0.01  0.0  -0.342574   0.387487
# 36046953         MinMaxScaler  NaN       0.01  0.0  -0.370496   1.139027
# 076c3815  QuantileTransformer  NaN       0.01  0.0  -0.463181   1.171484
# e3c5e095         MaxAbsScaler  NaN       0.01  0.0  -0.481483   1.023558
# aecf4a6a         MaxAbsScaler  NaN       0.01  0.0  -0.584404   0.589324
# e980401e         MinMaxScaler  NaN       0.01  0.0  -0.614623   1.121830
# e161bae0       StandardScaler  NaN       0.01  0.0  -0.970719   4.220925
# 85aa66c0         MinMaxScaler  NaN       0.01  0.0 -10.539266  41.080799
#
#           seconds  datasets
# run
# 678f9d02   8597.0         2
# c817d1c1   5486.0         2
# 399edb43   5536.0         2
# b7b72d30   6156.0         2
# 4b83ffb6   3020.0         2
# 7cce85ba  10651.0         2
# ccb9696c  10839.0         2
# 83a3bd2b   2356.0         2
# 950ee138   2054.0         2
# 16bff4a8  15753.0         2
# 0e5a43e8  12494.0         2
# bce98971  29008.0         2
# b7c728ee   4695.0         2
# ec2a425e   2774.0         2
# b3228e13    310.0         2
# 9396374d   5677.0         2
# 26277a7c   8872.0         2
# c74fbbe0   5663.0         2
# e0df41ff    459.0         2
# 982d8b11    608.0         2
# df9f1d04    160.0         2
# 980c01d7   4324.0         2
# 0bea2bdc    244.0         2
# 64620800   1426.0         2
# c7c8ed42   4637.0         2
# 67f81626   4570.0         2
# 5af81bc5   5505.0         2
# 22da1f44   2405.0         2
# 4b3deb36   5003.0         2
# 2e70e72f   4280.0         2
# ...           ...       ...
# 227996ce    180.0         1
# 21b6e3e8   1454.0         1
# 20e001bc   3277.0         2
# 98de0cfa    493.0         1
# 7f2d6e42    828.0         1
# 590568d3   1158.0         1
# 520c0aec   1865.0         1
# bea9a3a5    826.0         2
# b5953438   1025.0         1
# 2217696f    523.0         1
# 81a86370    242.0         2
# 9b04d9cb   3097.0         2
# f741bbf8    237.0         1
# 6e716254    586.0         1
# a14b5910    129.0         1
# 9943f16d    164.0         2
# f1d89b20    445.0         1
# 587d7ca5   1042.0         1
# f1adf025    127.0         1
# d4df60a5    746.0         1
# 546b05f9    449.0         2
# 2cb9fab6    378.0         1
# 5e7b5693    998.0         1
# 36046953     46.0         1
# 076c3815   1926.0         1
# e3c5e095   1962.0         1
# aecf4a6a   1057.0         1
# e980401e   2167.0         1
# e161bae0    100.0         1
# 85aa66c0    885.0         1
#
# [883 rows x 23 columns]

# %% [markdown]
# ## FEDA t-test

# %%
data[data['fs']=='Lasso'][['model', 'feda','r_2_mean']]
# Out:
#                           model   feda  r_2_mean
# run
# acbbf2bd    KNeighborsRegressor   True  0.026389
# ddc1fcee             ElasticNet  False  0.212919
# f15866de             ElasticNet  False  0.038551
# 9fe7654e  DecisionTreeRegressor   True -0.183967
# 5e7b5693  DecisionTreeRegressor   True -0.342574
# ...                         ...    ...       ...
# ec5e4047  DecisionTreeRegressor  False  0.999100
# 81ec90e7  DecisionTreeRegressor  False  0.999535
# dde14bbd  DecisionTreeRegressor  False  0.999529
# 7dc18ca8    KNeighborsRegressor   True  0.996150
# 7a25e42c    KNeighborsRegressor  False  0.999677
#
# [196 rows x 3 columns]

# %%
ndata[(ndata['feda']==False)&(~ndata['model'].isin(['SVR', 'ElasticNet']))]['r_2_mean'].mean()
# Out:
# 0.11587292792107694

# %%
ndata[(ndata['feda']==True)&(~ndata['model'].isin(['SVR', 'ElasticNet']))]['r_2_mean'].mean()
# Out:
# -0.0038146281337004995

# %%
from scipy import stats
stats.ttest_ind(data[data['metric']=='AUC_IC50']['r_2_mean'].values, data[data['metric']!='AUC_IC50']['r_2_mean'].values)
# Out:
# Ttest_indResult(statistic=-0.3913970844859045, pvalue=0.6955567243773826)

# %%
stats.ttest_ind(ndata[ndata['feda']==True]['r_2_mean'].values, ndata[ndata['feda']==False]['r_2_mean'].values, equal_var=False)
# Out:
# Ttest_indResult(statistic=-9.375550795860045, pvalue=5.019565164007916e-19)

# %% [markdown]
# ## Model composition

# %%
models = data.groupby('model').mean()
models['Number of runs'] = [data[data['model']==i].shape[0] for i in models.index]
models
# Out:
#                        cutoff      drugs         n  test  threshold  step  \
# model
# DecisionTreeRegressor     4.0  19.961616  0.096877   NaN   0.010000   0.0
# ElasticNet                4.0  20.000000  0.095670   NaN   0.010000   0.0
# KNeighborsRegressor       4.0  20.000000  0.092033   NaN   0.010000   0.0
# RandomForestRegressor     4.0  20.000000  0.094340   NaN   0.010000   0.0
# SVR                       4.0  23.327465  0.118070   NaN   0.010546   0.0
#
#                        r_2_mean   r_2_std      seconds  Number of runs
# model
# DecisionTreeRegressor  0.175909  0.184037  2027.828283             495
# ElasticNet             0.116151  0.107175  2236.716157             916
# KNeighborsRegressor    0.119621  0.106173  9850.083333             288
# RandomForestRegressor  0.294086  0.092262  4389.613020             553
# SVR                    0.000950  0.830511  2085.440917             568

# %%
ndata[ndata['norm'].notnull()].shape
# Out:
# (923, 23)

# %%
nmodels = data[data['started'] > pd.to_datetime('2020-04-15 18:00:00')].groupby('model').mean()
nmodels['Number of runs'] = [data[(data['model']==i) & (data['started'] > pd.to_datetime('2020-04-15 18:00:00'))].shape[0] for i in nmodels.index]
nmodels
# Out:
#                        cutoff  drugs         n  test  threshold  step  \
# model
# DecisionTreeRegressor     4.0   20.0  0.095266   NaN       0.01   0.0
# ElasticNet                4.0   20.0  0.093522   NaN       0.01   0.0
# KNeighborsRegressor       4.0   20.0  0.093337   NaN       0.01   0.0
# RandomForestRegressor     4.0   20.0  0.090055   NaN       0.01   0.0
# SVR                       4.0   20.0  0.112966   NaN       0.01   0.0
#
#                        r_2_mean   r_2_std       seconds  Number of runs
# model
# DecisionTreeRegressor -0.077297  0.253204   1990.424615             325
# ElasticNet             0.091800  0.097221   2544.857651             562
# KNeighborsRegressor    0.102191  0.108939  10295.411321             265
# RandomForestRegressor  0.117742  0.116893   4417.362069             406
# SVR                   -0.070615  0.697170   2163.361478             379

# %%
nmodels = data[data['started'] > pd.to_datetime('2020-04-15 18:00:00')].groupby(['model', 'fs']).mean()
nmodels['Number of runs'] = [ndata[(ndata['model']==i[0]) & (ndata['fs']==i[1]) & (ndata['started'] > pd.to_datetime('2020-04-15 18:00:00'))].shape[0] for i in nmodels.index]
nmodels
# Out:
#                                               cutoff  drugs         n  test  \
# model                 fs
# DecisionTreeRegressor ElasticNet                 4.0   20.0  0.092746   NaN
#                       Lasso                      4.0   20.0  0.091461   NaN
#                       RandomForestRegressor      4.0   20.0  0.106888   NaN
#                       f_regression               4.0   20.0  0.096230   NaN
#                       mutual_info_regression     4.0   20.0  0.088843   NaN
# ElasticNet            DecisionTreeRegressor      4.0   20.0  0.092954   NaN
#                       Lasso                      4.0   20.0  0.089914   NaN
#                       RandomForestRegressor      4.0   20.0  0.091076   NaN
#                       f_regression               4.0   20.0  0.095004   NaN
#                       mutual_info_regression     4.0   20.0  0.099319   NaN
# KNeighborsRegressor   DecisionTreeRegressor      4.0   20.0  0.095376   NaN
#                       ElasticNet                 4.0   20.0  0.101517   NaN
#                       Lasso                      4.0   20.0  0.087990   NaN
#                       RandomForestRegressor      4.0   20.0  0.082220   NaN
#                       f_regression               4.0   20.0  0.095046   NaN
#                       mutual_info_regression     4.0   20.0  0.097676   NaN
# RandomForestRegressor DecisionTreeRegressor      4.0   20.0  0.084889   NaN
#                       ElasticNet                 4.0   20.0  0.088234   NaN
#                       Lasso                      4.0   20.0  0.091052   NaN
#                       f_regression               4.0   20.0  0.097112   NaN
#                       mutual_info_regression     4.0   20.0  0.087512   NaN
# SVR                   DecisionTreeRegressor      4.0   20.0  0.120953   NaN
#                       ElasticNet                 4.0   20.0  0.108686   NaN
#                       Lasso                      4.0   20.0  0.120958   NaN
#                       RandomForestRegressor      4.0   20.0  0.106283   NaN
#                       f_regression               4.0   20.0  0.105371   NaN
#                       mutual_info_regression     4.0   20.0  0.114274   NaN
#
#                                               threshold  step  r_2_mean  \
# model                 fs
# DecisionTreeRegressor ElasticNet                   0.01   0.0 -0.065991
#                       Lasso                        0.01   0.0 -0.097438
#                       RandomForestRegressor        0.01   0.0 -0.110483
#                       f_regression                 0.01   0.0 -0.047285
#                       mutual_info_regression       0.01   0.0 -0.071775
# ElasticNet            DecisionTreeRegressor        0.01   0.0  0.092580
#                       Lasso                        0.01   0.0  0.086706
#                       RandomForestRegressor        0.01   0.0  0.097208
#                       f_regression                 0.01   0.0  0.083539
#                       mutual_info_regression       0.01   0.0  0.100263
# KNeighborsRegressor   DecisionTreeRegressor        0.01   0.0  0.114027
#                       ElasticNet                   0.01   0.0  0.085021
#                       Lasso                        0.01   0.0  0.097808
#                       RandomForestRegressor        0.01   0.0  0.112384
#                       f_regression                 0.01   0.0  0.084948
#                       mutual_info_regression       0.01   0.0  0.125733
# RandomForestRegressor DecisionTreeRegressor        0.01   0.0  0.093433
#                       ElasticNet                   0.01   0.0  0.103799
#                       Lasso                        0.01   0.0  0.117210
#                       f_regression                 0.01   0.0  0.126952
#                       mutual_info_regression       0.01   0.0  0.147020
# SVR                   DecisionTreeRegressor        0.01   0.0  0.024256
#                       ElasticNet                   0.01   0.0 -0.047846
#                       Lasso                        0.01   0.0 -0.278309
#                       RandomForestRegressor        0.01   0.0  0.016924
#                       f_regression                 0.01   0.0 -0.065238
#                       mutual_info_regression       0.01   0.0  0.001865
#
#                                                r_2_std       seconds  \
# model                 fs
# DecisionTreeRegressor ElasticNet              0.208554   1527.653333
#                       Lasso                   0.231564   1520.545455
#                       RandomForestRegressor   0.355750   3178.516667
#                       f_regression            0.236814   1086.054795
#                       mutual_info_regression  0.249692   3175.784314
# ElasticNet            DecisionTreeRegressor   0.080173   2438.700000
#                       Lasso                   0.078432   1688.495726
#                       RandomForestRegressor   0.092658   3163.695652
#                       f_regression            0.139806   1573.889831
#                       mutual_info_regression  0.093035   4067.205882
# KNeighborsRegressor   DecisionTreeRegressor   0.106985  10096.395833
#                       ElasticNet              0.120822  10198.200000
#                       Lasso                   0.099410  10986.630435
#                       RandomForestRegressor   0.113891  10038.461538
#                       f_regression            0.104001   9294.890909
#                       mutual_info_regression  0.112594  11557.432432
# RandomForestRegressor DecisionTreeRegressor   0.115920   4625.869048
#                       ElasticNet              0.112075   4107.835821
#                       Lasso                   0.127404   3429.170455
#                       f_regression            0.115497   3599.881720
#                       mutual_info_regression  0.111617   6663.445946
# SVR                   DecisionTreeRegressor   0.372443   2329.109091
#                       ElasticNet              0.487869   1524.014493
#                       Lasso                   1.571454    705.037975
#                       RandomForestRegressor   0.403204   3824.067797
#                       f_regression            0.587764   2432.783333
#                       mutual_info_regression  0.471582   2795.982456
#
#                                               Number of runs
# model                 fs
# DecisionTreeRegressor ElasticNet                          75
#                       Lasso                               66
#                       RandomForestRegressor               60
#                       f_regression                        73
#                       mutual_info_regression              51
# ElasticNet            DecisionTreeRegressor              110
#                       Lasso                              117
#                       RandomForestRegressor              115
#                       f_regression                       118
#                       mutual_info_regression             102
# KNeighborsRegressor   DecisionTreeRegressor               48
#                       ElasticNet                          40
#                       Lasso                               46
#                       RandomForestRegressor               39
#                       f_regression                        55
#                       mutual_info_regression              37
# RandomForestRegressor DecisionTreeRegressor               84
#                       ElasticNet                          67
#                       Lasso                               88
#                       f_regression                        93
#                       mutual_info_regression              74
# SVR                   DecisionTreeRegressor               55
#                       ElasticNet                          69
#                       Lasso                               79
#                       RandomForestRegressor               59
#                       f_regression                        60
#                       mutual_info_regression              57

# %%
ndata.groupby('datasets').max()
# Out:
#             operation             started            time     status  \
# datasets
# 1         train:train 2020-04-29 14:56:20 0 days 15:11:42  completed
# 2         train:train 2020-04-29 13:22:49 1 days 04:49:17  completed
# 3         train:train 2020-04-29 14:28:55 0 days 17:16:36  completed
#
#                                                       label  ccle  ctrp  \
# datasets
# 1         ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...  True  True
# 2         ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...  True  True
# 3         ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...  True  True
#
#           cutoff  drugs  feda  ...  gdsc    metric model         n  test  \
# datasets                       ...
# 1            4.0   20.0  True  ...  True  AUC_IC50   SVR  0.199592   NaN
# 2            4.0   20.0  True  ...  True  AUC_IC50   SVR  0.199802   NaN
# 3            4.0   20.0  True  ...  True  AUC_IC50   SVR  0.199700   NaN
#
#           threshold  step  r_2_mean    r_2_std  seconds
# datasets
# 1              0.01   0.0  0.221530  42.588642  54702.0
# 2              0.01   0.0  0.409924   1.295494  63575.0
# 3              0.01   0.0  0.273208   0.354959  62196.0
#
# [3 rows x 21 columns]

# %%
norm = ndata.groupby(['model', 'norm']).max()
norm['Number of runs'] = [ndata[(ndata['model']==i[0])&(ndata['norm']==i[1])].shape[0] for i in norm.index]

# %%
norm.loc['SVR', 'QuantileTransformer']
# Out:
# operation                                               train:train
# started                                         2020-04-20 21:54:10
# time                                                0 days 01:31:26
# status                                                    completed
# label             ccle=yes ctrp=yes cutoff=4 drugs=20 feda=no fs...
# ccle                                                           True
# ctrp                                                           True
# cutoff                                                            4
# drugs                                                            20
# feda                                                           True
# fs                                           mutual_info_regression
# gdsc                                                           True
# metric                                                     AUC_IC50
# n                                                         0.0802049
# test                                                            NaN
# threshold                                                      0.01
# step                                                              0
# r_2_mean                                                   0.391546
# r_2_std                                                     1.55622
# seconds                                                        5486
# datasets                                                          2
# Number of runs                                                    5
# Name: (SVR, QuantileTransformer), dtype: object

# %%
stats.ttest_ind(ndata[ndata['norm'].notnull()]['r_2_mean'].values, ndata[~ndata['norm'].notnull()]['r_2_mean'].values, equal_var=False)
# Out:
# Ttest_indResult(statistic=-1.8743103650682442, pvalue=0.062111994287563865)

# %% [markdown]
# ## Per model

# %%
ndata[(ndata['feda']==True)&(ndata['datasets']>1)].sort_values('r_2_mean', ascending=False)
# Out:
#             operation             started     time     status  \
# run
# 0d238804  train:train 2020-04-16 05:51:03 01:40:36  completed
# 51241a74  train:train 2020-04-17 02:59:27 00:15:25  completed
# 0b35dc5d  train:train 2020-04-16 04:46:41 01:41:16  completed
# 5ff47509  train:train 2020-04-16 01:48:47 01:05:08  completed
# a2001ef9  train:train 2020-04-16 05:06:57 03:58:31  completed
# ...               ...                 ...      ...        ...
# 7cca510a  train:train 2020-04-18 13:07:13 00:44:52  completed
# 26d60d3b  train:train 2020-04-19 17:20:57 00:48:47  completed
# 9e0cc091  train:train 2020-04-19 17:56:20 02:35:00  completed
# 2a0a8def  train:train 2020-04-19 19:03:19 00:44:07  completed
# 5e36c60f  train:train 2020-04-19 18:18:44 00:20:34  completed
#
#                                                       label   ccle   ctrp  \
# run
# 0d238804  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# 51241a74  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# 0b35dc5d  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# 5ff47509  ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...   True  False
# a2001ef9  ccle=no ctrp=yes cutoff=4 drugs=20 feda=yes fs...  False   True
# ...                                                     ...    ...    ...
# 7cca510a  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# 26d60d3b  ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes f...   True   True
# 9e0cc091  ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...   True  False
# 2a0a8def  ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...   True  False
# 5e36c60f  ccle=yes ctrp=no cutoff=4 drugs=20 feda=yes fs...   True  False
#
#           cutoff  drugs  feda  ...                  model         n norm test  \
# run                            ...
# 0d238804     4.0   20.0  True  ...             ElasticNet  0.159352  NaN  NaN
# 51241a74     4.0   20.0  True  ...             ElasticNet  0.031760  NaN  NaN
# 0b35dc5d     4.0   20.0  True  ...             ElasticNet  0.129060  NaN  NaN
# 5ff47509     4.0   20.0  True  ...             ElasticNet  0.120254  NaN  NaN
# a2001ef9     4.0   20.0  True  ...  RandomForestRegressor  0.160064  NaN  NaN
# ...          ...    ...   ...  ...                    ...       ...  ...  ...
# 7cca510a     4.0   20.0  True  ...                    SVR  0.023019  NaN  NaN
# 26d60d3b     4.0   20.0  True  ...  DecisionTreeRegressor  0.009347  NaN  NaN
# 9e0cc091     4.0   20.0  True  ...  DecisionTreeRegressor  0.172456  NaN  NaN
# 2a0a8def     4.0   20.0  True  ...  DecisionTreeRegressor  0.119520  NaN  NaN
# 5e36c60f     4.0   20.0  True  ...  DecisionTreeRegressor  0.043906  NaN  NaN
#
#           threshold step  r_2_mean   r_2_std  seconds  datasets
# run
# 0d238804       0.01  0.0 -0.001914  0.001383   6036.0         3
# 51241a74       0.01  0.0 -0.002197  0.002287    925.0         2
# 0b35dc5d       0.01  0.0 -0.002357  0.002823   6076.0         2
# 5ff47509       0.01  0.0 -0.002631  0.002777   3908.0         2
# a2001ef9       0.01  0.0 -0.003089  0.007976  14311.0         2
# ...             ...  ...       ...       ...      ...       ...
# 7cca510a       0.01  0.0 -0.142764  0.272121   2692.0         2
# 26d60d3b       0.01  0.0 -0.146341  0.282566   2927.0         2
# 9e0cc091       0.01  0.0 -0.148571  0.111783   9300.0         2
# 2a0a8def       0.01  0.0 -0.155403  0.181256   2647.0         2
# 5e36c60f       0.01  0.0 -0.155955  0.213443   1234.0         2
#
# [116 rows x 23 columns]

# %%
ndata.loc['51241a74']['label']
# Out:
# 'ccle=yes ctrp=yes cutoff=4 drugs=20 feda=yes fs=Lasso gdsc=no metric=AUC_IC50 model=ElasticNet n=0.03176 threshold=0.01'

# %% [markdown]
# ## Individual drug analysis

# %%
svr = data[(data['model'] == 'SVR') & (data['r_2_mean']>0)]
svr[svr['r_2_mean']> 0.6][['feda', 'n', 'fs','r_2_mean']].sort_values('r_2_mean', ascending=False)
# Out:
#            feda         n                      fs  r_2_mean
# run
# c84c194d  False  0.010000              ElasticNet  0.934915
# 8071f94a  False  0.094795   DecisionTreeRegressor  0.922619
# 400d39b7  False  0.098271   DecisionTreeRegressor  0.922580
# d2703cd1  False  0.147682  mutual_info_regression  0.919401
# dfde6ba7  False  0.072084  mutual_info_regression  0.917935
# c889fa24  False  0.087590            f_regression  0.916772
# b1cea166  False  0.003354  mutual_info_regression  0.901983
# e32273a7  False  0.144099              ElasticNet  0.897122
# 9cabe208  False  0.057282   RandomForestRegressor  0.887763
# 817fe23c  False  0.234739              ElasticNet  0.880673
# 1cac9155  False  0.075622   RandomForestRegressor  0.879680
# 9ca97a06  False  0.207309  mutual_info_regression  0.875751
# 71717aac  False  0.083997   RandomForestRegressor  0.874252
# 7595e90f  False  0.186537   RandomForestRegressor  0.873950
# a09332a2  False  0.165444   DecisionTreeRegressor  0.867954
# 495c478b  False  0.091419   RandomForestRegressor  0.867252
# 2c5dd08f  False  0.142545   DecisionTreeRegressor  0.865925
# bd7f70ed  False  0.125951   RandomForestRegressor  0.863635
# f51f0d15  False  0.131659   RandomForestRegressor  0.861257
# a7c0f9cb  False  0.180103   DecisionTreeRegressor  0.860921
# d11b42ff  False  0.134668   RandomForestRegressor  0.859252
# c7c902ea  False  0.090289              ElasticNet  0.858777
# c38d772e  False  0.121895  mutual_info_regression  0.858140
# ffa1a16e  False  0.233662   DecisionTreeRegressor  0.857756
# ce7b8139  False  0.006441  mutual_info_regression  0.850047
# effa2da8  False       NaN            f_regression  0.845099
# 5e73ff68  False  0.089894   RandomForestRegressor  0.842403
# 5bbbd788  False  0.206109   RandomForestRegressor  0.835783
# 59ac77c6  False  0.023710            f_regression  0.816473
# b860f16b  False  0.235075   RandomForestRegressor  0.812622
# a1f57bb0  False  0.197305   RandomForestRegressor  0.811903
# 33b52062  False  0.016721  mutual_info_regression  0.807464
# e244994e  False  0.172284   RandomForestRegressor  0.806879
# d7a232b1  False  0.088963   RandomForestRegressor  0.806771
# 2edb3361  False       NaN            f_regression  0.803451
# 03f01c0a  False  0.167859   RandomForestRegressor  0.803054
# bee8f3c7  False       NaN            f_regression  0.792058
# db9cb686  False  0.114731  mutual_info_regression  0.789706
# f87f4975  False  0.181142   RandomForestRegressor  0.785550
# 697b9b8d  False  0.084761  mutual_info_regression  0.780089
# 7b8999b1  False  0.110294   RandomForestRegressor  0.776557
# e6598d01  False  0.053861   RandomForestRegressor  0.724338
# 952a94a7  False  0.228177              ElasticNet  0.679434
# c4a6f807  False  0.067696              ElasticNet  0.639985
# 4ac958b1   True  0.227109  mutual_info_regression  0.620109
# 00615e23   True  0.071038            f_regression  0.620010

# %%
en = data[(data['model'] == 'ElasticNet') & (data['r_2_mean']>0)]
en[['feda', 'n', 'fs','r_2_mean']].sort_values('r_2_mean', ascending=False)
# Out:
#            feda         n                      fs  r_2_mean
# run
# 150587db  False  0.100081  mutual_info_regression  0.541867
# 140511c0  False  0.006392   DecisionTreeRegressor  0.502989
# 61f79f6a  False  0.146809   DecisionTreeRegressor  0.499752
# a0fd39fd  False  0.161861   DecisionTreeRegressor  0.479983
# d122f81c   True  0.002680   DecisionTreeRegressor  0.445192
# ...         ...       ...                     ...       ...
# ae6aad99   True  0.083612            f_regression  0.030006
# 30aec5a1   True  0.172041  mutual_info_regression  0.029708
# c7025afd  False  0.025666   RandomForestRegressor  0.021164
# 58c98a2d   True  0.039189   RandomForestRegressor  0.019261
# f41ef515  False  0.142023   RandomForestRegressor  0.006351
#
# [327 rows x 4 columns]

# %%
dt = data[(data['model'] == 'DecisionTreeRegressor') & (data['r_2_mean']>0)]
dt[['feda', 'n', 'fs','r_2_mean']].sort_values('r_2_mean', ascending=False)
# Out:
#            feda         n                     fs  r_2_mean
# run
# bb21f1a1  False  0.178835                  Lasso  0.999979
# ffb505bc  False  0.029654                  Lasso  0.999978
# 8ee1461e  False  0.000266                  Lasso  0.999976
# 62069de6  False  0.132054                  Lasso  0.999972
# 43650dda  False  0.073360                  Lasso  0.999966
# ...         ...       ...                    ...       ...
# 25e24ad2  False  0.117603  RandomForestRegressor  0.110713
# b54c0127  False  0.109115             ElasticNet  0.100940
# 1ea7b30d  False  0.018304             ElasticNet  0.056617
# c2c1bbc9  False  0.199108           f_regression  0.043945
# 21f2bd9e  False  0.076134  RandomForestRegressor  0.013338
#
# [134 rows x 4 columns]

# %%
from config import guild
def append(data, run):
    result = pd.DataFrame()
    run = [i for i in run if i not in data['run'].values]
    print(len(run))
    for a in run:
        f = subprocess.run("guild select " +a, shell=True, capture_output=True)
        d = pd.read_csv(guild+'runs/'+f.stdout.decode('utf-8')[:-1]+'/scores.csv')
        d['run'] = [a for i in range(0, d.shape[0])]
        result = pd.concat([result, d])
        
        if len(result) % 50 == 0:
            new = pd.concat([data, result])
            print('Drug data length is {}'.format(len(new)))
            new.to_csv('new_drug')
    new = pd.concat([data, result])
    print('Drug data length is {}'.format(len(new)))
    new.to_csv('new_drug')
    return result

# %%
# %%time
k = append(drug_data, ndata.index)
# Out:
# 688
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Drug data length is 50646
# Drug data length is 52896
# Drug data length is 55496
# Drug data length is 56446
# Drug data length is 57346
# Drug data length is 57646

# %%
ndata.loc['3f9d1cab']

# %%
no = pd.read_csv('data/runs/drug_data.csv')
lo = pd.concat([no, k])

# %%
k.to_csv('new_drug.csv')

# %%
k.shape

# %%
no = pd.read_csv('data/runs/drug_data.csv')
no = no.join(ndata, rsuffix='_drug')
# Out:
#            run   Unnamed: 0  r2_score  mean_absolute_error  \
# 0     46efb220       17-AAG  0.048576             0.182631
# 1     46efb220   Crizotinib -0.054589             0.318273
# 2     46efb220    Erlotinib  0.054720             0.163415
# 3     46efb220     L-685458  0.024931             0.104633
# 4     46efb220    Lapatinib  0.003609             0.186385
# ...        ...          ...       ...                  ...
# 5070  30f1586e   Paclitaxel  0.417166             0.177412
# 5071  30f1586e  Saracatinib  0.166791             0.143612
# 5072  30f1586e  Selumetinib  0.290452             0.147707
# 5073  30f1586e    Sorafenib  0.103364             0.112843
# 5074  30f1586e       TAE684  0.043252             0.202737
#
#       mean_squared_error  median_absolute_error  algorithm  leaf_size  \
# 0               0.050794               0.160040  ball_tree       30.0
# 1               0.120567               0.345793    kd_tree       30.0
# 2               0.044111               0.138618  ball_tree       30.0
# 3               0.025981               0.070908    kd_tree       30.0
# 4               0.054420               0.165393    kd_tree       30.0
# ...                  ...                    ...        ...        ...
# 5070            0.056626               0.123328  ball_tree       30.0
# 5071            0.033232               0.113486  ball_tree       30.0
# 5072            0.038296               0.112335    kd_tree       30.0
# 5073            0.022993               0.078590  ball_tree       30.0
# 5074            0.060140               0.180685  ball_tree       30.0
#
#          metric  metric_params  ...  model   n  norm test  threshold step  \
# 0     minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 1     minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 2     minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 3     minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 4     minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# ...         ...            ...  ...    ...  ..   ...  ...        ...  ...
# 5070  minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 5071  minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 5072  minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 5073  minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
# 5074  minkowski            NaN  ...    NaN NaN   NaN  NaN        NaN  NaN
#
#      r_2_mean  r_2_std  seconds datasets
# 0         NaN      NaN      NaN      NaN
# 1         NaN      NaN      NaN      NaN
# 2         NaN      NaN      NaN      NaN
# 3         NaN      NaN      NaN      NaN
# 4         NaN      NaN      NaN      NaN
# ...       ...      ...      ...      ...
# 5070      NaN      NaN      NaN      NaN
# 5071      NaN      NaN      NaN      NaN
# 5072      NaN      NaN      NaN      NaN
# 5073      NaN      NaN      NaN      NaN
# 5074      NaN      NaN      NaN      NaN
#
# [5075 rows x 72 columns]

# %% [markdown]
# ## Influence of n on r2 mean
# By changing `col` and `hue` to 'fs' one can see the impact depending on the feature selection model use

# %%
sns.set(font_scale=2)
g = sns.lmplot(x='n', y='r2_score', data=ndrug_data[ndrug_data['r2_score']>-1], col='model', hue='model', col_wrap=2, height=12, legend=False)
#plt.savefig('model vs n')

# %%
fig, ax = plt.subplots(figsize = (12,9))
ax.scatter(ndata[ndata['r_2_mean']>-10]['n'], ndata[ndata['r_2_mean']>-10]['r_2_mean'])
ax.set_xlabel('Percentage of features used')
ax.set_ylabel('R2 mean')
plt.tight_layout()
#plt.savefig('Features vs r2')

# %% [markdown]
# ## Violinplots of r2 per model and per Drug (using the top-10 most common)

# %%
sns.set()
plt.figure(figsize = (12,9))
ax = sns.violinplot(x=ndrug_data[ndrug_data['r2_score']>-2]['fs'], y = ndrug_data['r2_score'])
plt.tight_layout()
#plt.savefig('model.png')

# %%
from collections import Counter
count = Counter(ndrug_data['Unnamed: 0'])

def getDrugs(n):
    return [i[0] for i in count.most_common(n)]

# %%
jo = ndrug_data[ndrug_data['Unnamed: 0'].isin(getDrugs(10))]

# %%
plt.figure(figsize = (12,9))
ax = sns.violinplot(x=jo['Unnamed: 0'], y = jo['r2_score'])
ax.set_xlabel('Drug')
plt.tight_layout()
#plt.savefig('drugs.png')

# %%
lo = k.join(ndata, lsuffix='n')

# %%
lo.groupby('model').mean()
# Out:
#                        r2_score  mean_absolute_error  mean_squared_error  \
# model
# DecisionTreeRegressor -0.094432             0.165591            0.049621
# ElasticNet             0.109282             0.152390            0.040928
# KNeighborsRegressor    0.068197             0.152170            0.042126
# RandomForestRegressor  0.108255             0.161446            0.044138
# SVR                    0.015268             0.160099            0.044577
#
#                        median_absolute_error     alpha  l1_ratio  max_iter  \
# model
# DecisionTreeRegressor               0.138739       NaN       NaN       NaN
# ElasticNet                          0.135200  2.924088  0.108212    5000.0
# KNeighborsRegressor                 0.131089       NaN       NaN       NaN
# RandomForestRegressor               0.143393       NaN       NaN       NaN
# SVR                                 0.137407       NaN       NaN      -1.0
#
#                        random_state     tol  max_depth  ...  epsilon  cutoff  \
# model                                                   ...
# DecisionTreeRegressor           NaN     NaN   2.518900  ...      NaN     4.0
# ElasticNet                      NaN  0.0001        NaN  ...      NaN     4.0
# KNeighborsRegressor             NaN     NaN        NaN  ...      NaN     4.0
# RandomForestRegressor           NaN     NaN   4.345299  ...      NaN     4.0
# SVR                             NaN  0.0010        NaN  ...      0.1     4.0
#
#                        drugs         n  test  threshold  step  r_2_mean  \
# model
# DecisionTreeRegressor   20.0  0.090949   NaN       0.01   0.0 -0.094432
# ElasticNet              20.0  0.092379   NaN       0.01   0.0  0.109282
# KNeighborsRegressor     20.0  0.094594   NaN       0.01   0.0  0.068197
# RandomForestRegressor   20.0  0.079032   NaN       0.01   0.0  0.108255
# SVR                     20.0  0.067049   NaN       0.01   0.0  0.015268
#
#                         r_2_std       seconds
# model
# DecisionTreeRegressor  0.338541   3467.963918
# ElasticNet             0.121841   2296.259854
# KNeighborsRegressor    0.107072  10402.251889
# RandomForestRegressor  0.092693   4008.966154
# SVR                    0.295948   1913.851003
#
# [5 rows x 37 columns]
