# %%
full = pd.read_csv('data/runs/full.csv').drop('Unnamed: 0', axis=1)
clean = full[full['Quality']>-0.95]
clean['started'] = pd.to_datetime(clean['started'])
clean = clean[clean['started'] > pd.to_datetime('2020-04-15 18:00:00')]
full['started'] = pd.to_datetime(full['started'])
full = full[full['started'] > pd.to_datetime('2020-04-15 18:00:00')]
# Out:
# /rwthfs/rz/cluster/home/kz035322/Thesis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # ANOVA

# %% [markdown]
# Here we train an ANOVA model on the configurations of the pipeline and their respective drug-agnostic $ r^2 $ to determine which factors lead to a bigger improvement in performance

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
clean = pd.read_csv('data/runs/clean.csv')

# %%
clean.shape
# Out:
# (119804, 77)

# %%
clean[['Drug', 'r2_score']].groupby('Drug').describe().sort_values(('r2_score', 'count'), ascending=False).head()
# Out:
#             r2_score                                                    \
#                count      mean       std       min       25%       50%
# Drug
# Selumetinib   4512.0  0.189548  0.177463 -0.586784  0.003512  0.215650
# Nutlin-3      4480.0  0.042574  0.222276 -1.956753 -0.029524  0.013063
# Paclitaxel    4479.0  0.114114  0.157428 -0.866935 -0.003286  0.121838
# Saracatinib   4452.0  0.089953  0.155960 -1.412134 -0.006891  0.083961
# TAE684        4451.0  0.054032  0.166655 -0.774732 -0.022764  0.016381
#
#
#                   75%       max
# Drug
# Selumetinib  0.337072  0.598656
# Nutlin-3     0.129311  0.738862
# Paclitaxel   0.223766  0.479926
# Saracatinib  0.181256  0.586263
# TAE684       0.126441  0.693535

# %%
clean.columns
# Out:
# Index(['C', 'Drug', 'algorithm', 'alpha', 'bootstrap', 'cache_size', 'coef0',
#        'copy_X', 'criterion', 'degree', 'epsilon', 'fit_intercept', 'gamma',
#        'kernel', 'l1_ratio', 'leaf_size', 'max_depth', 'max_features',
#        'max_iter', 'max_leaf_nodes', 'mean_absolute_error',
#        'mean_squared_error', 'median_absolute_error', 'metric',
#        'metric_params', 'min_impurity_decrease', 'min_impurity_split',
#        'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf',
#        'n_estimators', 'n_jobs', 'n_neighbors', 'normalize', 'oob_score', 'p',
#        'positive', 'precompute', 'presort', 'r2_score', 'random_state', 'run',
#        'selection', 'shrinking', 'splitter', 'tol', 'verbose', 'warm_start',
#        'weights', 'operation', 'started', 'time', 'status', 'label', 'ajive',
#        'ccle', 'ctrp', 'cutoff', 'drugs', 'feda', 'fs', 'gdsc', 'metric_drug',
#        'model', 'n', 'norm', 'test', 'threshold', 'step', 'r_2_mean',
#        'r_2_std', 'seconds', 'datasets', 'Quality', 'r2', 'da', 'catn'],
#       dtype='object')

# %% [markdown]
# # ANOVA

# %% [markdown]
# We start by determining the factors and interaction factors using the patsy formula api

# %%
import patsy
import statsmodels.api as sm
f = 'r2 ~catn +Quality + fs:model + model +catn:model+ +norm:model+da:model+da+ctrp + gdsc + norm+C(datasets)+metric_drug'
y, X = patsy.dmatrices(f,clean.drop('C', axis=1), return_type='dataframe')

# %%
#X.columns

# %% [markdown]
# We drop factors that either don't exist on our model aand those that would cause multicolinearity

# %%
X = X.drop(['fs[T.f_regression]:model[DecisionTreeRegressor]', 'fs[T.ElasticNet]:model[ElasticNet]', 'fs[T.RandomForestRegressor]:model[RandomForestRegressor]'], axis=1)

# %% [markdown]
# We turn the results of the OLS from a `SimpleTable` into a `DataFrame`

# %%
mod = sm.OLS(y, X).fit()
results = pd.DataFrame(mod.summary(alpha=0.01).tables[1].data).set_index(0)
results = results.rename(columns=results.iloc[0])[1:]

# %%
results['[0.005'] = pd.to_numeric(results['[0.005'])
results['0.995]'] = pd.to_numeric(results['0.995]'])

# %% [markdown]
# We plot the factors for which 0 is not within the 99% confidence interval

# %%
results[results['[0.005']*results['0.995]'] > 0].sort_values('coef').head()
# Out:
#                                                 coef    std err          t  \
# 0
# C(datasets)[T.2]                              0.0165      0.002      7.532
# da[T.none]                                    0.0173      0.005      3.775
# fs[T.Lasso]:model[RandomForestRegressor]      0.0180      0.006      2.833
# catn[T.mid]                                   0.0199      0.005      4.014
# fs[T.ElasticNet]:model[SVR]                   0.0217      0.007      2.955
#
#                                            P>|t|  [0.005  0.995]
# 0
# C(datasets)[T.2]                           0.000   0.011   0.022
# da[T.none]                                 0.000   0.005   0.029
# fs[T.Lasso]:model[RandomForestRegressor]   0.005   0.002   0.034
# catn[T.mid]                                0.000   0.007   0.033
# fs[T.ElasticNet]:model[SVR]                0.003   0.003   0.041

# %%
results.shape
# Out:
# (83, 6)

# %% [markdown]
# We see 42 interaction factors are not significant (0 is within their 99% confidence interval)

# %%
results[results['[0.005']*results['0.995]'] > 0].sort_values('coef').shape
# Out:
# (36, 6)

# %% [markdown]
# We drop non-significant factors

# %%
drop = list(results[results['[0.005']*results['0.995]'] < 0].index)
drop = [i for i in drop if ':' in i]
X = X.drop(drop, axis=1)

# %% [markdown]
# Then retrain the OLS model

# %%
mod = sm.OLS(y, X).fit()
results = pd.DataFrame(mod.summary(alpha=0.01).tables[1].data).set_index(0)
results = results.rename(columns=results.iloc[0])[1:]
results['[0.005'] = pd.to_numeric(results['[0.005'])
results['0.995]'] = pd.to_numeric(results['0.995]'])
results['coef'] = pd.to_numeric(results['coef'])

# %%
anova = results[results['[0.005']*results['0.995]'] > 0]
anova = anova.sort_values('coef').reset_index().rename(columns={0:'factor'})

# %%
anova
# Out:
#                                                factor    coef    std err  \
# 0                                           Intercept -0.1704      0.005
# 1                                          da[T.feda] -0.0872      0.004
# 2                 norm[T.StandardScaler]:model[T.SVR] -0.0850      0.011
# 3   norm[T.StandardScaler]:model[T.RandomForestReg... -0.0824      0.010
# 4   norm[T.StandardScaler]:model[T.KNeighborsRegre... -0.0814      0.012
# 5          norm[T.StandardScaler]:model[T.ElasticNet] -0.0785      0.008
# 6                             da[T.feda]:model[T.SVR] -0.0531      0.006
# 7             da[T.feda]:model[T.KNeighborsRegressor] -0.0483      0.008
# 8         norm[T.None]:model[T.RandomForestRegressor] -0.0431      0.006
# 9            catn[T.low]:model[T.KNeighborsRegressor] -0.0341      0.007
# 10           catn[T.mid]:model[T.KNeighborsRegressor] -0.0332      0.008
# 11                     da[T.feda]:model[T.ElasticNet] -0.0313      0.006
# 12      catn[T.very low]:model[T.KNeighborsRegressor] -0.0267      0.007
# 13          da[T.feda]:model[T.RandomForestRegressor] -0.0262      0.006
# 14          norm[T.None]:model[T.KNeighborsRegressor] -0.0260      0.008
# 15            da[T.none]:model[T.KNeighborsRegressor] -0.0245      0.007
# 16               catn[T.very low]:model[T.ElasticNet] -0.0233      0.005
# 17                    catn[T.mid]:model[T.ElasticNet] -0.0173      0.005
# 18                     da[T.none]:model[T.ElasticNet] -0.0126      0.005
# 19                                   catn[T.very low] -0.0091      0.003
# 20                        norm[T.QuantileTransformer]  0.0094      0.003
# 21                                         da[T.none]  0.0126      0.003
# 22                                        catn[T.mid]  0.0145      0.003
# 23                        fs[T.ElasticNet]:model[SVR]  0.0162      0.006
# 24                                   C(datasets)[T.2]  0.0163      0.002
# 25             fs[T.RandomForestRegressor]:model[SVR]  0.0205      0.006
# 26                                       ctrp[T.True]  0.0261      0.002
# 27  fs[T.mutual_info_regression]:model[RandomFores...  0.0269      0.006
# 28                  norm[T.MinMaxScaler]:model[T.SVR]  0.0273      0.007
# 29            fs[T.mutual_info_regression]:model[SVR]  0.0277      0.006
# 30    fs[T.f_regression]:model[RandomForestRegressor]  0.0282      0.006
# 31                                       norm[T.None]  0.0297      0.003
# 32                             norm[T.StandardScaler]  0.0332      0.008
# 33                                       gdsc[T.True]  0.0500      0.002
# 34                                       model[T.SVR]  0.1106      0.005
# 35                     model[T.RandomForestRegressor]  0.2122      0.005
# 36                                model[T.ElasticNet]  0.2166      0.004
# 37                       model[T.KNeighborsRegressor]  0.2416      0.009
#
#             t   P>|t|  [0.005  0.995]
# 0     -37.700   0.000  -0.182  -0.159
# 1     -20.375   0.000  -0.098  -0.076
# 2      -7.889   0.000  -0.113  -0.057
# 3      -8.569   0.000  -0.107  -0.058
# 4      -6.538   0.000  -0.113  -0.049
# 5      -9.585   0.000  -0.100  -0.057
# 6      -8.346   0.000  -0.069  -0.037
# 7      -6.006   0.000  -0.069  -0.028
# 8      -7.395   0.000  -0.058  -0.028
# 9      -4.703   0.000  -0.053  -0.015
# 10     -4.427   0.000  -0.053  -0.014
# 11     -5.458   0.000  -0.046  -0.017
# 12     -3.721   0.000  -0.045  -0.008
# 13     -4.069   0.000  -0.043  -0.010
# 14     -3.415   0.001  -0.046  -0.006
# 15     -3.493   0.000  -0.043  -0.006
# 16     -4.936   0.000  -0.035  -0.011
# 17     -3.658   0.000  -0.030  -0.005
# 18     -2.692   0.007  -0.025  -0.001
# 19     -2.846   0.004  -0.017  -0.001
# 20      2.955   0.003   0.001   0.018
# 21      4.323   0.000   0.005   0.020
# 22      4.608   0.000   0.006   0.023
# 23      2.872   0.004   0.002   0.031
# 24      7.483   0.000   0.011   0.022
# 25      3.322   0.001   0.005   0.036
# 26     11.970   0.000   0.021   0.032
# 27      4.624   0.000   0.012   0.042
# 28      4.022   0.000   0.010   0.045
# 29      4.460   0.000   0.012   0.044
# 30      5.028   0.000   0.014   0.043
# 31      8.711   0.000   0.021   0.038
# 32      4.305   0.000   0.013   0.053
# 33     24.149   0.000   0.045   0.055
# 34     24.542   0.000   0.099   0.122
# 35     40.697   0.000   0.199   0.226
# 36     50.396   0.000   0.206   0.228
# 37     25.580   0.000   0.217   0.266

# %%
anova[(anova['coef']>0.03)|(anova['coef']<-0.03)]
# Out:
#                                                factor    coef    std err  \
# 0                                           Intercept -0.1704      0.005
# 1                                          da[T.feda] -0.0872      0.004
# 2                 norm[T.StandardScaler]:model[T.SVR] -0.0850      0.011
# 3   norm[T.StandardScaler]:model[T.RandomForestReg... -0.0824      0.010
# 4   norm[T.StandardScaler]:model[T.KNeighborsRegre... -0.0814      0.012
# 5          norm[T.StandardScaler]:model[T.ElasticNet] -0.0785      0.008
# 6                             da[T.feda]:model[T.SVR] -0.0531      0.006
# 7             da[T.feda]:model[T.KNeighborsRegressor] -0.0483      0.008
# 8         norm[T.None]:model[T.RandomForestRegressor] -0.0431      0.006
# 9            catn[T.low]:model[T.KNeighborsRegressor] -0.0341      0.007
# 10           catn[T.mid]:model[T.KNeighborsRegressor] -0.0332      0.008
# 11                     da[T.feda]:model[T.ElasticNet] -0.0313      0.006
# 32                             norm[T.StandardScaler]  0.0332      0.008
# 33                                       gdsc[T.True]  0.0500      0.002
# 34                                       model[T.SVR]  0.1106      0.005
# 35                     model[T.RandomForestRegressor]  0.2122      0.005
# 36                                model[T.ElasticNet]  0.2166      0.004
# 37                       model[T.KNeighborsRegressor]  0.2416      0.009
#
#             t   P>|t|  [0.005  0.995]
# 0     -37.700   0.000  -0.182  -0.159
# 1     -20.375   0.000  -0.098  -0.076
# 2      -7.889   0.000  -0.113  -0.057
# 3      -8.569   0.000  -0.107  -0.058
# 4      -6.538   0.000  -0.113  -0.049
# 5      -9.585   0.000  -0.100  -0.057
# 6      -8.346   0.000  -0.069  -0.037
# 7      -6.006   0.000  -0.069  -0.028
# 8      -7.395   0.000  -0.058  -0.028
# 9      -4.703   0.000  -0.053  -0.015
# 10     -4.427   0.000  -0.053  -0.014
# 11     -5.458   0.000  -0.046  -0.017
# 32      4.305   0.000   0.013   0.053
# 33     24.149   0.000   0.045   0.055
# 34     24.542   0.000   0.099   0.122
# 35     40.697   0.000   0.199   0.226
# 36     50.396   0.000   0.206   0.228
# 37     25.580   0.000   0.217   0.266

# %%
sns.palplot(sns.color_palette("seismic", n_colors=14)[:-3])

# %%
sns.set(font_scale=1.1)
g = sns.catplot(x='factor', y='coef', data=anova[(anova['coef']>0.03)|(anova['coef']<-0.03)],height=5, kind='bar', palette=sns.color_palette("seismic", n_colors=22)[:-4], aspect=2.1)
#labels = ['Intercept', 'FEDA','SS:SVR', 'SS:RF','SS:KNN','SS:EN', 'FEDA:SVR', 'FEDA:KNN', 'NoNorm:RF', 'Low:KNN', 'Mid:KNN', 'FEDA:EN', 'VLow:KNN','FEDA:RF', 'NoNorm:KNN', 'NoDA:KNN', 'VLow:EN','RF:SVR', 'CTRP', 'MI:RF', 'MinMax:SVR', 'MI:SVR', 'F:RF', 'NoNorm','SS', 'GDSC', 'SVR', 'RF', 'EN', 'KNN']
#labels = ['Intercept', 'FEDA','SS:SVR', 'SS:RF','SS:KNN','SS:EN', 'FEDA:SVR', 'FEDA:KNN', 'NoNorm:RF', 'Low:KNN', 'Mid:KNN', 'FEDA:EN', 'SS', 'GDSC', 'SVR', 'RF', 'EN', 'KNN']


g.set_xticklabels(rotation=90)
g.set(ylabel='coefficient')
plt.tight_layout()
#plt.savefig('anova2.png')
# Out:
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   if __name__ == '__main__':

# %%
sns.set(font_scale=1.1)
g = sns.catplot(x='factor', y='coef', data=anova[(anova['coef']>0.05)|(anova['coef']<-0.05)],height=5, kind='bar', palette=sns.color_palette("seismic", n_colors=14)[:-3], aspect=1.9)
labels = ['Intercept', 'FEDA','SS:SVR', 'SS:RF','SS:KNN','SS:EN', 'FEDA:SVR', 
          'SVR', 'RF', 'EN', 'KNN']
g.set_xticklabels(labels,rotation=45)
g.set(ylabel='coefficient')
plt.tight_layout()
#plt.savefig('graphs/anova.eps', format='eps')

# %% [markdown]
# # Statistical analysis

# %% [markdown]
# Here we calculate the p values and store them in an excel file. These will be used to determine if certain characteristics outperform others. Having statistically significant differences in their means

# %%
import scikit_posthocs as sp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-111-2441a686a57f> in <module>
# ----> 1 import scikit_posthocs as sp
#
# ModuleNotFoundError: No module named 'scikit_posthocs'

# %%
data = {}

# %%
data['datasets'] = sp.posthoc_ttest(clean, val_col='r2', group_col='datasets', equal_var=False)

# %%
clean[['da', 'seconds']].groupby('da').mean()
# Out:
#            seconds
# da
# ajive  3010.940019
# feda   4267.973428
# none   3099.367052

# %%
data['datime'] = sp.posthoc_ttest(clean, val_col='seconds', group_col='da',p_adjust='bonferroni', equal_var=False)

# %%
data['dar2'] = sp.posthoc_ttest(clean, val_col='r2', group_col='da',p_adjust='bonferroni', equal_var=False)

# %%
data['drug_metric']= sp.posthoc_ttest(clean, val_col='r2', group_col='metric_drug',p_adjust='bonferroni', equal_var=False)

# %%
clean[['ajive', 'r2']].groupby('ajive').mean()
# Out:
#              r2
# ajive
# 1.0    0.018035
# 2.0    0.009894
# 3.0    0.021486

# %%
data['ajive'] = sp.posthoc_ttest(clean[clean['ajive'].notnull()], val_col='r2', group_col='ajive',p_adjust='bonferroni', equal_var=False)

# %%
clean[['model', 'r2', 'r2_score']].groupby('model').describe()
# Out:
#                             r2                                           \
#                          count      mean       std        min       25%
# model
# DecisionTreeRegressor  32763.0 -0.107654  0.330173 -21.387152 -0.194470
# ElasticNet             36645.0  0.052347  0.177941 -17.062857 -0.037346
# KNeighborsRegressor    13429.0  0.057575  0.164130  -2.322091 -0.045199
# RandomForestRegressor  19146.0  0.067556  0.160275  -2.320106 -0.026550
# SVR                    17821.0 -0.025688  0.508320 -14.848288 -0.109139
#
#                                                     r2_score            \
#                             50%       75%       max    count      mean
# model
# DecisionTreeRegressor -0.084466  0.017947  1.616582  32763.0 -0.037711
# ElasticNet             0.046187  0.123836  1.821272  36645.0  0.125031
# KNeighborsRegressor    0.057143  0.140480  1.785508  13429.0  0.129778
# RandomForestRegressor  0.065927  0.148132  1.890687  19146.0  0.137984
# SVR                    0.039014  0.139992  1.463462  17821.0  0.049715
#
#                                                                           \
#                             std        min       25%       50%       75%
# model
# DecisionTreeRegressor  0.368877 -21.885501 -0.117190 -0.019682  0.093768
# ElasticNet             0.180468 -18.884530 -0.000032  0.097782  0.208514
# KNeighborsRegressor    0.169241  -2.808844 -0.002351  0.105865  0.224046
# RandomForestRegressor  0.175215  -4.073783  0.003616  0.114238  0.238969
# SVR                    0.570104 -15.346637 -0.045170  0.093328  0.239466
#
#
#                             max
# model
# DecisionTreeRegressor  0.909735
# ElasticNet             0.930501
# KNeighborsRegressor    0.892240
# RandomForestRegressor  0.909261
# SVR                    0.920145

# %%
data['model']= sp.posthoc_ttest(clean, val_col='r2', group_col='model',p_adjust='bonferroni', equal_var=False)

# %%
clean[['catnmodel', 'r2']].groupby('catnmodel').mean()
# Out:
#                                       r2
# catnmodel
# DecisionTreeRegressorhigh      -0.119226
# DecisionTreeRegressorlow       -0.104427
# DecisionTreeRegressormid       -0.093363
# DecisionTreeRegressorvery high -0.109124
# DecisionTreeRegressorvery low  -0.113852
# ElasticNethigh                  0.062686
# ElasticNetlow                   0.056247
# ElasticNetmid                   0.062682
# ElasticNetvery high             0.059287
# ElasticNetvery low              0.022645
# KNeighborsRegressorhigh         0.071434
# KNeighborsRegressorlow          0.034789
# KNeighborsRegressormid          0.071822
# KNeighborsRegressorvery high    0.074635
# KNeighborsRegressorvery low     0.042496
# RandomForestRegressorhigh       0.071088
# RandomForestRegressorlow        0.066879
# RandomForestRegressormid        0.076114
# RandomForestRegressorvery high  0.083644
# RandomForestRegressorvery low   0.046169
# SVRhigh                        -0.030149
# SVRlow                         -0.027772
# SVRmid                         -0.001914
# SVRvery high                   -0.022856
# SVRvery low                    -0.044914

# %%
clean[['norm', 'r2']].groupby('norm').mean()
# Out:
#                            r2
# norm
# MaxAbsScaler         0.025408
# MinMaxScaler         0.030459
# None                -0.027711
# QuantileTransformer  0.041444
# StandardScaler      -0.003402

# %%
data['norm']=sp.posthoc_ttest(clean, val_col='r2', group_col='norm', equal_var=False).sort_index()

# %%
clean['catnmodel'] = clean['model']+clean['catn'].astype(str)
data['catnmodel'] = sp.posthoc_ttest(clean, val_col='r2', group_col='catnmodel', equal_var=False).sort_index()

# %%
clean['damodel'] = clean['da']+clean['model']
data['damodel'] = sp.posthoc_ttest(clean, val_col='r2', group_col='damodel', equal_var=False)

# %%
clean['normodel'] = clean['model']+clean['norm']
data['normodel'] = sp.posthoc_ttest(clean, val_col='r2', group_col='normodel',p_adjust='bonferroni', equal_var=False).sort_index()

# %%
clean[['model','fs', 'r2']].groupby(['model','fs']).mean()
# Out:
#                                                     r2
# model                 fs
# DecisionTreeRegressor ElasticNet             -0.110480
#                       Lasso                  -0.109897
#                       RandomForestRegressor  -0.111533
#                       f_regression           -0.109480
#                       mutual_info_regression -0.095648
# ElasticNet            DecisionTreeRegressor   0.055742
#                       Lasso                   0.045464
#                       RandomForestRegressor   0.055860
#                       f_regression            0.047112
#                       mutual_info_regression  0.057798
# KNeighborsRegressor   DecisionTreeRegressor   0.060930
#                       ElasticNet              0.055133
#                       Lasso                   0.043864
#                       RandomForestRegressor   0.059342
#                       f_regression            0.055191
#                       mutual_info_regression  0.074310
# RandomForestRegressor DecisionTreeRegressor   0.048860
#                       ElasticNet              0.057723
#                       Lasso                   0.062217
#                       f_regression            0.081284
#                       mutual_info_regression  0.087961
# SVR                   DecisionTreeRegressor  -0.046653
#                       ElasticNet             -0.023859
#                       Lasso                  -0.029881
#                       RandomForestRegressor  -0.018541
#                       f_regression           -0.040974
#                       mutual_info_regression  0.003361

# %%
data['norm'] = sp.posthoc_ttest(clean, val_col='r2', group_col='norm',p_adjust='bonferroni', equal_var=False).sort_index()

# %%
clean['normodel'] = clean['norm']+clean['model']

a = {}
for i in clean['model'].unique():
    b = sp.posthoc_ttest(clean[clean['model']==i], val_col='r2',p_adjust='bonferroni', group_col='normodel', equal_var=False)
    a[i] = b

# %%
clean[['norm', 'r2']].groupby(['norm']).describe()
# Out:
#                           r2                                           \
#                        count      mean       std        min       25%
# norm
# MaxAbsScaler         16604.0  0.025408  0.295457  -9.638426 -0.053829
# MinMaxScaler         16675.0  0.030459  0.270299  -9.994582 -0.044749
# None                 54661.0 -0.027711  0.335489 -21.387152 -0.127564
# QuantileTransformer  15460.0  0.041444  0.239722  -6.263471 -0.056048
# StandardScaler       16404.0 -0.003402  0.248211 -17.062857 -0.081792
#
#
#                           50%       75%       max
# norm
# MaxAbsScaler         0.047451  0.127554  1.734022
# MinMaxScaler         0.051274  0.129497  1.890687
# None                -0.012319  0.103998  1.821272
# QuantileTransformer  0.059117  0.153869  1.726961
# StandardScaler       0.000085  0.075535  1.799190

# %%
model='RandomForestRegressor'
a[model][['StandardScaler'+model]]
# Out:
#                                           StandardScalerRandomForestRegressor
# StandardScalerRandomForestRegressor                             -1.000000e+00
# QuantileTransformerRandomForestRegressor                         1.877308e-15
# MaxAbsScalerRandomForestRegressor                                3.032053e-17
# MinMaxScalerRandomForestRegressor                                1.807952e-43
# NoneRandomForestRegressor                                        1.000000e+00

# %%
clean['fsmodel'] = clean['model']+clean['fs']

data['fsmodel'] = sp.posthoc_ttest(clean, val_col='r2', group_col='fsmodel', equal_var=False).sort_index()

# %%
clean['fsmodel'] = clean['model']+clean['fs']

a = {}
for i in clean['model'].unique():
    b = sp.posthoc_ttest(clean[clean['model']==i], val_col='r2',p_adjust='bonferroni', group_col='fsmodel', equal_var=False)
    a[i] = b

# %%
a['SVR']
# Out:
#                            SVRf_regression  SVRDecisionTreeRegressor  \
# SVRf_regression                  -1.000000                   1.00000
# SVRDecisionTreeRegressor          1.000000                  -1.00000
# SVRElasticNet                     1.000000                   1.00000
# SVRRandomForestRegressor          1.000000                   1.00000
# SVRmutual_info_regression         0.013424                   0.01341
# SVRLasso                          1.000000                   1.00000
#
#                            SVRElasticNet  SVRRandomForestRegressor  \
# SVRf_regression                 1.000000                       1.0
# SVRDecisionTreeRegressor        1.000000                       1.0
# SVRElasticNet                  -1.000000                       1.0
# SVRRandomForestRegressor        1.000000                      -1.0
# SVRmutual_info_regression       0.146746                       1.0
# SVRLasso                        1.000000                       1.0
#
#                            SVRmutual_info_regression  SVRLasso
# SVRf_regression                             0.013424  1.000000
# SVRDecisionTreeRegressor                    0.013410  1.000000
# SVRElasticNet                               0.146746  1.000000
# SVRRandomForestRegressor                    1.000000  1.000000
# SVRmutual_info_regression                  -1.000000  0.140391
# SVRLasso                                    0.140391 -1.000000

# %%
clean[['model', 'fs', 'r2']].groupby(['model', 'fs']).mean()
# Out:
#                                                     r2
# model                 fs
# DecisionTreeRegressor ElasticNet             -0.110480
#                       Lasso                  -0.109897
#                       RandomForestRegressor  -0.111533
#                       f_regression           -0.109480
#                       mutual_info_regression -0.095648
# ElasticNet            DecisionTreeRegressor   0.055742
#                       Lasso                   0.045464
#                       RandomForestRegressor   0.055860
#                       f_regression            0.047112
#                       mutual_info_regression  0.057798
# KNeighborsRegressor   DecisionTreeRegressor   0.060930
#                       ElasticNet              0.055133
#                       Lasso                   0.043864
#                       RandomForestRegressor   0.059342
#                       f_regression            0.055191
#                       mutual_info_regression  0.074310
# RandomForestRegressor DecisionTreeRegressor   0.048860
#                       ElasticNet              0.057723
#                       Lasso                   0.062217
#                       f_regression            0.081284
#                       mutual_info_regression  0.087961
# SVR                   DecisionTreeRegressor  -0.046653
#                       ElasticNet             -0.023859
#                       Lasso                  -0.029881
#                       RandomForestRegressor  -0.018541
#                       f_regression           -0.040974
#                       mutual_info_regression  0.003361

# %%
sp.posthoc_ttest(clean, val_col='r2', group_col='model', equal_var=False)
# Out:
#                          ElasticNet  DecisionTreeRegressor            SVR  \
# ElasticNet            -1.000000e+00           0.000000e+00   2.397743e-87
# DecisionTreeRegressor  0.000000e+00          -1.000000e+00   2.297734e-83
# SVR                    2.397743e-87           2.297734e-83  -1.000000e+00
# KNeighborsRegressor    2.030287e-03           0.000000e+00   1.676887e-92
# RandomForestRegressor  1.394168e-24           0.000000e+00  7.544494e-120
#
#                        KNeighborsRegressor  RandomForestRegressor
# ElasticNet                    2.030287e-03           1.394168e-24
# DecisionTreeRegressor         0.000000e+00           0.000000e+00
# SVR                           1.676887e-92          7.544494e-120
# KNeighborsRegressor          -1.000000e+00           4.939678e-08
# RandomForestRegressor         4.939678e-08          -1.000000e+00

# %%
sp.posthoc_ttest(clean, val_col='r2',p_adjust='bonferroni', group_col='damodel', equal_var=False)
# Out:
#                             noneElasticNet  noneDecisionTreeRegressor  \
# noneElasticNet               -1.000000e+00               0.000000e+00
# noneDecisionTreeRegressor     0.000000e+00              -1.000000e+00
# fedaDecisionTreeRegressor     0.000000e+00              2.370829e-114
# noneSVR                       2.192556e-12               6.191982e-61
# fedaSVR                      2.626676e-160               4.222702e-04
# fedaElasticNet                0.000000e+00               6.891120e-37
# noneKNeighborsRegressor       1.000000e+00               0.000000e+00
# fedaKNeighborsRegressor      1.422364e-283               1.486690e-16
# fedaRandomForestRegressor    4.021936e-253               4.770865e-47
# noneRandomForestRegressor     1.513534e-14               0.000000e+00
# ajiveElasticNet               1.000000e+00               0.000000e+00
# ajiveDecisionTreeRegressor    0.000000e+00               1.000000e+00
# ajiveRandomForestRegressor    2.353146e-01               0.000000e+00
# ajiveKNeighborsRegressor      9.236314e-06               0.000000e+00
# ajiveSVR                      3.584419e-26               8.849328e-31
#
#                             fedaDecisionTreeRegressor        noneSVR  \
# noneElasticNet                           0.000000e+00   2.192556e-12
# noneDecisionTreeRegressor               2.370829e-114   6.191982e-61
# fedaDecisionTreeRegressor               -1.000000e+00  2.952038e-228
# noneSVR                                 2.952038e-228  -1.000000e+00
# fedaSVR                                  1.076402e-20   3.902445e-60
# fedaElasticNet                           0.000000e+00   5.850702e-25
# noneKNeighborsRegressor                  0.000000e+00   9.882599e-15
# fedaKNeighborsRegressor                 9.076448e-267   1.155914e-31
# fedaRandomForestRegressor                0.000000e+00   1.118432e-17
# noneRandomForestRegressor                0.000000e+00   9.825158e-30
# ajiveElasticNet                          0.000000e+00   9.542169e-11
# ajiveDecisionTreeRegressor              1.367252e-125   1.650706e-80
# ajiveRandomForestRegressor               0.000000e+00   1.691897e-18
# ajiveKNeighborsRegressor                 0.000000e+00   3.640046e-23
# ajiveSVR                                2.021342e-154   1.819162e-01
#
#                                   fedaSVR  fedaElasticNet  \
# noneElasticNet              2.626676e-160    0.000000e+00
# noneDecisionTreeRegressor    4.222702e-04    6.891120e-37
# fedaDecisionTreeRegressor    1.076402e-20    0.000000e+00
# noneSVR                      3.902445e-60    5.850702e-25
# fedaSVR                     -1.000000e+00    1.182887e-31
# fedaElasticNet               1.182887e-31   -1.000000e+00
# noneKNeighborsRegressor     4.871040e-169    0.000000e+00
# fedaKNeighborsRegressor      1.415581e-21    4.567258e-03
# fedaRandomForestRegressor    8.518880e-38    2.245043e-02
# noneRandomForestRegressor   6.707224e-206    0.000000e+00
# ajiveElasticNet             2.386058e-163    0.000000e+00
# ajiveDecisionTreeRegressor   5.066716e-02    5.056921e-86
# ajiveRandomForestRegressor  8.605307e-181    0.000000e+00
# ajiveKNeighborsRegressor    1.809596e-188    0.000000e+00
# ajiveSVR                     5.337292e-37    8.420844e-07
#
#                             noneKNeighborsRegressor  fedaKNeighborsRegressor  \
# noneElasticNet                         1.000000e+00            1.422364e-283
# noneDecisionTreeRegressor              0.000000e+00             1.486690e-16
# fedaDecisionTreeRegressor              0.000000e+00            9.076448e-267
# noneSVR                                9.882599e-15             1.155914e-31
# fedaSVR                               4.871040e-169             1.415581e-21
# fedaElasticNet                         0.000000e+00             4.567258e-03
# noneKNeighborsRegressor               -1.000000e+00             0.000000e+00
# fedaKNeighborsRegressor                0.000000e+00            -1.000000e+00
# fedaRandomForestRegressor             3.129731e-302             2.531455e-09
# noneRandomForestRegressor              2.509000e-12             0.000000e+00
# ajiveElasticNet                        6.832977e-03             0.000000e+00
# ajiveDecisionTreeRegressor             0.000000e+00             5.014031e-38
# ajiveRandomForestRegressor             1.000000e+00             0.000000e+00
# ajiveKNeighborsRegressor               5.902326e-04             0.000000e+00
# ajiveSVR                               2.346128e-29             4.289580e-11
#
#                             fedaRandomForestRegressor  \
# noneElasticNet                          4.021936e-253
# noneDecisionTreeRegressor                4.770865e-47
# fedaDecisionTreeRegressor                0.000000e+00
# noneSVR                                  1.118432e-17
# fedaSVR                                  8.518880e-38
# fedaElasticNet                           2.245043e-02
# noneKNeighborsRegressor                 3.129731e-302
# fedaKNeighborsRegressor                  2.531455e-09
# fedaRandomForestRegressor               -1.000000e+00
# noneRandomForestRegressor                0.000000e+00
# ajiveElasticNet                          0.000000e+00
# ajiveDecisionTreeRegressor               5.702462e-98
# ajiveRandomForestRegressor               0.000000e+00
# ajiveKNeighborsRegressor                 0.000000e+00
# ajiveSVR                                 1.689006e-03
#
#                             noneRandomForestRegressor  ajiveElasticNet  \
# noneElasticNet                           1.513534e-14     1.000000e+00
# noneDecisionTreeRegressor                0.000000e+00     0.000000e+00
# fedaDecisionTreeRegressor                0.000000e+00     0.000000e+00
# noneSVR                                  9.825158e-30     9.542169e-11
# fedaSVR                                 6.707224e-206    2.386058e-163
# fedaElasticNet                           0.000000e+00     0.000000e+00
# noneKNeighborsRegressor                  2.509000e-12     6.832977e-03
# fedaKNeighborsRegressor                  0.000000e+00     0.000000e+00
# fedaRandomForestRegressor                0.000000e+00     0.000000e+00
# noneRandomForestRegressor               -1.000000e+00     3.187830e-43
# ajiveElasticNet                          3.187830e-43    -1.000000e+00
# ajiveDecisionTreeRegressor               0.000000e+00     0.000000e+00
# ajiveRandomForestRegressor               1.075552e-07     1.417449e-10
# ajiveKNeighborsRegressor                 1.000000e+00     3.041727e-18
# ajiveSVR                                 2.063861e-47     1.366392e-24
#
#                             ajiveDecisionTreeRegressor  \
# noneElasticNet                            0.000000e+00
# noneDecisionTreeRegressor                 1.000000e+00
# fedaDecisionTreeRegressor                1.367252e-125
# noneSVR                                   1.650706e-80
# fedaSVR                                   5.066716e-02
# fedaElasticNet                            5.056921e-86
# noneKNeighborsRegressor                   0.000000e+00
# fedaKNeighborsRegressor                   5.014031e-38
# fedaRandomForestRegressor                 5.702462e-98
# noneRandomForestRegressor                 0.000000e+00
# ajiveElasticNet                           0.000000e+00
# ajiveDecisionTreeRegressor               -1.000000e+00
# ajiveRandomForestRegressor                0.000000e+00
# ajiveKNeighborsRegressor                  0.000000e+00
# ajiveSVR                                  3.446046e-42
#
#                             ajiveRandomForestRegressor  \
# noneElasticNet                            2.353146e-01
# noneDecisionTreeRegressor                 0.000000e+00
# fedaDecisionTreeRegressor                 0.000000e+00
# noneSVR                                   1.691897e-18
# fedaSVR                                  8.605307e-181
# fedaElasticNet                            0.000000e+00
# noneKNeighborsRegressor                   1.000000e+00
# fedaKNeighborsRegressor                   0.000000e+00
# fedaRandomForestRegressor                 0.000000e+00
# noneRandomForestRegressor                 1.075552e-07
# ajiveElasticNet                           1.417449e-10
# ajiveDecisionTreeRegressor                0.000000e+00
# ajiveRandomForestRegressor               -1.000000e+00
# ajiveKNeighborsRegressor                  3.553293e-01
# ajiveSVR                                  3.391061e-34
#
#                             ajiveKNeighborsRegressor       ajiveSVR
# noneElasticNet                          9.236314e-06   3.584419e-26
# noneDecisionTreeRegressor               0.000000e+00   8.849328e-31
# fedaDecisionTreeRegressor               0.000000e+00  2.021342e-154
# noneSVR                                 3.640046e-23   1.819162e-01
# fedaSVR                                1.809596e-188   5.337292e-37
# fedaElasticNet                          0.000000e+00   8.420844e-07
# noneKNeighborsRegressor                 5.902326e-04   2.346128e-29
# fedaKNeighborsRegressor                 0.000000e+00   4.289580e-11
# fedaRandomForestRegressor               0.000000e+00   1.689006e-03
# noneRandomForestRegressor               1.000000e+00   2.063861e-47
# ajiveElasticNet                         3.041727e-18   1.366392e-24
# ajiveDecisionTreeRegressor              0.000000e+00   3.446046e-42
# ajiveRandomForestRegressor              3.553293e-01   3.391061e-34
# ajiveKNeighborsRegressor               -1.000000e+00   1.469125e-39
# ajiveSVR                                1.469125e-39  -1.000000e+00

# %%
this = 0
for k,v in data.items():
    this+=v.shape[0]

# %%
this
# Out:
# 116

# %%
with pd.ExcelWriter('means.xlsx') as writer:
    for k,v in means.items():
        v.to_excel(writer, sheet_name=k)

# %%
with pd.ExcelWriter('pvalues.xlsx') as writer:
    for k,v in data.items():
        v.to_excel(writer, sheet_name=k)

# %% [markdown]
# # Odds Ratio

# %%
def OR(indices, rest, top, group):
    li = []
    for i in indices:
        model_t = top[(top[group[0]]==i[0])&(top[group[1]]==i[1])].shape[0]
        nmodel_t = top[(top[group[0]]!=i[0])|(top[group[1]]!=i[1])].shape[0]
        model_r = rest[(rest[group[0]]==i[0])&(rest[group[1]]==i[1])].shape[0]
        nmodel_r = rest[(rest[group[0]]!=i[0])|(rest[group[1]]!=i[1])].shape[0]
        if model_r > 0 and nmodel_r > 0:
            li.append((model_t/model_r)/(nmodel_t/nmodel_r))
        else:
            li.append(0)
    return li

# %%
def top_OR(data, group, q=0.95, score='r2_score'):
    top = data[data[score] >= data[score].quantile(q)]
    counts = data[group +[score]].groupby(group).count()
    topcounts = top[group +[score]].groupby(group).count()
    topcounts['OR'] = OR(topcounts.index, data[data[score]<data[score].quantile(q)], top, group)
    return topcounts

# %%
def ORone(indices, rest, top, group):
    li = []
    for i in indices:
        model_t = top[(top[group[0]]==i)].shape[0]
        nmodel_t = top[(top[group[0]]!=i)].shape[0]
        model_r = rest[(rest[group[0]]==i)].shape[0]
        nmodel_r = rest[(rest[group[0]]!=i)].shape[0]
        if model_r > 0 and nmodel_r > 0:
            li.append((model_t/model_r)/(nmodel_t/nmodel_r))
        else:
            li.append(0)
    return li

# %%
def one_OR(data, group, q=0.95, score='r2_score'):
    top = data[data[score] >= data[score].quantile(q)]
    counts = data[group +[score]].groupby(group).count()
    topcounts = top[group +[score]].groupby(group).count()
    topcounts['OR'] = ORone(topcounts.index, data[data[score]<data[score].quantile(q)], top, group)
    return topcounts

# %% [markdown]
# # Hyper parameters

# %% [markdown]
# Here some initial exploration of the hyper parameters of the models is performed

# %% [markdown]
# ## KNN

# %%
knn = clean[clean['model']=='KNeighborsRegressor'][['Drug', 'fs', 'da','ajive', 'catn', 'n_neighbors', 'weights', 'algorithm', 'p','r2_score', 'r2']]

# %%
knn.head()
# Out:
#            Drug     fs    da  ajive catn  n_neighbors   weights  algorithm  \
# 207     AZD6482  Lasso  none    NaN  low         29.0   uniform  ball_tree
# 208     AZD7762  Lasso  none    NaN  low         13.0  distance  ball_tree
# 209  BMS-754807  Lasso  none    NaN  low         20.0  distance  ball_tree
# 210   Dasatinib  Lasso  none    NaN  low         14.0  distance  ball_tree
# 211   Docetaxel  Lasso  none    NaN  low         24.0  distance    kd_tree
#
#        p  r2_score        r2
# 207  1.0  0.416520  0.236597
# 208  1.0  0.377099  0.109259
# 209  2.0  0.112876  0.033824
# 210  1.0  0.427305  0.157184
# 211  1.0  0.107432 -0.010444

# %%
sns.set(font_scale=1.1)
#order= ['DecisionTreeRegressor', 'ElasticNet', 'KNeighborsRegressor', 'RandomForestRegressor', 'SVR']
g = sns.catplot(x='weights', y='r2', hue='algorithm', data=knn[knn['n_neighbors']>5], kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

plt.legend(loc='lower center')
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-n.eps', format='eps')

# %%
knn['ajive'] = knn['ajive'].fillna(0)
sns.set(font_scale=1.1)
order= ['very low', 'low', 'mid', 'high', 'very high']

g = sns.catplot(x='catn', y='r2',order=order, hue='ajive', data=knn, kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

plt.legend(loc='lower left')
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-n.eps', format='eps')

# %%
sns.set(font_scale=1.1)
order= ['very low', 'low', 'mid', 'high', 'very high']
g = sns.catplot(x='catn', y='r2',hue='da', data=knn,order=order, kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

plt.legend(loc='lower center')
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-n.eps', format='eps')

# %%
sns.set(font_scale=1.1)
order= ['very low', 'low', 'mid', 'high', 'very high']
g = sns.catplot(x='catn', y='r2', hue='p', data=knn,order=order, kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

plt.legend(loc='lower left')
plt.tight_layout()
g.set(xlabel='features')
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-n.eps', format='eps')

# %%
sns.set(font_scale=1.1)
#hue = ['DecisionTreeRegressor', 'mutual_info_regression', 'ElasticNet', 'f_regression', 'Lasso', 'RandomForestRegressor', ]
g = sns.catplot(x = 'catn', y='OR', hue='da',order=order,data=top_OR(knn, ['da', 'catn'], score='r2').reset_index(), kind='bar', palette='Greens', height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])
g.set_ylabels('Odds Ratio')
plt.legend(loc='upper center')
plt.tight_layout()
#plt.savefig('graphs/adjusted-top-n.eps', format='eps')

# %% [markdown]
# ## Random Forest

# %%
rf = clean[clean['model']=='RandomForestRegressor'][['Drug', 'fs', 'da', 'catn', 'n_estimators', 'max_depth', 'max_features','r2_score', 'r2']]

# %%
sns.set(font_scale=1.1)
#hue = ['DecisionTreeRegressor', 'mutual_info_regression', 'ElasticNet', 'f_regression', 'Lasso', 'RandomForestRegressor', ]
g = sns.catplot(x = 'max_depth', y='OR', hue='max_features',data=top_OR(rf, ['max_depth', 'max_features'], score='r2').reset_index(), kind='bar', height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])
g.set_ylabels('Odds Ratio')
plt.legend(loc='lower right')
plt.tight_layout()
#plt.savefig('graphs/adjusted-top-n.eps', format='eps')

# %%
sns.set(font_scale=1.1)

g = sns.catplot(x='n_estimators', y='r2', hue='max_depth', data=rf, kind='bar',palette='Greens',height=5, aspect=1.9, legend=False)
#order= ['DecisionTreeRegressor', 'ElasticNet', 'KNeighborsRegressor', 'RandomForestRegressor', 'SVR']
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])
plt.legend(title='max_depth',ncol=2)
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-depth.eps', format='eps')

# %%
sns.set(font_scale=1.1)
#order= ['DecisionTreeRegressor', 'ElasticNet', 'KNeighborsRegressor', 'RandomForestRegressor', 'SVR']
g = sns.catplot(x='max_features', y='r2', data=rf, kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

plt.legend(loc='lower center')
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-depth.eps', format='eps')
# Out:
# No handles with labels found to put in legend.

# %%
sns.set(font_scale=1.1)
#order= ['DecisionTreeRegressor', 'ElasticNet', 'KNeighborsRegressor', 'RandomForestRegressor', 'SVR']
g = sns.catplot(x='max_depth', y='r2', hue='fs', data=rf, kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

plt.legend(loc='lower center')
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-n.eps', format='eps')

# %%
sns.set(font_scale=1.1)
#order= ['DecisionTreeRegressor', 'ElasticNet', 'KNeighborsRegressor', 'RandomForestRegressor', 'SVR']
g = sns.catplot(x='n_estimators', y='r2', hue='max_depth', data=rf, kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

plt.legend(loc='lower center')
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-n.eps', format='eps')

# %% [markdown]
# ## Elastic Net

# %%
en = clean[clean['model']=='ElasticNet'][['Drug', 'fs', 'da', 'catn', 'alpha', 'l1_ratio','r2_score', 'r2']]

# %%
sns.set(font_scale=1.1)
#hue = ['DecisionTreeRegressor', 'mutual_info_regression', 'ElasticNet', 'f_regression', 'Lasso', 'RandomForestRegressor', ]
g = sns.catplot(x = 'alpha', y='OR', hue='l1_ratio',data=top_OR(en, ['l1_ratio', 'alpha'], score='r2').reset_index(), kind='bar', palette='Greens', height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])
g.set_ylabels('Odds Ratio')
plt.legend(loc='lower right')
plt.tight_layout()
#plt.savefig('graphs/adjusted-top-n.eps', format='eps')

# %%
sns.set(font_scale=1.1)
#order= ['DecisionTreeRegressor', 'ElasticNet', 'KNeighborsRegressor', 'RandomForestRegressor', 'SVR']
g = sns.catplot(x='alpha', y='r2', data=en, kind='bar',height=5, aspect=1.9, legend=False)
#g.set_xticklabels(['Decision Tree', 'Elastic Net', 'KNN', 'Random Forest', 'SVR'])

#plt.legend(loc='lower center')
plt.tight_layout()
#g.set(yscale='symlog')
#plt.savefig('graphs/adjusted-n.eps', format='eps')
