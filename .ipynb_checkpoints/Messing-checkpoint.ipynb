# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_regression, mutual_info_regression, SelectFromModel, VarianceThreshold
from methods import pre

# %% [markdown]
# ## Implementing New DA's and Standardization/Normalization

# %%
gdsc_ge = pd.read_csv('data/Processed/gdsc_cell_ge.csv').fillna(0).set_index('CCL')

# %%
import OnPLS
import numpy as np

# %%
np.random.seed(42)

n, p_1, p_2, p_3 = 4, 3, 4, 5
t = np.sort(np.random.randn(n, 1), axis=0)
p1 = np.sort(np.random.randn(p_1, 1), axis=0)
p2 = np.sort(np.random.randn(p_2, 1), axis=0)
p3 = np.sort(np.random.randn(p_3, 1), axis=0)
X1 = np.dot(t, p1.T) + 0.1 * np.random.randn(n, p_1)
X2 = np.dot(t, p2.T) + 0.1 * np.random.randn(n, p_2)
X3 = np.dot(t, p3.T) + 0.1 * np.random.randn(n, p_3)

# %%
# Define the connections between blocks
predComp = [[0, 1, 1], [1, 0, 1], [1, 1, 0]]
# Define the numbers of non-global components
orthComp = [1, 1, 1]

# Create the estimator
onpls = OnPLS.estimators.OnPLS(predComp, orthComp)

# %%
# Fit a model
onpls.fit([X1, X2, X3])

# Perform prediction of all matrices from all connected matrices
Xhat = onpls.predict([X1, X2, X3])

# Compute prediction score
score = onpls.score([X1, X2, X3])

cv_scores = OnPLS.resampling.cross_validation(onpls, [X1, X2, X3], cv_rounds=4)
# Out:
# /Users/admin/Desktop/Thesis/Code/OnPLS/OnPLS/estimators.py:132: UserWarning: Too small orthogonal component for matrix 2! Not included!
#   warnings.warn(warning)
# /Users/admin/Desktop/Thesis/Code/OnPLS/OnPLS/estimators.py:132: UserWarning: Too small orthogonal component for matrix 0! Not included!
#   warnings.warn(warning)

# %%
onpls.precomputedW
# Out:
# [array([[-0.15363395],
#         [-0.18393189],
#         [ 0.97085821]]),
#  array([[-0.38025657],
#         [-0.45758902],
#         [ 0.47166374],
#         [ 0.65080762]]),
#  array([[ 0.69783882],
#         [ 0.64528545],
#         [ 0.22216816],
#         [ 0.20472423],
#         [-0.07319133]])]

# %% [markdown]
# ## Checking ElasticNet RandomizedSearch

# %%
gdsc_ge = pd.read_csv('data/Processed/gdsc_cell_ge.csv').fillna(0).set_index('CCL')
gdsc_dr = pd.read_csv('data/Processed/gdsc_poz_dr.csv').fillna(0)

# %%
gdsc

# %%
from sklearn import linear_model
from sklearn.datasets import load_iris
from sklearn.model_selection import RandomizedSearchCV
iris = load_iris()
t3 = {
    'alpha': [0.5, 1, 1.5, 2, 5],
    'l1_ratio': [0, 0.25, 0.5, 0.75, 1],
    'max_iter': [5000]
}

lo = RandomizedSearchCV(linear_model.ElasticNet(), t3, n_iter=50, scoring='r2')
lo.fit(iris.data, iris.target)
pe = pd.DataFrame(lo.cv_results_)
# Out:
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2052: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/model_selection/_search.py:271: UserWarning: The total space of parameters 25 is smaller than n_iter=50. Running 25 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/admin/Desktop/Thesis/Code/phc-data-pipeline/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %% [markdown]
# ## Reducing memory usage by using indices

# %%
from classes import drug
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_regression, mutual_info_regression, SelectFromModel, VarianceThreshold

# %%
# %%time
gdsc_ge = pd.read_csv('data/Processed/gdsc_cell_ge.csv').fillna(0).set_index('CCL')
ctrp_ge = pd.read_csv('data/Processed/ctrp_cell_ge.csv').fillna(0).set_index('CCL')
gdsc_dr = pd.read_csv('data/Processed/gdsc_poz_dr.csv').fillna(0)
ctrp_dr = pd.read_csv('data/Processed/ctrp_poz_dr.csv').fillna(0)
# Out:
# CPU times: user 35.9 s, sys: 579 ms, total: 36.5 s
# Wall time: 36.4 s

# %%
# %%time
aag = drug('17-AAG', {'ctrp': ctrp_ge, 'gdsc': gdsc_ge}, {'ctrp': ctrp_dr, 'gdsc': gdsc_dr})
# Out:
# CPU times: user 1.44 s, sys: 4.97 ms, total: 1.45 s
# Wall time: 1.45 s

# %%
aag.pre()

# %%
'ge' in aag.__dict__
# Out:
# False

# %%
aag.combine()

# %%
aag.split()

# %%
aag.get('X', 'train').shape
# Out:
# (827, 20600)

# %%
# Out:
# 'mean is 1, std is 2'

# %%
aag.fs(mutual_info_regression, n=0.01)
# Out:
# 206 features
# [[ 8.22625117  7.9240769  11.25370085 ...  0.          0.
#    0.        ]
#  [ 7.38502456  9.18294846 11.28107417 ...  0.          0.
#    0.        ]
#  [ 6.48340108 10.20096264  9.33630783 ...  6.24645304  3.41559208
#    3.64098972]
#  ...
#  [ 6.48211485  9.75738726 10.56100587 ...  8.97084604  3.28393378
#    3.57814007]
#  [ 5.82768649  9.15923494 10.25319984 ...  3.9957859   3.14716415
#    3.25962857]
#  [ 5.93190027 10.3220042   9.9263591  ...  3.53349924  3.26787564
#    3.32453528]]
# After fs (276, 206) (827, 206)

# %%
aag.get('X', 'train')
# Out:
#                      AGGF1     ANAPC5      AP3S1  ARHGAP27      ASPH  \
#      CCL
# ctrp LN229        8.226251   7.924077  11.253701  4.407883  7.413361
#      KCL22        7.385025   9.182948  11.281074  4.634485  7.294799
# gdsc HUPT4        6.483401  10.200963   9.336308  4.412368  5.471657
#      SIMA         5.733640   9.590814   9.940340  3.210771  3.790866
#      RPMI6666     5.988554   9.614634  10.509346  3.716671  3.724674
# ctrp NCIH520      7.554070   8.654919  11.247098  4.837946  6.880808
#      SIGM5        7.505783   9.508165  11.261540  5.623851  5.387787
# gdsc HUPT3        5.927602   9.884768  10.187934  4.142101  6.135774
#      CAL27        6.039181   9.712396  10.369503  3.897784  5.095961
#      CCFSTTG1     6.448939   9.764155  10.411066  3.218237  6.006615
#      EW22         5.895883  10.643214   9.926383  3.195529  5.039069
#      SKCO1        5.463876  10.255246   9.851045  3.814860  4.381802
#      MDAMB175VII  0.000000   0.000000   0.000000  0.000000  0.000000
#      P30OHK       5.364537  10.435565   9.801633  3.915209  3.447255
# ctrp RT4          7.897703   8.599565  10.855744  5.897786  7.753499
#      ONS76        8.147711   8.259714  11.217261  5.221980  8.062563
#      SW620        7.850675   9.011963  10.868859  5.557184  6.687329
# gdsc IGR1         6.658858  10.528090  10.316008  3.272897  5.335654
#      IGROV1       6.697842   9.965031  10.006696  3.411352  6.185626
#      ES8          6.461207  10.117543  10.254876  3.219853  4.947870
# ctrp F36P         7.438694   8.634550  11.039533  5.368833  4.334154
#      NCIH1650     7.599365   8.287609  12.366556  5.945763  7.515549
#      AN3CA        5.791632  8.593442  5.897358  4.206349
#      LP1          5.993863  6.909197  3.226815  4.276136
# ...                    ...       ...       ...       ...
#      MFM223       7.103192  3.785752  3.101469  3.389945
#      MOLT13       5.427390  8.206062  3.431871  5.169534
#      KPNYN        5.274998  9.315734  3.798741  4.091679
#      MS1          6.144052  3.875589  3.500161  3.433611
#      HCE4         6.069724  5.468818  3.745651  3.463285
# ctrp NCIH1869     0.000000  0.000000  0.000000  0.000000
# gdsc NB13         6.418076  9.471542  4.023624  3.904980
# ctrp LUDLU1       0.000000  0.000000  0.000000  0.000000
# gdsc NUGC3        6.568435  7.371823  5.181240  3.592279
#      TE5          8.201441  8.666656  3.654915  3.281088
#      NCIH1299     5.164678  3.908460  3.298752  3.288492
#      CORL105      5.474832  5.408972  3.113632  3.648309
#      KYSE410      7.045104  6.644224  3.127400  3.664931
# ctrp NCO2         0.000000  0.000000  0.000000  0.000000
# gdsc HCC2218      6.652979  4.604968  3.861655  4.109958
#      M059J        6.305898  7.045714  2.977307  3.553071
#      RO82W1       7.584827  5.700158  3.065886  3.911151
# ctrp NCIH2023     0.000000  0.000000  0.000000  0.000000
#      KELLY        0.000000  0.000000  0.000000  0.000000
#      KYSE450      0.000000  0.000000  0.000000  0.000000
# gdsc SCC4         8.011306  7.128382  3.036918  3.408622
#      EFO21        7.003787  5.929505  3.517867  3.313351
#      CP66MEL      6.557878  5.510015  3.126647  4.368478
# ctrp NCIH1568     0.000000  0.000000  0.000000  0.000000
# gdsc JIYOYEP2003  4.920929  3.406811  3.736626  3.546764
# ctrp 42MGBA       0.000000  0.000000  0.000000  0.000000
# gdsc TGBC24TKB    6.433465  5.555820  3.553610  4.064103
#      NO10         5.808211  8.970846  3.283934  3.578140
#      SCH          6.982197  3.995786  3.147164  3.259629
#      BFTC905      6.611940  3.533499  3.267876  3.324535
#
# [827 rows x 206 columns]

# %%
aag.get('X', 'train').shape
# Out:
# (827, 2060)

# %%
from methods import pre
lo = 34
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-79a1a8c91006> in <module>
#       1 from methods import pre
#       2 lo = 34
# ----> 3 lo.__name__
#
# AttributeError: 'int' object has no attribute '__name__'

# %%
aag.X['fs_test']

# %% [markdown]
# ## Speeding up combine

# %%
gdsc_dr = pd.read_csv('data/Processed/gdsc_poz_dr.csv').fillna(0)
gdsc_ge = pd.read_csv('data/Processed/gdsc_cell_ge.csv').fillna(0).set_index('CCL')

# %%
gdsc_ge.shape[1]
# Out:
# 19562

# %%
dr = gdsc_dr
ge = gdsc_ge

# %%
ge.join(dr[dr['Drug_name'] == '17-AAG'][['CCL', 'AUC_IC50']].set_index('CCL'), how='right')
# Out:
#              A1BG      A1CF       A2M     A2ML1   A3GALT2  A3GALT2P    A4GALT  \
# CCL
# 22RV1    3.537942  6.364651  5.332441  2.923030  2.815383  2.815383  3.241125
# 2313287  3.370950  6.284884  3.485675  2.831562  2.913369  2.913369  3.313028
# 5637     2.927335  2.892365  3.181651  2.926549  2.677943  2.677943  4.295357
# 639V     3.953010  2.858072  2.892599  2.828334  2.729762  2.729762  2.960059
# 647V     2.804009  2.944390  3.178071  2.675572  2.949402  2.949402  3.029297
# ...           ...       ...       ...       ...       ...       ...       ...
# YAPC     3.043994  3.055992  3.532297  2.946112  2.835091  2.835091  3.273226
# YH13     5.167861  3.072842  3.049070  3.098071  3.029716  3.029716  2.990092
# YKG1     4.711624  3.067945  3.306930  3.037960  2.713442  2.713442  3.154398
# YT       3.143593  3.779792  5.095163  2.879333  2.749091  2.749091  3.186225
# ZR7530   5.594177  3.032126  3.562195  3.108549  2.767673  2.767673  3.611381
#
#             A4GNT      AAAS      AACS  ...    ZWILCH      ZWINT      ZXDB  \
# CCL                                    ...
# 22RV1    3.262633  4.722157  4.942126  ...  7.526319   9.274166  3.785757
# 2313287  3.096527  4.873621  4.213177  ...  6.526713   8.021952  3.520584
# 5637     3.205598  5.249042  4.495021  ...  7.057572   9.261486  3.492602
# 639V     3.121154  4.445200  4.017422  ...  6.310088   8.021780  3.919468
# 647V     3.024326  4.636786  4.724453  ...  8.657911   9.426794  3.657576
# ...           ...       ...       ...  ...       ...        ...       ...
# YAPC     3.182387  4.474313  4.238488  ...  8.619045  10.392332  3.704526
# YH13     3.318574  4.561866  3.581945  ...  8.048126   8.235304  3.305898
# YKG1     2.988924  4.586814  3.781220  ...  7.978261   9.150385  3.972405
# YT       3.359589  4.511721  4.241912  ...  8.196766   9.205680  3.515323
# ZR7530   3.247737  4.547910  4.423134  ...  7.398583   8.781244  3.574957
#
#              ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3  AUC_IC50
# CCL
# 22RV1    5.201929  2.742575  4.635015  3.940190  4.658663  8.088672  0.169156
# 2313287  4.957371  2.636933  4.350120  4.395806  4.598583  7.951146  0.577314
# 5637     4.813163  2.558705  4.580977  4.810975  4.371501  7.974367  0.828724
# 639V     5.923131  2.782005  4.969272  5.481422  5.205446  8.118109  0.726141
# 647V     6.082990  3.148358  5.182059  5.203430  4.806941  8.530606  0.008665
# ...           ...       ...       ...       ...       ...       ...       ...
# YAPC     5.128979  3.082707  4.061633  3.664478  4.276836  7.238275  0.502122
# YH13     4.745612  2.577626  5.215836  7.003537  4.203823  7.919283  0.881166
# YKG1     5.166082  2.813449  5.117194  5.085635  4.918170  8.208343  0.803193
# YT       5.152341  2.472749  5.046783  6.016707  5.168183  7.063949  0.513477
# ZR7530   5.301549  3.045222  4.952083  4.604161  4.472996  7.675603  0.463716
#
# [660 rows x 19563 columns]

# %%
dr[dr['Drug_name'] == '17-AAG'][['CCL', 'AUC_IC50']].set_index('CCL')
# Out:
#          AUC_IC50
# CCL
# 22RV1    0.169156
# 2313287  0.577314
# 5637     0.828724
# 639V     0.726141
# 647V     0.008665
# ...           ...
# YAPC     0.502122
# YH13     0.881166
# YKG1     0.803193
# YT       0.513477
# ZR7530   0.463716
#
# [660 rows x 1 columns]

# %%
# %%time
drug_dr = dr[dr['Drug_name'] == '17-AAG'][['CCL', 'AUC_IC50']]
# Out:
# CPU times: user 7.94 ms, sys: 1.2 ms, total: 9.14 ms
# Wall time: 15.4 ms

# %%
# %%time
X = np.array([list(ge.loc[i].values) for i in drug_dr[drug_dr['CCL'].isin(ge.index)]['CCL']])
gdsc_ge = pd.read_csv('data/Processed/gdsc_cell_ge.csv').fillna(0).set_index('CCL')

# %%
print(type(gdsc_ge.keys()))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
gdsc_ge.shape
# Out:
# (706, 19562)

# %%
gdsc_ge.shape[0]
# Out:
# 706

# %%
# %%time
under = (gdsc_ge.to_numpy()>5).T.astype(np.int8)

n = [np.count_nonzero(i) > 0.1*gdsc_ge.shape[0] for i in under]
names = {gdsc_ge.keys()[k]:v for k, v in enumerate(n)}
indices = [k for k,v in names.items() if v]
index = gdsc_ge[indices]
# Out:
# CPU times: user 117 ms, sys: 6.79 ms, total: 124 ms
# Wall time: 125 ms

# %%
# %%time
index2 = pre(gdsc_ge,t=5, p=0.1)
# Out:
# CPU times: user 6.17 s, sys: 127 ms, total: 6.3 s
# Wall time: 6.36 s

# %%
index.shape
# Out:
# (706, 9919)

# %%
index2.shape
# Out:
# (706, 9919)

# %% [markdown]
# ## Domain Adaptation experiments

# %%
X_a = np.random.rand(3, 2) * 3

# %%
X_b = np.random.rand(3, 2) * 4

# %%
X_c = np.random.rand(3, 2) * 5

# %%
def jump(domain, n, data):
    result = []
    for i, ele in enumerate(data):
        result.append(ele)
        for j in range(0, domain):
            result.append(0)
        result.append(ele)
        for j in range(0, n-domain-1):
            result.append(0)
    return result

# %%
def feda(domains):
    n = len(domains)
    
    samples = 0
    for i in domains:
        samples += i.shape[0]
    
    features = domains[0].shape[1]*(n+1)
    
    new = np.zeros(features)
    for i, data in enumerate(domains):
        for j in data:
            new = np.vstack([new, jump(i, n, j)])
            
    return new[1:]

# %%
feda([X_a, X_b, X_c])
# Out:
# array([[2.39552445, 2.39552445, 0.        , 0.        , 0.8923882 ,
#         0.8923882 , 0.        , 0.        ],
#        [2.09713092, 2.09713092, 0.        , 0.        , 1.99024727,
#         1.99024727, 0.        , 0.        ],
#        [2.17421497, 2.17421497, 0.        , 0.        , 2.66618415,
#         2.66618415, 0.        , 0.        ],
#        [3.77029806, 0.        , 3.77029806, 0.        , 0.52768015,
#         0.        , 0.52768015, 0.        ],
#        [3.03560501, 0.        , 3.03560501, 0.        , 1.3673342 ,
#         0.        , 1.3673342 , 0.        ],
#        [2.41889914, 0.        , 2.41889914, 0.        , 3.77142649,
#         0.        , 3.77142649, 0.        ],
#        [0.70066211, 0.        , 0.        , 0.70066211, 3.89969596,
#         0.        , 0.        , 3.89969596],
#        [1.67451535, 0.        , 0.        , 1.67451535, 0.97901028,
#         0.        , 0.        , 0.97901028],
#        [0.52645206, 0.        , 0.        , 0.52645206, 1.13973433,
#         0.        , 0.        , 1.13973433]])

# %% [markdown]
# ## Mess

# %%
from methods import fs

# %%
fs.__doc__
# Out:
# ' Returns a subset of {X_train} and {X_test} with features being selected by the method {model}\n    :param int n: it can be the variance thereshold or the number of chosen features \n    :\n    '

# %%
from classes import drug
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
import config as c
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_regression, mutual_info_regression, SelectFromModel, VarianceThreshold

# %%
gdsc_ge = pd.read_csv(c.dir + 'gdsc_cell_ge.csv').fillna(0).set_index('CCL')
ctrp_ge = pd.read_csv(c.dir + 'ctrp_cell_ge.csv').fillna(0).set_index('CCL')
gdsc_dr = pd.read_csv(c.dir + 'gdsc_poz_dr.csv').fillna(0)
ctrp_dr = pd.read_csv(c.dir + 'ctrp_poz_dr.csv').fillna(0)

# %%
# %%time
aag = drug('17-AAG', {'ctrp': ctrp_ge, 'gdsc': gdsc_ge}, {'ctrp': ctrp_dr, 'gdsc': gdsc_dr})
# Out:
# CPU times: user 973 ms, sys: 119 ms, total: 1.09 s
# Wall time: 1.1 s

# %%
aag.to_json()
# Out:
# col
# <class 'list'>
# da
# <class 'dict'>
# data
# <class 'pandas.core.frame.DataFrame'>
# dr
# <class 'pandas.core.frame.DataFrame'>
# ge
# <class 'pandas.core.frame.DataFrame'>
# name
# <class 'str'>
# predicted
# <class 'list'>

# %%
# %%time
aag.pre()
# Out:
# CPU times: user 496 ms, sys: 297 ms, total: 794 ms
# Wall time: 888 ms

# %%
# %%time
aag.combine()
# Out:
# CPU times: user 478 ms, sys: 398 ms, total: 876 ms
# Wall time: 898 ms

# %%
# %%time
aag.split()
# Out:
# CPU times: user 141 ms, sys: 109 ms, total: 250 ms
# Wall time: 254 ms

# %%
# %%time
aag.fs(f_regression, n=0.01)
# Out:
# After fs (276, 206) (827, 206)
# CPU times: user 364 ms, sys: 185 ms, total: 550 ms
# Wall time: 466 ms

# %%
# %%time
aag.feda()
# Out:
# CPU times: user 938 ms, sys: 702 ms, total: 1.64 s
# Wall time: 1.69 s

# %%
aag.get('X', 'train')
# Out:
#           0         1    2          3          4          5         6    \
# 0    4.031054  4.031054  0.0  10.708475  10.708475   0.000000  3.620436
# 1    4.070159  4.070159  0.0  10.684955  10.684955   0.000000  3.457989
# 2    4.254251  4.254251  0.0  10.563919  10.563919   0.000000  3.448932
# 3    4.292504  4.292504  0.0   6.804169   6.804169   0.000000  3.800755
# 4    4.086229  4.086229  0.0  12.579925  12.579925   0.000000  3.383222
# ..        ...       ...  ...        ...        ...        ...       ...
# 822  0.000000  0.000000  0.0   0.000000   0.000000   0.000000  0.000000
# 823  0.000000  0.000000  0.0   0.000000   0.000000   0.000000  0.000000
# 824  0.000000  0.000000  0.0   9.771689   0.000000   9.771689  0.000000
# 825  0.000000  0.000000  0.0  12.743566   0.000000  12.743566  0.000000
# 826  0.000000  0.000000  0.0  11.653961   0.000000  11.653961  0.000000
#
#           7    8         9    ...       608       609  610       611  \
# 0    3.620436  0.0  5.459297  ...  0.000000  0.000000  0.0  0.000000
# 1    3.457989  0.0  6.579006  ...  0.000000  0.000000  0.0  0.000000
# 2    3.448932  0.0  4.778966  ...  0.000000  0.000000  0.0  0.000000
# 3    3.800755  0.0  4.509346  ...  0.000000  0.000000  0.0  0.000000
# 4    3.383222  0.0  5.262325  ...  0.000000  0.000000  0.0  0.000000
# ..        ...  ...       ...  ...       ...       ...  ...       ...
# 822  0.000000  0.0  0.000000  ...  0.000000  0.000000  0.0  0.000000
# 823  0.000000  0.0  0.000000  ...  0.000000  0.000000  0.0  0.000000
# 824  0.000000  0.0  0.000000  ...  5.976329  3.557185  0.0  3.557185
# 825  0.000000  0.0  0.000000  ...  5.782401  3.402952  0.0  3.402952
# 826  0.000000  0.0  0.000000  ...  5.114994  4.132016  0.0  4.132016
#
#           612  613       614       615  616       617
# 0    0.000000  0.0  0.000000  0.000000  0.0  0.000000
#
columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(aag.data.drop(aag.metric, axis=1), aag.data[aag.metric])

# %%
from methods import fs
X_train, X_test, co = fs(f_regression, X_train, X_test, y_train, n=0.01)

# %%
from methods import drp
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score

mod = drp(DecisionTreeRegressor(), X_train, y_train)
ypred= mod.predict(X_test)
r2_score(y_test, ypred)
# Out:
# -0.3029939981101124

# %%
# %%time
aag.train(DecisionTreeRegressor())
# Out:
# CPU times: user 203 ms, sys: 101 ms, total: 303 ms
# Wall time: 314 ms

# %%
importances = {0:[],1:[],2:[]}
e=0
for j in aag.model.feature_importances_:
    importances[e].append(j*100)
    if e == 2:
        e = 0
    else:
        e += 1

# %%
pd.DataFrame.from_dict(importances).rename(columns={0:'Global', 1:'CTRP', 2:'GDSC'}).describe()
# Out:
#            Global        CTRP        GDSC
# count  206.000000  206.000000  206.000000
# mean     0.234660    0.107341    0.143436
# std      0.643431    0.702760    0.357749
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.001635    0.000000    0.001708
# 75%      0.081482    0.000000    0.057856
# max      4.915703    6.327331    2.865300

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

aag.metrics([r2_score, mean_absolute_error, mean_squared_error, median_absolute_error])
# Out:
# {'r2_score': -0.589656604796021,
#  'mean_absolute_error': 0.29517072848360304,
#  'mean_squared_error': 0.1373123651256232,
#  'median_absolute_error': 0.2491798193489835}

# %%
aag.scores
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-875c1d3ec278> in <module>
# ----> 1 aag.scores
#
# AttributeError: 'drug' object has no attribute 'scores'

# %%
aag.to_json()

# %% [markdown]
# ## Runs

# %%
from runs import run
from sklearn.svm import SVR
from classes import tuning

# %%
from classes import drug
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_regression, mutual_info_regression, SelectFromModel, VarianceThreshold

# %%
#ge = {'ctrp': ctrp_ge, 'gdsc': gdsc_ge}
#dr = {'ctrp': ctrp_dr, 'gdsc': gdsc_dr}

t2 = {
    'degree': [2, 3, 4, 5],
    'epsilon' : [0.1, 0.2, 0.3, 0.9],
    'C':[0.01, 0.1, 1, 10, 100],
    'gamma':['scale']
}
tune = tuning(t2, iterations=50, cv=3, scoring='r2')

# %%
ge={'gdsc':True, 'ctrp':False, 'ccle':False}

# %%
# %%time
r1, scores = run(ge, 'ElasticNet', False, 'DecisionTreeRegressor',drugs=3, n = 0.1, tuning = None)
# Out:
# CPU times: user 27.4 s, sys: 1.93 s, total: 29.4 s
# Wall time: 54.9 s

# %%
for i in r1.values():
    print(len(i.col))
# Out:
# 1607
# 1607
# 1607

# %%
model = {k:v.model.get_params() for k,v in r1.items()}

# %%
for i in r1.values():
    print(i.metrics([r2_score]))
# Out:
# {'r2_score': -0.4402398209397902}
# {'r2_score': -1.1516677873876828}
# {'r2_score': -0.9183615617612619}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
scores = pd.DataFrame.from_dict(scores, orient='index')

# %%
scores = scores.join(pd.DataFrame.from_dict(model, orient='index'))

# %%
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_regression, mutual_info_regression, SelectFromModel, VarianceThreshold

# %%
VarianceThreshold.__name__
# Out:
# 'VarianceThreshold'

# %%
scores
# Out:
#                      r2_score  mean_absolute_error  mean_squared_error  \
# PD-173074            0.998486             0.001222            0.000030
# S-Trityl-L-cysteine  0.999911             0.001753            0.000006
# Vinorelbine          0.999976             0.000921            0.000002
#
#                      median_absolute_error criterion max_depth max_features  \
# PD-173074                         0.000151       mse      None         None
# S-Trityl-L-cysteine               0.001241       mse      None         None
# Vinorelbine                       0.000581       mse      None         None
#
#                     max_leaf_nodes  min_impurity_decrease min_impurity_split  \
# PD-173074                     None                    0.0               None
# S-Trityl-L-cysteine           None                    0.0               None
# Vinorelbine                   None                    0.0               None
#
#                      min_samples_leaf  min_samples_split  \
# PD-173074                           1                  2
# S-Trityl-L-cysteine                 1                  2
# Vinorelbine                         1                  2
#
#                      min_weight_fraction_leaf  presort random_state splitter
# PD-173074                                 0.0    False         None     best
# S-Trityl-L-cysteine                       0.0    False         None     best
# Vinorelbine                               0.0    False         None     best

# %%
a = [1,2,3]
b = [2,3,4]
x = [2,7,9]

# %%
c = set(a) & set(b)

# %%
list(c & set(x))
# Out:
# [2]

# %%
import pandas as pd
import config as c

# %%
ccle_ge = pd.read_csv(c.dir + 'ccle_cell_ge.csv').fillna(0).set_index('CCL')
ctrp_ge = pd.read_csv(c.dir + 'ctrp_cell_ge.csv').fillna(0).set_index('CCL')
ccle_dr = pd.read_csv(c.dir + 'ccle_poz_dr.csv').fillna(0)
ctrp_dr = pd.read_csv(c.dir + 'ctrp_poz_dr.csv').fillna(0)

# %%
drug_data = {'ccle':ccle_dr, 'ctrp':ctrp_dr}
[item for sublist in [list(j['Drug_name'].unique()) for j in drug_data.values()] for item in sublist]
# Out:
# ['17-AAG',
#  'AEW541',
#  'Saracatinib',
#  'Selumetinib',
#  'Erlotinib',
#  'Irinotecan',
#  'L-685458',
#  'Lapatinib',
#  'LBW242',
#  'Nilotinib',
#  'Nutlin-3',
#  'Paclitaxel',
#  'Panobinostat',
#  'PD-0325901',
#  'PD-0332991',
#  'Crizotinib',
#  'PHA-665752',
#  'PLX-4720',
#  'RAF265',
#  'Sorafenib',
#  'TAE684',
#  'Dovitinib',
#  'Topotecan',
#  'Vandetanib',
#  '16-beta-bromoandrosterone',
#  '1S,3R-RSL-3',
#  '3-Cl-AHPC',
#  '968',
#  'A-804598',
#  'AA-COCF3',
#  'Abiraterone',
#  'ABT-199',
#  'ABT-737',
#  'AC55649',
#  'Afatinib',
#  'AGK-2',
#  'Alisertib',
#  'Alisertib_navitoclax 2 to 1 ratio mol by mol',
#  'Flavopiridol',
#  'AM-580',
#  'Apicidin',
#  'AT-406',
#  'AT13387',
#  'AT7867',
#  'Austocystin D',
#  'Avicin D',
#  'Avrainvillamide',
#  'Axitinib',
#  'AZ-3146',
#  'Azacitidine',
#  'AZD1480',
#  'AZD4547',
#  'AZD6482',
#  'AZD7545',
#  'AZD7762',
#  'AZD8055',
#  'B02',
#  'Bafilomycin A1',
#  'Barasertib',
#  'Bardoxolone methyl',
#  'Bax channel blocker',
#  'BCL-LZH-4',
#  'BEC',
#  'Belinostat',
#  'Bendamustine',
#  'Betulinic acid',
#  'Bexarotene',
#  'BI-2536',
#  'BIBR-1532',
#  'BIRB-796',
#  'Birinapant',
#  'BIX-01294',
#  'Blebbistatin',
#  'Bleomycin',
#  'BMS-195614',
#  'BMS-270394',
#  'BMS-345541',
#  'BMS-536924',
#  'BMS-754807',
#  'Bortezomib',
#  'Bosutinib',
#  'BRD-A02303741',
#  'BRD-A02303741_carboplatin 1 to 1 ratio mol by mol',
#  'BRD-A02303741_navitoclax 2 to 1 ratio mol by mol',
#  'BRD-A05715709',
#  'BRD-A71883111',
#  'BRD-A86708339',
#  'BRD-A94377914',
#  'BRD-K01737880',
#  'BRD-K02251932',
#  'BRD-K02492147',
#  'BRD-K03536150',
#  'BRD-K03911514',
#  'BRD-K04800985',
#  'BRD-K07442505',
#  'BRD-K09344309',
#  'BRD-K09587429',
#  'BRD-K11533227',
#  'BRD-K13185470',
#  'BRD-K13999467',
#  'BRD-K14844214',
#  'BRD-K16130065',
#  'BRD-K16147474',
#  'BRD-K17060750',
#  'BRD-K19103580',
#  'BRD-K20514654',
#  'BRD-K24690302',
#  'BRD-K26531177',
#  'BRD-K27188169',
#  'BRD-K27188169_navitoclax 2 to 1 ratio mol by mol',
#  'BRD-K27224038',
#  'BRD-K27986637',
#  'BRD-K28456706',
#  'BRD-K29086754',
#  'BRD-K29313308',
#  'BRD-K30019337',
#  'BRD-K30748066',
#  'BRD-K33199242',
#  'BRD-K33514849',
#  'BRD-K34099515',
#  'BRD-K34222889',
#  'BRD-K34485477',
#  'BRD-K35604418',
#  'BRD-K37390332',
#  'BRD-K41334119',
#  'BRD-K41597374',
#  'BRD-K42260513',
#  'BRD-K44224150',
#  'BRD-K45681478',
#  'BRD-K48334597',
#  'BRD-K48477130',
#  'BRD-K49290616',
#  'BRD-K50799972',
#  'BRD-K51490254',
#  'BRD-K51831558',
#  'BRD-K52037352',
#  'BRD-K55116708',
#  'BRD-K55473186',
#  'BRD-K58730230',
#  'BRD-K61166597',
#  'BRD-K63431240',
#  'BRD-K64610608',
#  'BRD-K66453893',
#  'BRD-K66532283',
#  'BRD-K70511574',
#  'BRD-K71781559',
#  'BRD-K71935468',
#  'BRD-K75293299',
#  'BRD-K78574327',
#  'BRD-K79669418',
#  'BRD-K80183349',
#  'BRD-K84807411',
#  'BRD-K85133207',
#  'BRD-K86535717',
#  'BRD-K88742110',
#  'BRD-K90370028',
#  'BRD-K92856060',
#  'BRD-K94991378',
#  'BRD-K96431673',
#  'BRD-K96970199',
#  'BRD-K97651142',
#  'BRD-K99006945',
#  'BRD-K99584050',
#  'BRD-M00053801',
#  'BRD1812',
#  'BRD1835',
#  'BRD4132',
#  'BRD6340',
#  'BRD8899',
#  'BRD8958',
#  'BRD9647',
#  'BRD9876',
#  'BRD9876_MK-1775 4 to 1 ratio mol by mol',
#  'Brefeldin A',
#  'Brivanib',
#  'BYL-719',
#  'C6-ceramide',
#  'Cabozantinib',
#  'CAL-101',
#  'Canertinib',
#  'Carboplatin',
#  'Carboplatin_etoposide 40 to 17 ratio mol by mol',
#  'Carboplatin_UNC0638 2 to 1 ratio mol by mol',
#  'CAY10576',
#  'CAY10594',
#  'CAY10618',
#  'CBB-1007',
#  'CCT036477',
#  'CD-1530',
#  'CD-437',
#  'Cediranib',
#  'Ceranib-2',
#  'Cerulenin',
#  'Ch-55',
#  'CHIR-99021',
#  'Chlorambucil',
#  'CHM-1',
#  'CI-976',
#  'Ciclopirox',
#  'Ciclosporin',
#  'CID-5951923',
#  'CIL41',
#  'CIL55',
#  'CIL55A',
#  'CIL56',
#  'CIL70',
#  'Cimetidine',
#  'Clofarabine',
#  'COL-3',
#  'Compound 1541A',
#  'Compound 1B',
#  'Compound 23 citrate',
#  'Compound 7d-cis',
#  'CR-1-31B',
#  'Crizotinib',
#  'Crizotinib_PLX-4032 2 to 1 ratio mol by mol',
#  'Cucurbitacin I',
#  'Curcumin',
#  'Cyanoquinoline 11',
#  'Cyclophosphamide',
#  'Cytarabine',
#  'Cytochalasin B',
#  'Dabrafenib',
#  'Dacarbazine',
#  'Daporinad',
#  'Darinaparsin',
#  'Dasatinib',
#  'DBeQ',
#  'Decitabine',
#  'Decitabine_carboplatin 1 to 1 ratio mol by mol',
#  'Decitabine_navitoclax 2 to 1 ratio mol by mol',
#  'Dexamethasone',
#  'Dinaciclib',
#  'Docetaxel',
#  'Docetaxel_tanespimycin 2 to 1 ratio mol by mol',
#  'Doxorubicin',
#  'Doxorubicin_navitoclax 2 to 1 ratio mol by mol',
#  'ELCPK',
#  'Elocalcitol',
#  'Entinostat',
#  'Epigallocatechin-3-monogallate',
#  'Erastin',
#  'Erismodegib',
#  'Erlotinib',
#  'Erlotinib_vemurafenib 2 to 1 ratio mol by mol',
#  'Etomoxir',
#  'Etoposide',
#  'ETP-46464',
#  'EX-527',
#  'FGIN-1-27',
#  'Fingolimod',
#  'Fluorouracil',
#  'Fluvastatin',
#  'Foretinib',
#  'FQI-1',
#  'FQI-2',
#  'FSC231',
#  'Fulvestrant',
#  'Fumonisin B1',
#  'GANT-61',
#  'GDC-0879',
#  'GDC-0941',
#  'Gefitinib',
#  'Gemcitabine',
#  'GMX-1778',
#  'Gossypol',
#  'GSK-3 inhibitor IX',
#  'GSK-J4',
#  'GSK1059615',
#  'GSK2636771',
#  'GSK4112',
#  'GSK461364',
#  'GSK525762A',
#  'GW-405833',
#  'GW-843682X',
#  'HBX-41108',
#  'HC-067047',
#  'HLI 373',
#  'Hyperforin',
#  'I-BET151',
#  'Ibrutinib',
#  'IC-87114',
#  'Ifosfamide',
#  'Imatinib',
#  'Importazole',
#  'Indisulam',
#  'IPR-456',
#  'Isoevodiamine',
#  'Isoliquiritigenin',
#  'Isonicotinohydroxamic acid',
#  'ISOX',
#  'ISOX_bortezomib 250 to 1 ratio mol by mol',
#  'Istradefylline',
#  'Itraconazole',
#  'IU1',
#  'JQ-1',
#  'JQ-1_carboplatin 1 to 1 ratio mol by mol',
#  'JQ-1_MK-0752 1 to 1 ratio mol by mol',
#  'JQ-1_navitoclax 2 to 1 ratio mol by mol',
#  'JQ-1_UNC0638 2 to 1 ratio mol by mol',
#  'JQ-1_vorinostat 2 to 1 ratio mol by mol',
#  'JW-480',
#  'JW-55',
#  'JW-74',
#  'KH-CB19',
#  'KHS101',
#  'Ki8751',
#  'Ko-143',
#  'KPT185',
#  'KU-0063794',
#  'KU-55933',
#  'KU-60019',
#  'KU 0060648',
#  'KW-2449',
#  'KX2-391',
#  'L-685458',
#  'Lapatinib',
#  'Panobinostat',
#  'LE-135',
#  'Lenvatinib',
#  'Leptomycin B',
#  'Linifanib',
#  'Linsitinib',
#  'Lomeguatrib',
#  'Lovastatin',
#  'LRRK2-IN-1',
#  'LY-2157299',
#  'LY-2183240',
#  'Manumycin A',
#  'Marinopyrrole A',
#  'Masitinib',
#  'Mdivi-1',
#  'Merck60',
#  'Methotrexate',
#  'Methylstat',
#  'MG-132',
#  'MGCD-265',
#  'MI-1',
#  'MI-2',
#  'Mitomycin',
#  'MK-0752',
#  'MK-1775',
#  'MK-2206',
#  'ML006',
#  'ML029',
#  'ML031',
#  'ML050',
#  'ML083',
#  'ML162',
#  'ML203',
#  'ML210',
#  'ML239',
#  'ML258',
#  'ML311',
#  'ML312',
#  'ML320',
#  'ML334 diastereomer',
#  'MLN2238',
#  'MLN2480',
#  'Momelotinib',
#  'MST-312',
#  'Myricetin',
#  'Myriocin',
#  'N9-isopropylolomoucine',
#  'Nakiterpiosin',
#  'Narciclasine',
#  'Navitoclax',
#  'Navitoclax_birinapant 1 to 1 ratio mol by mol',
#  'Navitoclax_gemcitabine 1 to 1 ratio mol by mol',
#  'Navitoclax_MST-312 1 to 1 ratio mol by mol',
#  'Navitoclax_piperlongumine 1 to 1 ratio mol by mol',
#  'Navitoclax_pluripotin 1 to 1 ratio mol by mol',
#  'Navitoclax_vemurafenib 1 to 1 ratio mol by mol',
#  'Navitoclax_sorafenib 1 to 1 ratio mol by mol',
#  'Necrostatin-1',
#  'Necrostatin-7',
#  'Necrosulfonamide',
#  'Nelarabine',
#  'Neopeltolide',
#  'Neratinib',
#  'Neuronal differentiation inducer III',
#  'Niclosamide',
#  'Nilotinib',
#  'Nintedanib',
#  'NPC-26',
#  'NSC 74859',
#  'NSC19630',
#  'NSC23766',
#  'NSC30930',
#  'NSC48300',
#  'NSC632839',
#  'NSC95397',
#  'Nutlin-3',
#  'NVP-231',
#  'NVP-ADW742',
#  'NVP-BEZ235',
#  'NVP-BSK805',
#  'TAE684',
#  'O-6-benzylguanine',
#  'Obatoclax',
#  'Olaparib',
#  'Oligomycin A',
#  'Omacetaxine mepesuccinate',
#  'OSI-027',
#  'OSI-930',
#  'Ouabain',
#  'Oxaliplatin',
#  'PAC-1',
#  'Paclitaxel',
#  'Palmostatin B',
#  'Pandacostat',
#  'Parbendazole',
#  'Parthenolide',
#  'Pazopanib',
#  'PD 153035',
#  'PD318088',
#  'PDMP',
#  'Pevonedistat',
#  'PF-184',
#  'PF-3758309',
#  'PF-4800567',
#  'PF-543',
#  'PF-573228',
#  'PF-750',
#  'PHA-793887',
#  'Phloretin',
#  'PI-103',
#  'Pifithrin-alpha',
#  'Pifithrin-mu',
#  'PIK-93',
#  'Piperlongumine',
#  'Piperlongumine_MST-312 1 to 1 ratio mol by mol',
#  'Pitstop2',
#  'PL-DI',
#  'Platin',
#  'Pluripotin',
#  'Vemurafenib',
#  'PLX-4720',
#  'PRIMA-1',
#  'PRIMA-1-Met',
#  'PRL-3 inhibitor I',
#  'Procarbazine',
#  'Prochlorperazine',
#  'Purmorphamine',
#  'PX-12',
#  'PYR-41',
#  'Pyrazolanthrone',
#  'QS-11',
#  'Quizartinib',
#  'QW-BI-011',
#  'R428',
#  'RAF265',
#  'Regorafenib',
#  'Repligen 136',
#  'RG-108',
#  'Rigosertib',
#  'RITA',
#  'RO4929097',
#  'Ruxolitinib',
#  'Salermide',
#  'Salermide_vemurafenib 12 to 1 ratio mol by mol',
#  'Saracatinib',
#  'SB-225002',
#  'SB-431542',
#  'SB-525334',
#  'SB-743921',
#  'SCH-529074',
#  'SCH-79797',
#  'Selumetinib',
#  'Selumetinib_BRD-A02303741 4 to 1 ratio mol by mol',
#  'Selumetinib_decitabine 4 to 1 ratio mol by mol',
#  'Selumetinib_GDC-0941 4 to 1 ratio mol by mol',
#  'Selumetinib_JQ-1 4 to 1 ratio mol by mol',
#  'Selumetinib_MK-2206 8 to 1 ratio mol by mol',
#  'Selumetinib_navitoclax 8 to 1 ratio mol by mol',
#  'Selumetinib_piperlongumine 8 to 1 ratio mol by mol',
#  'Selumetinib_vemurafenib 8 to 1 ratio mol by mol',
#  'Selumetinib_tretinoin 2 to 1 ratio mol by mol',
#  'Selumetinib_UNC0638 4 to 1 ratio mol by mol',
#  'Selumetinib_vorinostat 8 to 1 ratio mol by mol',
#  'Semagacestat',
#  'Serdemetan',
#  'Serdemetan_SCH-529074 1 to 1 ratio mol by mol',
#  'SGX-523',
#  'SID 26681509',
#  'Sildenafil',
#  'Silmitasertib',
#  'Simvastatin',
#  'Rapamycin',
#  'Sirolimus_bortezomib 250 to 1 ratio mol by mol',
#  'Sitagliptin',
#  'SJ-172550',
#  'Skepinone-L',
#  'SKI-II',
#  'SMER-3',
#  'SN-38',
#  'SNS-032',
#  'SNX-2112',
#  'SNX-2112_bortezomib 250 to 1 ratio mol by mol',
#  'Sorafenib',
#  'Sotrastaurin',
#  'Spautin-1',
#  'SR-II-138A',
#  'SR1001',
#  'SR8278',
#  'SRT-1720',
#  'Staurosporine',
#  'StemRegenin 1',
#  'STF-31',
#  'SU11274',
#  'Sunitinib',
#  'SZ4TA2',
#  'Tacedinaline',
#  'Tacrolimus',
#  'Tamatinib',
#  'Tamoxifen',
#  'Tandutinib',
#  '17-AAG',
#  'Tanespimycin_bortezomib 250 to 1 ratio mol by mol',
#  'Tanespimycin_gemcitabine 1 to 1 ratio mol by mol',
#  'Temozolomide',
#  'Temsirolimus',
#  'Teniposide',
#  'TG-100-115',
#  'TG-101348',
#  'TGX-221',
#  'Thalidomide',
#  'Tigecycline',
#  'Tipifarnib-P1',
#  'Tipifarnib',
#  'Tivantinib',
#  'Tivozanib',
#  'Topotecan',
#  'Tosedostat',
#  'TPCA-1',
#  'Trametinib',
#  'Tretinoin',
#  'Tretinoin_carboplatin 2 to 1 ratio mol by mol',
#  'Tretinoin_navitoclax 4 to 1 ratio mol by mol',
#  'Triazolothiadiazine',
#  'Trifluoperazine',
#  'Triptolide',
#  'Tubastatin A',
#  'TW-37',
#  'UNC0321',
#  'UNC0638',
#  'UNC0638_navitoclax 1 to 1 ratio mol by mol',
#  'VAF-347',
#  'Valdecoxib',
#  'Vandetanib',
#  'Veliparib',
#  'VER-155008',
#  'Vincristine',
#  'Vorapaxar',
#  'Vorinostat',
#  'Vorinostat_carboplatin 1 to 1 ratio mol by mol',
#  'Vorinostat_navitoclax 4 to 1 ratio mol by mol',
#  'VU0155056',
#  'VX-680',
#  'WAY-362450',
#  'WP1130',
#  'WZ4002',
#  'WZ8040',
#  'XL765',
#  'YK 4-279',
#  'YL54',
#  'YM-155',
#  'Zebularine',
#  'ZSTK474']

# %% [markdown]
# ## Fixing feda

# %%
from methods import feda
from classes import drug
import pandas as pd

# %%
ccle_ge = pd.read_csv(c.dir + 'ccle_cell_ge.csv').fillna(0).set_index('CCL')
ctrp_ge = pd.read_csv(c.dir + 'ctrp_cell_ge.csv').fillna(0).set_index('CCL')
ccle_dr = pd.read_csv(c.dir + 'ccle_poz_dr.csv').fillna(0)
ctrp_dr = pd.read_csv(c.dir + 'ctrp_poz_dr.csv').fillna(0)

# %%
a = ccle_ge[:3][['A1BG', 'A1CF']]
b = ctrp_ge[:3][['A1BG', 'A1CF']]
c = ctrp_ge[3:6][['A1BG', 'A1CF']]

# %%
a
# Out:
#             A1BG      A1CF
# CCL
# 1321N1  5.542720  3.921564
# 22RV1   4.753564  7.445061
# 42MGBA  7.290132  4.030574

# %%
b
# Out:
#             A1BG      A1CF
# CCL
# 22RV1   4.753564  7.445061
# 42MGBA  7.290132  4.030574
# 5637    4.293473  4.157908

# %%
c
# Out:
#           A1BG      A1CF
# CCL
# 639V  6.627165  4.094668
# 697   6.991375  4.027624
# 769P  4.477092  5.060515

# %%
pd.DataFrame(feda([a.to_numpy(), b.to_numpy(), c.to_numpy()]))
# Out:
#           0         1         2         3         4         5         6  \
# 0  5.542720  5.542720  0.000000  0.000000  3.921564  3.921564  0.000000
# 1  4.753564  4.753564  0.000000  0.000000  7.445061  7.445061  0.000000
# 2  7.290132  7.290132  0.000000  0.000000  4.030574  4.030574  0.000000
# 3  4.753564  0.000000  4.753564  0.000000  7.445061  0.000000  7.445061
# 4  7.290132  0.000000  7.290132  0.000000  4.030574  0.000000  4.030574
# 5  4.293473  0.000000  4.293473  0.000000  4.157908  0.000000  4.157908
# 6  6.627165  0.000000  0.000000  6.627165  4.094668  0.000000  0.000000
# 7  6.991375  0.000000  0.000000  6.991375  4.027624  0.000000  0.000000
# 8  4.477092  0.000000  0.000000  4.477092  5.060515  0.000000  0.000000
#
#           7
# 0  0.000000
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  0.000000
# 5  0.000000
# 6  4.094668
# 7  4.027624
# 8  5.060515
